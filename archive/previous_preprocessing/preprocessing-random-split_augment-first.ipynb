# %% [markdown]
# ###  MFCC-Chroma Fusion using a Dual-Channel CNN-LSTM Preprocessing Pipeline

# %% [markdown]
# ##### Import Statements

# %%
import numpy as np
import pandas as pd
import os
import librosa as lb
import soundfile as sf
from sklearn.model_selection import StratifiedShuffleSplit
from tqdm import tqdm
import shutil
import matplotlib.pyplot as plt
import zipfile
from collections import defaultdict
import random

from scipy.signal import butter, filtfilt
import librosa as lb
import numpy as np

# %% [markdown]
# ### 1. Initial Configuration

# %% [markdown]
# ##### Defined Parameters

# %%
# Target size per class 
TARGET_COUNT = 500                      
SEG_LEN = 6
SR = 4000

# %% [markdown]
# ##### Paths

# %%
# Where the dataset rests
RAW_DATA_DIR = "/home/rithik-tank/Desktop/Auscultate/preprocessing/Respiratory_Sound_Database"

ROOT_DIR = "/home/rithik-tank/Desktop/Auscultate/preprocessing" 

#Save Directories
SEGMENTS_DIR = "outputs/segmentation_outputs/" 
#TEST_SEGMENTS_DIR = "outputs/segmentation_outputs/test_segments" 
#VAL_SEGMENTS_DIR = "outputs/segmentation_outputs/val_segments" 
TRAIN_SEGMENTS_AUGMENTED_DIR = "outputs/augmentation_outputs/train_segments" 
TEST_SEGMENTS_AUGMENTED_DIR = "outputs/augmentation_outputs/test_segments" 
VAL_SEGMENTS_AUGMENTED_DIR = "outputs/augmentation_outputs/val_segments" 
SEGMENTS_AUGMENTED_DIR = "outputs/augmentation_outputs/segments"
SPLIT_DIR = "outputs/final/"

# %% [markdown]
# ##### Filters and Normalization

# %% [markdown]
# The function `load_audio` essentially loads the different audio clips following a 4000Hz sampling rate and applies butterworth filtering prior to returning the audio file. This function will be used to load the **unsegmented** audio files.

# %%
def butterworth_filter(y, sr, lowcut=50, highcut=1800, order=4):
    nyquist = 0.5 * sr

    low = lowcut / nyquist
    high = highcut / nyquist

    b, a = butter(order, [low, high], btype="band")
    return filtfilt(b, a, y)

# %% [markdown]
# The function `rms_normalize` will be applied to **each segment** aftey they are created and before they are exported to the save directories defined.

# %%
def rms_normalize(y, eps=1e-9, min_rms=1e-3):
    rms = np.sqrt(np.mean(y**2) + eps)
    if rms < min_rms:
        return y  # avoid boosting silence
    return y / rms

# %% [markdown]
# ##### Augmentation

# %%
def augment_noise(y, sr=SR):
    return y + np.random.normal(0, 0.005, len(y))

def augment_pitch(y, sr=SR):
    steps = np.random.uniform(-2, 2)
    return lb.effects.pitch_shift(y=y, sr=sr, n_steps=steps)

def augment_speed(y, sr=SR):
    rate = np.random.uniform(0.95, 1.05)
    return lb.effects.time_stretch(y=y, rate=rate)

def augment_gain(y, sr=SR):
    return y * np.random.uniform(0.8, 1.2)



# Python list containing all of the augmentation methods
AUGS = [augment_noise, augment_pitch, augment_speed, augment_gain]

# %% [markdown]
# ### 2. Creating the Reference Data Frame

# %%
# Extracts relevant information from the file name
def get_filename_info(file):
    return file.split("_")

# %%
def read_icbhi_metadata(data_dir):

    audio_dir = os.path.join(data_dir, "audio_and_txt_files") # Where all of the audio files are stored in the ICBHI dataset
    diagnosis_path = os.path.join(data_dir, "patient_diagnosis.csv") # The CSV file that maps the PID to a disease within the dataset

    # Read patient diagnoses
    patient_df = pd.read_csv(diagnosis_path, names=["pid", "disease"])
    patient_df.pid = patient_df.pid.astype(int) # DF that holds PID and associated Disease

    # Read all annotation txt files
    txt_files = sorted([f for f in os.listdir(audio_dir) if f.endswith(".txt")]) # All of the annotiation files associated with the recordings

    rows = []

    # Iterate through all of the audio file annotations and create a datafram that stores all of the data. 
    # It gets the start, end, crackles, and wheezes annotations from the .txt files 
    #   and the PID from the filename itself and the actual filename too.
    for txt in txt_files:
        file = txt.replace(".txt", "")
        metadata = pd.read_csv(
            os.path.join(audio_dir, txt),
            sep="\t",
            names=["start", "end", "crackles", "wheezes"]
        )
        pid = int(get_filename_info(file)[0]) #  Gets only the first part of the filename which is the PID

        metadata["filename"] = file
        metadata["pid"] = pid

        rows.append(metadata)

    # Combine all annotations
    df = pd.concat(rows)

    # We carry out a merge of the two dataframes using the patient ID so we can have one giant dataframe with all of the necessary information
    df = df.merge(patient_df, on="pid")


    print("The total number of patients within the dataset is exactly", patient_df['pid'].count())
    print("The total number of segments of data within the entire dataset amounts to", df['pid'].count())
    print("After carrying out the join, the total number of segments of data within the entire dataset amounts to", df['pid'].count())


    # We drop disease classes with fewer than 3 unique patients
    counts = df.groupby('disease')['pid'].nunique()
    rare_classes = counts[counts < 3].index.tolist()
    if rare_classes:
        print(f"\nDropping the following rare disease classes with < 3 patients: {rare_classes}")
        df_dropped = df[~df['disease'].isin(rare_classes)].copy()
    else: 
        df_dropped = df['disease']

    
    print("\nThese rare classes have the following number of patients:")
    print(counts[rare_classes])

    print("\nThe Total number of segments that are found among these rare classes amounts to:", df[df['disease'].isin(rare_classes)]['pid'].count())

    print("\nThen, the revised total number of segments after dropping the segments of these rare classes amounts to", df_dropped['pid'].count())

    # We reset the index because of the entries we dropped. We don't want the jumps evident in the dataset because they become confusing later on
    df_dropped = df_dropped.reset_index(drop=True)
    return df_dropped


df = read_icbhi_metadata(RAW_DATA_DIR)
os.makedirs("outputs", exist_ok=True)
df.to_csv("outputs/df_with_rare_classes_dropped.csv")
# Out:
# The total number of patients within the dataset is exactly 126
# The total number of segments of data within the entire dataset amounts to 6898
# After carrying out the join, the total number of segments of data within the entire dataset amounts to 6898
#
# Dropping the following rare disease classes with < 3 patients: ['Asthma', 'LRTI']
#
# These rare classes have the following number of patients:
# disease
# Asthma    1
# LRTI      2
# Name: pid, dtype: int64
#
# The Total number of segments that are found among these rare classes amounts to: 38
#
# Then, the revised total number of segments after dropping the segments of these rare classes amounts to 6860

# %% [markdown]
# ### Segmentation

# %%
def load_audio(file_path, sr=SR): # Loads the audio file following the global parameter SAMPLING RATE
    y, sr = lb.load(file_path, sr=sr)
    y = y.astype(np.float32)

    # Butterworth bandpass filter
    y = butterworth_filter(
        y,
        sr,
        lowcut=50,     # remove heart sounds & DC
        highcut=1800,  # remove high-frequency noise
        order=4
    )

    return np.clip(y, -1, 1), sr

# %%
def extract_segments(df, data_dir, save_dir, segment_folder):
    audio_dir = os.path.join(data_dir, "audio_and_txt_files")

    seg_folder =os.path.join(save_dir, segment_folder)

    shutil.rmtree(seg_folder, ignore_errors=True)
    os.makedirs(seg_folder)

    segment_list = []
    for row_idx, row in tqdm(df.iterrows(), total=len(df)):

        file = row["filename"]
        start = row["start"]
        end = row["end"]

        # Load the audiofile
        wav_path = os.path.join(audio_dir, file + ".wav")
        y, sr = load_audio(wav_path) # Filtering is applied within the function

        # Compute the exact sample where the audio clip will start and end using the sampling rate.
        s = int(start * SR)
        e = int(end * SR)
        s = max(0, min(s, len(y)))
        e = max(0, min(e, len(y)))

        if e <= s:
            print("Invalid segment window:", file, start, end)

        relevant_region = y[s:e]

        # TIME period in sample will follow the configured SEG_LEN
        seg_samples = SEG_LEN * SR

        # The seg_samples - 1 is add onto the length.
        # This ensures remainders round up instead of down
        n_segments = (len(relevant_region) + seg_samples - 1) // seg_samples

        for i in range(n_segments):
            seg = relevant_region[i * seg_samples:(i + 1) * seg_samples]

            if len(seg) < seg_samples:
                seg = np.pad(seg, (0, seg_samples - len(seg)), mode="constant")

            
            seg = rms_normalize(seg) # Apply RMS normalization
            
            seg_name = f"{file}_r-{row_idx}_s-{i}.wav"
            seg_path = os.path.join(seg_folder, seg_name)
            sf.write(seg_path, seg, SR)

            segment_list.append({
                "segment_file": seg_name,
                "pid": row["pid"],
                "disease": row["disease"],
                "start": start,
                "end": end, 
            })

    return pd.DataFrame(segment_list)

segments = extract_segments(df, RAW_DATA_DIR, SEGMENTS_DIR, "segments")

os.makedirs("outputs/segmentation_outputs", exist_ok=True)
segments.to_csv("outputs/segmentation_outputs/segments.csv")

#Outputs only for validation purposes
print("\nsegments count: ", segments['pid'].count())
# Out:
# 100%|██████████| 6860/6860 [00:51<00:00, 133.71it/s]
# segments count:  6980

# %%
# Read segments data
seg_df = pd.read_csv("outputs/segmentation_outputs/segments.csv")

# Count segments per disease
disease_counts = seg_df['disease'].value_counts()

# Create the bar chart
plt.figure(figsize=(12, 6))
bars = plt.bar(disease_counts.index, disease_counts.values, 
               color=['skyblue', 'lightcoral', 'lightgreen', 'orange', 'purple', 'brown', 'gray'])

# Add value labels on bars
for bar, count in zip(bars, disease_counts.values):
    plt.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 5, 
             f'{count:,}', ha='center', va='bottom', fontweight='bold')

plt.title('Number of Audio Segments per Disease Class', fontsize=14, fontweight='bold')
plt.xlabel('Disease Class', fontsize=12)
plt.ylabel('Number of Segments', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', alpha=0.3)

# Add some padding to top for labels
plt.ylim(0, disease_counts.max() * 1.1)

plt.tight_layout()
plt.show()

# Print the counts
print("Segment counts per disease:")
print(disease_counts)
# Out:
# Segment counts per disease:
# disease
# COPD              5852
# Healthy            328
# Pneumonia          286
# URTI               246
# Bronchiolitis      160
# Bronchiectasis     108
# Name: count, dtype: int64

# %% [markdown]
# ### Augmentation

# %%
def augment(
    seg_df,
    source_dir,
    save_dir,
    pdName,
    target_count=500,
    seed=42
):
    rng = random.Random(seed)
    np_rng = np.random.default_rng(seed)

    updated_records = []

    # Reset output directory
    shutil.rmtree(save_dir, ignore_errors=True)
    os.makedirs(save_dir, exist_ok=False)

    for disease, group in seg_df.groupby("disease"):
        print(f"\nProcessing disease class: {disease}")

        originals = group["segment_file"].tolist()
        pids = group["pid"].tolist()
        files_with_pid = list(zip(originals, pids))

        # --------------------------------------------------
        # STEP 1: HARD CAP (Undersample if > 1000)
        # --------------------------------------------------
        if len(files_with_pid) > target_count:
            files_with_pid = rng.sample(files_with_pid, target_count)
            print(f"\tUndersampled to {target_count}")

        current_count = len(files_with_pid)
        print(f"\tCurrent count after cap: {current_count}")

        # --------------------------------------------------
        # STEP 2: COPY ORIGINAL FILES
        # --------------------------------------------------
        for file, pid in files_with_pid:
            base_file = os.path.basename(file)
            src_path = os.path.join(source_dir, base_file)
            dest_path = os.path.join(save_dir, base_file)

            if not os.path.exists(src_path):
                raise FileNotFoundError(f"Missing file: {src_path}")

            shutil.copy(src_path, dest_path)

            updated_records.append({
                "segment_file": base_file,
                "pid": pid,
                "disease": disease,
            })

        # # --------------------------------------------------
        # # STEP 3: AUGMENT UNTIL 500
        # # --------------------------------------------------
        needed = target_count - current_count

        if needed > 0:
            print(f"\tAugmenting {needed} samples...")

        aug_index = 1

        for _ in range(needed):
            f, pid = rng.choice(files_with_pid)

            src_path = os.path.join(source_dir, os.path.basename(f))
            y, sr = lb.load(src_path, sr=SR)

            # Choose random augmentation
            aug_fn = np_rng.choice(AUGS)
            y_aug = aug_fn(y, sr)

            base = os.path.splitext(os.path.basename(f))[0]
            save_name = f"{base}_aug-{disease}-{aug_index}.wav"
            save_path = os.path.join(save_dir, save_name)
            print(save_name, " writing to: ", save_path)

            sf.write(save_path, y_aug, sr)

            updated_records.append({
                "segment_file": save_name,
                "pid": pid,
                "disease": disease,
            })

            aug_index += 1

        print(f"\tFinal count: {target_count}")

    df_final = pd.DataFrame(updated_records)
    df_final.to_csv(f"outputs/augmentation_outputs/{pdName}.csv", index=False)

    return df_final
  
train_augmented = augment(segments, 
    os.path.join(ROOT_DIR, SEGMENTS_DIR, "segments"),
    os.path.join(ROOT_DIR, SEGMENTS_AUGMENTED_DIR),
    "segments"
)
# Out:
# Processing disease class: Bronchiectasis
# 	Current count after cap: 108
# 	Augmenting 392 samples...
# 201_1b2_Ar_sc_Meditron_r-5597_s-0_aug-Bronchiectasis-1.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b2_Ar_sc_Meditron_r-5597_s-0_aug-Bronchiectasis-1.wav
# 111_1b3_Tc_sc_Meditron_r-475_s-0_aug-Bronchiectasis-2.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/111_1b3_Tc_sc_Meditron_r-475_s-0_aug-Bronchiectasis-2.wav
# 111_1b2_Tc_sc_Meditron_r-464_s-0_aug-Bronchiectasis-3.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/111_1b2_Tc_sc_Meditron_r-464_s-0_aug-Bronchiectasis-3.wav
# 201_1b3_Ar_sc_Meditron_r-5610_s-0_aug-Bronchiectasis-4.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b3_Ar_sc_Meditron_r-5610_s-0_aug-Bronchiectasis-4.wav
# 168_1b1_Al_sc_Meditron_r-3773_s-0_aug-Bronchiectasis-5.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/168_1b1_Al_sc_Meditron_r-3773_s-0_aug-Bronchiectasis-5.wav
# 168_1b1_Al_sc_Meditron_r-3769_s-0_aug-Bronchiectasis-6.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/168_1b1_Al_sc_Meditron_r-3769_s-0_aug-Bronchiectasis-6.wav
# 116_1b2_Tc_sc_Meditron_r-627_s-0_aug-Bronchiectasis-7.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/116_1b2_Tc_sc_Meditron_r-627_s-0_aug-Bronchiectasis-7.wav
# 116_1b2_Pl_sc_Meditron_r-620_s-0_aug-Bronchiectasis-8.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/116_1b2_Pl_sc_Meditron_r-620_s-0_aug-Bronchiectasis-8.wav
# 201_1b3_Ar_sc_Meditron_r-5610_s-0_aug-Bronchiectasis-9.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b3_Ar_sc_Meditron_r-5610_s-0_aug-Bronchiectasis-9.wav
# 111_1b3_Tc_sc_Meditron_r-474_s-0_aug-Bronchiectasis-10.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/111_1b3_Tc_sc_Meditron_r-474_s-0_aug-Bronchiectasis-10.wav
# 201_1b3_Al_sc_Meditron_r-5602_s-0_aug-Bronchiectasis-11.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b3_Al_sc_Meditron_r-5602_s-0_aug-Bronchiectasis-11.wav
# 201_1b3_Ar_sc_Meditron_r-5610_s-0_aug-Bronchiectasis-12.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b3_Ar_sc_Meditron_r-5610_s-0_aug-Bronchiectasis-12.wav
# 201_1b1_Ar_sc_Meditron_r-5585_s-0_aug-Bronchiectasis-13.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b1_Ar_sc_Meditron_r-5585_s-0_aug-Bronchiectasis-13.wav
# 111_1b3_Tc_sc_Meditron_r-472_s-0_aug-Bronchiectasis-14.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/111_1b3_Tc_sc_Meditron_r-472_s-0_aug-Bronchiectasis-14.wav
# 201_1b2_Al_sc_Meditron_r-5591_s-0_aug-Bronchiectasis-15.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b2_Al_sc_Meditron_r-5591_s-0_aug-Bronchiectasis-15.wav
# 196_1b1_Pr_sc_Meditron_r-5348_s-0_aug-Bronchiectasis-16.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/196_1b1_Pr_sc_Meditron_r-5348_s-0_aug-Bronchiectasis-16.wav
# 111_1b2_Tc_sc_Meditron_r-465_s-0_aug-Bronchiectasis-17.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/111_1b2_Tc_sc_Meditron_r-465_s-0_aug-Bronchiectasis-17.wav
# 111_1b2_Tc_sc_Meditron_r-464_s-0_aug-Bronchiectasis-18.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/111_1b2_Tc_sc_Meditron_r-464_s-0_aug-Bronchiectasis-18.wav
# 111_1b3_Tc_sc_Meditron_r-472_s-0_aug-Bronchiectasis-19.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/111_1b3_Tc_sc_Meditron_r-472_s-0_aug-Bronchiectasis-19.wav
# 116_1b2_Tc_sc_Meditron_r-626_s-1_aug-Bronchiectasis-20.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/116_1b2_Tc_sc_Meditron_r-626_s-1_aug-Bronchiectasis-20.wav
# 168_1b1_Al_sc_Meditron_r-3767_s-0_aug-Bronchiectasis-21.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/168_1b1_Al_sc_Meditron_r-3767_s-0_aug-Bronchiectasis-21.wav
# 201_1b1_Ar_sc_Meditron_r-5580_s-0_aug-Bronchiectasis-22.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b1_Ar_sc_Meditron_r-5580_s-0_aug-Bronchiectasis-22.wav
# 201_1b2_Ar_sc_Meditron_r-5593_s-0_aug-Bronchiectasis-23.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b2_Ar_sc_Meditron_r-5593_s-0_aug-Bronchiectasis-23.wav
# 111_1b2_Tc_sc_Meditron_r-464_s-0_aug-Bronchiectasis-24.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/111_1b2_Tc_sc_Meditron_r-464_s-0_aug-Bronchiectasis-24.wav
# 201_1b2_Al_sc_Meditron_r-5587_s-0_aug-Bronchiectasis-25.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b2_Al_sc_Meditron_r-5587_s-0_aug-Bronchiectasis-25.wav
# 116_1b2_Tc_sc_Meditron_r-625_s-0_aug-Bronchiectasis-26.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/116_1b2_Tc_sc_Meditron_r-625_s-0_aug-Bronchiectasis-26.wav
# 201_1b3_Ar_sc_Meditron_r-5607_s-0_aug-Bronchiectasis-27.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b3_Ar_sc_Meditron_r-5607_s-0_aug-Bronchiectasis-27.wav
# 201_1b2_Ar_sc_Meditron_r-5599_s-0_aug-Bronchiectasis-28.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b2_Ar_sc_Meditron_r-5599_s-0_aug-Bronchiectasis-28.wav
# 201_1b3_Al_sc_Meditron_r-5605_s-0_aug-Bronchiectasis-29.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b3_Al_sc_Meditron_r-5605_s-0_aug-Bronchiectasis-29.wav
# 201_1b1_Ar_sc_Meditron_r-5585_s-0_aug-Bronchiectasis-30.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b1_Ar_sc_Meditron_r-5585_s-0_aug-Bronchiectasis-30.wav
# 196_1b1_Pr_sc_Meditron_r-5347_s-0_aug-Bronchiectasis-31.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/196_1b1_Pr_sc_Meditron_r-5347_s-0_aug-Bronchiectasis-31.wav
# 116_1b2_Tc_sc_Meditron_r-627_s-0_aug-Bronchiectasis-32.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/116_1b2_Tc_sc_Meditron_r-627_s-0_aug-Bronchiectasis-32.wav
# 201_1b1_Al_sc_Meditron_r-5573_s-0_aug-Bronchiectasis-33.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b1_Al_sc_Meditron_r-5573_s-0_aug-Bronchiectasis-33.wav
# 201_1b2_Al_sc_Meditron_r-5591_s-0_aug-Bronchiectasis-34.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b2_Al_sc_Meditron_r-5591_s-0_aug-Bronchiectasis-34.wav
# 168_1b1_Al_sc_Meditron_r-3773_s-0_aug-Bronchiectasis-35.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/168_1b1_Al_sc_Meditron_r-3773_s-0_aug-Bronchiectasis-35.wav
# 215_1b3_Tc_sc_Meditron_r-6447_s-0_aug-Bronchiectasis-36.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/215_1b3_Tc_sc_Meditron_r-6447_s-0_aug-Bronchiectasis-36.wav
# 111_1b2_Tc_sc_Meditron_r-461_s-0_aug-Bronchiectasis-37.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/111_1b2_Tc_sc_Meditron_r-461_s-0_aug-Bronchiectasis-37.wav
# 215_1b2_Ar_sc_Meditron_r-6441_s-0_aug-Bronchiectasis-38.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/215_1b2_Ar_sc_Meditron_r-6441_s-0_aug-Bronchiectasis-38.wav
# 215_1b3_Tc_sc_Meditron_r-6447_s-0_aug-Bronchiectasis-39.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/215_1b3_Tc_sc_Meditron_r-6447_s-0_aug-Bronchiectasis-39.wav
# 116_1b2_Pl_sc_Meditron_r-622_s-0_aug-Bronchiectasis-40.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/116_1b2_Pl_sc_Meditron_r-622_s-0_aug-Bronchiectasis-40.wav
# 201_1b3_Al_sc_Meditron_r-5605_s-0_aug-Bronchiectasis-41.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b3_Al_sc_Meditron_r-5605_s-0_aug-Bronchiectasis-41.wav
# 196_1b1_Pr_sc_Meditron_r-5348_s-0_aug-Bronchiectasis-42.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/196_1b1_Pr_sc_Meditron_r-5348_s-0_aug-Bronchiectasis-42.wav
# 169_1b2_Ll_sc_Meditron_r-3781_s-0_aug-Bronchiectasis-43.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/169_1b2_Ll_sc_Meditron_r-3781_s-0_aug-Bronchiectasis-43.wav
# 168_1b1_Al_sc_Meditron_r-3773_s-0_aug-Bronchiectasis-44.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/168_1b1_Al_sc_Meditron_r-3773_s-0_aug-Bronchiectasis-44.wav
# 116_1b2_Pl_sc_Meditron_r-621_s-1_aug-Bronchiectasis-45.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/116_1b2_Pl_sc_Meditron_r-621_s-1_aug-Bronchiectasis-45.wav
# 116_1b2_Tc_sc_Meditron_r-626_s-1_aug-Bronchiectasis-46.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/116_1b2_Tc_sc_Meditron_r-626_s-1_aug-Bronchiectasis-46.wav
# 215_1b2_Ar_sc_Meditron_r-6441_s-0_aug-Bronchiectasis-47.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/215_1b2_Ar_sc_Meditron_r-6441_s-0_aug-Bronchiectasis-47.wav
# 169_1b2_Ll_sc_Meditron_r-3781_s-0_aug-Bronchiectasis-48.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/169_1b2_Ll_sc_Meditron_r-3781_s-0_aug-Bronchiectasis-48.wav
# 111_1b3_Tc_sc_Meditron_r-474_s-0_aug-Bronchiectasis-49.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/111_1b3_Tc_sc_Meditron_r-474_s-0_aug-Bronchiectasis-49.wav
# 111_1b3_Tc_sc_Meditron_r-472_s-0_aug-Bronchiectasis-50.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/111_1b3_Tc_sc_Meditron_r-472_s-0_aug-Bronchiectasis-50.wav
# 169_1b2_Ll_sc_Meditron_r-3786_s-0_aug-Bronchiectasis-51.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/169_1b2_Ll_sc_Meditron_r-3786_s-0_aug-Bronchiectasis-51.wav
# 111_1b3_Tc_sc_Meditron_r-473_s-0_aug-Bronchiectasis-52.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/111_1b3_Tc_sc_Meditron_r-473_s-0_aug-Bronchiectasis-52.wav
# 169_1b2_Ll_sc_Meditron_r-3783_s-0_aug-Bronchiectasis-53.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/169_1b2_Ll_sc_Meditron_r-3783_s-0_aug-Bronchiectasis-53.wav
# 169_1b2_Ll_sc_Meditron_r-3782_s-0_aug-Bronchiectasis-54.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/169_1b2_Ll_sc_Meditron_r-3782_s-0_aug-Bronchiectasis-54.wav
# 201_1b2_Ar_sc_Meditron_r-5593_s-0_aug-Bronchiectasis-55.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b2_Ar_sc_Meditron_r-5593_s-0_aug-Bronchiectasis-55.wav
# 168_1b1_Al_sc_Meditron_r-3771_s-0_aug-Bronchiectasis-56.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/168_1b1_Al_sc_Meditron_r-3771_s-0_aug-Bronchiectasis-56.wav
# 215_1b3_Tc_sc_Meditron_r-6447_s-0_aug-Bronchiectasis-57.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/215_1b3_Tc_sc_Meditron_r-6447_s-0_aug-Bronchiectasis-57.wav
# 111_1b2_Tc_sc_Meditron_r-466_s-0_aug-Bronchiectasis-58.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/111_1b2_Tc_sc_Meditron_r-466_s-0_aug-Bronchiectasis-58.wav
# 201_1b3_Ar_sc_Meditron_r-5609_s-0_aug-Bronchiectasis-59.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b3_Ar_sc_Meditron_r-5609_s-0_aug-Bronchiectasis-59.wav
# 201_1b1_Al_sc_Meditron_r-5574_s-0_aug-Bronchiectasis-60.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b1_Al_sc_Meditron_r-5574_s-0_aug-Bronchiectasis-60.wav
# 201_1b1_Ar_sc_Meditron_r-5584_s-0_aug-Bronchiectasis-61.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b1_Ar_sc_Meditron_r-5584_s-0_aug-Bronchiectasis-61.wav
# 111_1b3_Tc_sc_Meditron_r-476_s-0_aug-Bronchiectasis-62.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/111_1b3_Tc_sc_Meditron_r-476_s-0_aug-Bronchiectasis-62.wav
# 169_1b2_Ll_sc_Meditron_r-3786_s-0_aug-Bronchiectasis-63.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/169_1b2_Ll_sc_Meditron_r-3786_s-0_aug-Bronchiectasis-63.wav
# 111_1b3_Tc_sc_Meditron_r-471_s-0_aug-Bronchiectasis-64.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/111_1b3_Tc_sc_Meditron_r-471_s-0_aug-Bronchiectasis-64.wav
# 201_1b2_Al_sc_Meditron_r-5586_s-0_aug-Bronchiectasis-65.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b2_Al_sc_Meditron_r-5586_s-0_aug-Bronchiectasis-65.wav
# 169_1b1_Lr_sc_Meditron_r-3775_s-0_aug-Bronchiectasis-66.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/169_1b1_Lr_sc_Meditron_r-3775_s-0_aug-Bronchiectasis-66.wav
# 215_1b3_Tc_sc_Meditron_r-6450_s-0_aug-Bronchiectasis-67.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/215_1b3_Tc_sc_Meditron_r-6450_s-0_aug-Bronchiectasis-67.wav
# 201_1b2_Ar_sc_Meditron_r-5596_s-0_aug-Bronchiectasis-68.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b2_Ar_sc_Meditron_r-5596_s-0_aug-Bronchiectasis-68.wav
# 201_1b2_Ar_sc_Meditron_r-5595_s-0_aug-Bronchiectasis-69.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b2_Ar_sc_Meditron_r-5595_s-0_aug-Bronchiectasis-69.wav
# 169_1b2_Ll_sc_Meditron_r-3784_s-0_aug-Bronchiectasis-70.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/169_1b2_Ll_sc_Meditron_r-3784_s-0_aug-Bronchiectasis-70.wav
# 201_1b2_Al_sc_Meditron_r-5589_s-0_aug-Bronchiectasis-71.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b2_Al_sc_Meditron_r-5589_s-0_aug-Bronchiectasis-71.wav
# 116_1b2_Tc_sc_Meditron_r-624_s-1_aug-Bronchiectasis-72.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/116_1b2_Tc_sc_Meditron_r-624_s-1_aug-Bronchiectasis-72.wav
# 201_1b3_Ar_sc_Meditron_r-5606_s-0_aug-Bronchiectasis-73.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b3_Ar_sc_Meditron_r-5606_s-0_aug-Bronchiectasis-73.wav
# 111_1b3_Tc_sc_Meditron_r-469_s-0_aug-Bronchiectasis-74.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/111_1b3_Tc_sc_Meditron_r-469_s-0_aug-Bronchiectasis-74.wav
# 111_1b2_Tc_sc_Meditron_r-466_s-0_aug-Bronchiectasis-75.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/111_1b2_Tc_sc_Meditron_r-466_s-0_aug-Bronchiectasis-75.wav
# 201_1b3_Al_sc_Meditron_r-5600_s-0_aug-Bronchiectasis-76.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b3_Al_sc_Meditron_r-5600_s-0_aug-Bronchiectasis-76.wav
# 168_1b1_Al_sc_Meditron_r-3767_s-0_aug-Bronchiectasis-77.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/168_1b1_Al_sc_Meditron_r-3767_s-0_aug-Bronchiectasis-77.wav
# 215_1b2_Ar_sc_Meditron_r-6442_s-0_aug-Bronchiectasis-78.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/215_1b2_Ar_sc_Meditron_r-6442_s-0_aug-Bronchiectasis-78.wav
# 169_1b1_Lr_sc_Meditron_r-3775_s-0_aug-Bronchiectasis-79.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/169_1b1_Lr_sc_Meditron_r-3775_s-0_aug-Bronchiectasis-79.wav
# 111_1b3_Tc_sc_Meditron_r-471_s-0_aug-Bronchiectasis-80.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/111_1b3_Tc_sc_Meditron_r-471_s-0_aug-Bronchiectasis-80.wav
# 168_1b1_Al_sc_Meditron_r-3767_s-0_aug-Bronchiectasis-81.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/168_1b1_Al_sc_Meditron_r-3767_s-0_aug-Bronchiectasis-81.wav
# 111_1b3_Tc_sc_Meditron_r-473_s-0_aug-Bronchiectasis-82.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/111_1b3_Tc_sc_Meditron_r-473_s-0_aug-Bronchiectasis-82.wav
# 169_1b2_Ll_sc_Meditron_r-3786_s-0_aug-Bronchiectasis-83.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/169_1b2_Ll_sc_Meditron_r-3786_s-0_aug-Bronchiectasis-83.wav
# 168_1b1_Al_sc_Meditron_r-3773_s-0_aug-Bronchiectasis-84.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/168_1b1_Al_sc_Meditron_r-3773_s-0_aug-Bronchiectasis-84.wav
# 201_1b1_Al_sc_Meditron_r-5574_s-0_aug-Bronchiectasis-85.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b1_Al_sc_Meditron_r-5574_s-0_aug-Bronchiectasis-85.wav
# 201_1b2_Ar_sc_Meditron_r-5597_s-0_aug-Bronchiectasis-86.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b2_Ar_sc_Meditron_r-5597_s-0_aug-Bronchiectasis-86.wav
# 215_1b3_Tc_sc_Meditron_r-6450_s-0_aug-Bronchiectasis-87.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/215_1b3_Tc_sc_Meditron_r-6450_s-0_aug-Bronchiectasis-87.wav
# 169_1b2_Ll_sc_Meditron_r-3784_s-0_aug-Bronchiectasis-88.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/169_1b2_Ll_sc_Meditron_r-3784_s-0_aug-Bronchiectasis-88.wav
# 116_1b2_Pl_sc_Meditron_r-622_s-0_aug-Bronchiectasis-89.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/116_1b2_Pl_sc_Meditron_r-622_s-0_aug-Bronchiectasis-89.wav
# 169_1b2_Ll_sc_Meditron_r-3785_s-0_aug-Bronchiectasis-90.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/169_1b2_Ll_sc_Meditron_r-3785_s-0_aug-Bronchiectasis-90.wav
# 169_1b2_Ll_sc_Meditron_r-3783_s-0_aug-Bronchiectasis-91.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/169_1b2_Ll_sc_Meditron_r-3783_s-0_aug-Bronchiectasis-91.wav
# 116_1b2_Tc_sc_Meditron_r-626_s-0_aug-Bronchiectasis-92.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/116_1b2_Tc_sc_Meditron_r-626_s-0_aug-Bronchiectasis-92.wav
# 201_1b3_Al_sc_Meditron_r-5601_s-0_aug-Bronchiectasis-93.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b3_Al_sc_Meditron_r-5601_s-0_aug-Bronchiectasis-93.wav
# 168_1b1_Al_sc_Meditron_r-3772_s-0_aug-Bronchiectasis-94.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/168_1b1_Al_sc_Meditron_r-3772_s-0_aug-Bronchiectasis-94.wav
# 201_1b3_Al_sc_Meditron_r-5605_s-0_aug-Bronchiectasis-95.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b3_Al_sc_Meditron_r-5605_s-0_aug-Bronchiectasis-95.wav
# 201_1b3_Al_sc_Meditron_r-5603_s-0_aug-Bronchiectasis-96.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b3_Al_sc_Meditron_r-5603_s-0_aug-Bronchiectasis-96.wav
# 201_1b2_Ar_sc_Meditron_r-5598_s-0_aug-Bronchiectasis-97.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b2_Ar_sc_Meditron_r-5598_s-0_aug-Bronchiectasis-97.wav
# 111_1b3_Tc_sc_Meditron_r-470_s-0_aug-Bronchiectasis-98.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/111_1b3_Tc_sc_Meditron_r-470_s-0_aug-Bronchiectasis-98.wav
# 201_1b2_Ar_sc_Meditron_r-5593_s-0_aug-Bronchiectasis-99.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b2_Ar_sc_Meditron_r-5593_s-0_aug-Bronchiectasis-99.wav
# 201_1b2_Ar_sc_Meditron_r-5597_s-0_aug-Bronchiectasis-100.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b2_Ar_sc_Meditron_r-5597_s-0_aug-Bronchiectasis-100.wav
# 116_1b2_Pl_sc_Meditron_r-622_s-1_aug-Bronchiectasis-101.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/116_1b2_Pl_sc_Meditron_r-622_s-1_aug-Bronchiectasis-101.wav
# 201_1b1_Ar_sc_Meditron_r-5584_s-0_aug-Bronchiectasis-102.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b1_Ar_sc_Meditron_r-5584_s-0_aug-Bronchiectasis-102.wav
# 201_1b3_Ar_sc_Meditron_r-5609_s-0_aug-Bronchiectasis-103.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b3_Ar_sc_Meditron_r-5609_s-0_aug-Bronchiectasis-103.wav
# 168_1b1_Al_sc_Meditron_r-3769_s-0_aug-Bronchiectasis-104.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/168_1b1_Al_sc_Meditron_r-3769_s-0_aug-Bronchiectasis-104.wav
# 116_1b2_Pl_sc_Meditron_r-622_s-0_aug-Bronchiectasis-105.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/116_1b2_Pl_sc_Meditron_r-622_s-0_aug-Bronchiectasis-105.wav
# 201_1b1_Al_sc_Meditron_r-5575_s-0_aug-Bronchiectasis-106.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b1_Al_sc_Meditron_r-5575_s-0_aug-Bronchiectasis-106.wav
# 169_1b2_Ll_sc_Meditron_r-3786_s-0_aug-Bronchiectasis-107.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/169_1b2_Ll_sc_Meditron_r-3786_s-0_aug-Bronchiectasis-107.wav
# 168_1b1_Al_sc_Meditron_r-3772_s-0_aug-Bronchiectasis-108.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/168_1b1_Al_sc_Meditron_r-3772_s-0_aug-Bronchiectasis-108.wav
# 201_1b2_Ar_sc_Meditron_r-5597_s-0_aug-Bronchiectasis-109.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b2_Ar_sc_Meditron_r-5597_s-0_aug-Bronchiectasis-109.wav
# 201_1b3_Al_sc_Meditron_r-5604_s-0_aug-Bronchiectasis-110.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b3_Al_sc_Meditron_r-5604_s-0_aug-Bronchiectasis-110.wav
# 201_1b2_Al_sc_Meditron_r-5587_s-0_aug-Bronchiectasis-111.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b2_Al_sc_Meditron_r-5587_s-0_aug-Bronchiectasis-111.wav
# 116_1b2_Tc_sc_Meditron_r-627_s-0_aug-Bronchiectasis-112.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/116_1b2_Tc_sc_Meditron_r-627_s-0_aug-Bronchiectasis-112.wav
# 201_1b3_Al_sc_Meditron_r-5603_s-0_aug-Bronchiectasis-113.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b3_Al_sc_Meditron_r-5603_s-0_aug-Bronchiectasis-113.wav
# 169_1b1_Lr_sc_Meditron_r-3779_s-0_aug-Bronchiectasis-114.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/169_1b1_Lr_sc_Meditron_r-3779_s-0_aug-Bronchiectasis-114.wav
# 215_1b3_Tc_sc_Meditron_r-6451_s-0_aug-Bronchiectasis-115.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/215_1b3_Tc_sc_Meditron_r-6451_s-0_aug-Bronchiectasis-115.wav
# 215_1b2_Ar_sc_Meditron_r-6442_s-0_aug-Bronchiectasis-116.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/215_1b2_Ar_sc_Meditron_r-6442_s-0_aug-Bronchiectasis-116.wav
# 215_1b2_Ar_sc_Meditron_r-6443_s-0_aug-Bronchiectasis-117.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/215_1b2_Ar_sc_Meditron_r-6443_s-0_aug-Bronchiectasis-117.wav
# 111_1b2_Tc_sc_Meditron_r-468_s-0_aug-Bronchiectasis-118.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/111_1b2_Tc_sc_Meditron_r-468_s-0_aug-Bronchiectasis-118.wav
# 168_1b1_Al_sc_Meditron_r-3767_s-0_aug-Bronchiectasis-119.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/168_1b1_Al_sc_Meditron_r-3767_s-0_aug-Bronchiectasis-119.wav
# 215_1b3_Tc_sc_Meditron_r-6449_s-0_aug-Bronchiectasis-120.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/215_1b3_Tc_sc_Meditron_r-6449_s-0_aug-Bronchiectasis-120.wav
# 111_1b2_Tc_sc_Meditron_r-465_s-0_aug-Bronchiectasis-121.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/111_1b2_Tc_sc_Meditron_r-465_s-0_aug-Bronchiectasis-121.wav
# 215_1b3_Tc_sc_Meditron_r-6447_s-0_aug-Bronchiectasis-122.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/215_1b3_Tc_sc_Meditron_r-6447_s-0_aug-Bronchiectasis-122.wav
# 169_1b1_Lr_sc_Meditron_r-3778_s-0_aug-Bronchiectasis-123.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/169_1b1_Lr_sc_Meditron_r-3778_s-0_aug-Bronchiectasis-123.wav
# 196_1b1_Pr_sc_Meditron_r-5345_s-0_aug-Bronchiectasis-124.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/196_1b1_Pr_sc_Meditron_r-5345_s-0_aug-Bronchiectasis-124.wav
# 168_1b1_Al_sc_Meditron_r-3772_s-0_aug-Bronchiectasis-125.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/168_1b1_Al_sc_Meditron_r-3772_s-0_aug-Bronchiectasis-125.wav
# 111_1b3_Tc_sc_Meditron_r-469_s-0_aug-Bronchiectasis-126.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/111_1b3_Tc_sc_Meditron_r-469_s-0_aug-Bronchiectasis-126.wav
# 116_1b2_Tc_sc_Meditron_r-626_s-1_aug-Bronchiectasis-127.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/116_1b2_Tc_sc_Meditron_r-626_s-1_aug-Bronchiectasis-127.wav
# 201_1b2_Al_sc_Meditron_r-5588_s-0_aug-Bronchiectasis-128.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b2_Al_sc_Meditron_r-5588_s-0_aug-Bronchiectasis-128.wav
# 201_1b3_Ar_sc_Meditron_r-5607_s-0_aug-Bronchiectasis-129.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b3_Ar_sc_Meditron_r-5607_s-0_aug-Bronchiectasis-129.wav
# 169_1b1_Lr_sc_Meditron_r-3778_s-0_aug-Bronchiectasis-130.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/169_1b1_Lr_sc_Meditron_r-3778_s-0_aug-Bronchiectasis-130.wav
# 116_1b2_Tc_sc_Meditron_r-626_s-1_aug-Bronchiectasis-131.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/116_1b2_Tc_sc_Meditron_r-626_s-1_aug-Bronchiectasis-131.wav
# 201_1b2_Ar_sc_Meditron_r-5599_s-0_aug-Bronchiectasis-132.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b2_Ar_sc_Meditron_r-5599_s-0_aug-Bronchiectasis-132.wav
# 201_1b1_Ar_sc_Meditron_r-5579_s-0_aug-Bronchiectasis-133.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b1_Ar_sc_Meditron_r-5579_s-0_aug-Bronchiectasis-133.wav
# 196_1b1_Pr_sc_Meditron_r-5344_s-0_aug-Bronchiectasis-134.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/196_1b1_Pr_sc_Meditron_r-5344_s-0_aug-Bronchiectasis-134.wav
# 201_1b2_Ar_sc_Meditron_r-5598_s-0_aug-Bronchiectasis-135.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b2_Ar_sc_Meditron_r-5598_s-0_aug-Bronchiectasis-135.wav
# 201_1b1_Al_sc_Meditron_r-5574_s-0_aug-Bronchiectasis-136.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b1_Al_sc_Meditron_r-5574_s-0_aug-Bronchiectasis-136.wav
# 116_1b2_Pl_sc_Meditron_r-621_s-0_aug-Bronchiectasis-137.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/116_1b2_Pl_sc_Meditron_r-621_s-0_aug-Bronchiectasis-137.wav
# 168_1b1_Al_sc_Meditron_r-3771_s-0_aug-Bronchiectasis-138.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/168_1b1_Al_sc_Meditron_r-3771_s-0_aug-Bronchiectasis-138.wav
# 116_1b2_Pl_sc_Meditron_r-620_s-0_aug-Bronchiectasis-139.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/116_1b2_Pl_sc_Meditron_r-620_s-0_aug-Bronchiectasis-139.wav
# 168_1b1_Al_sc_Meditron_r-3769_s-0_aug-Bronchiectasis-140.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/168_1b1_Al_sc_Meditron_r-3769_s-0_aug-Bronchiectasis-140.wav
# 201_1b3_Ar_sc_Meditron_r-5611_s-0_aug-Bronchiectasis-141.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b3_Ar_sc_Meditron_r-5611_s-0_aug-Bronchiectasis-141.wav
# 201_1b2_Al_sc_Meditron_r-5587_s-0_aug-Bronchiectasis-142.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b2_Al_sc_Meditron_r-5587_s-0_aug-Bronchiectasis-142.wav
# 201_1b1_Ar_sc_Meditron_r-5584_s-0_aug-Bronchiectasis-143.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b1_Ar_sc_Meditron_r-5584_s-0_aug-Bronchiectasis-143.wav
# 168_1b1_Al_sc_Meditron_r-3771_s-0_aug-Bronchiectasis-144.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/168_1b1_Al_sc_Meditron_r-3771_s-0_aug-Bronchiectasis-144.wav
# 201_1b3_Ar_sc_Meditron_r-5611_s-0_aug-Bronchiectasis-145.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b3_Ar_sc_Meditron_r-5611_s-0_aug-Bronchiectasis-145.wav
# 201_1b2_Al_sc_Meditron_r-5590_s-0_aug-Bronchiectasis-146.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b2_Al_sc_Meditron_r-5590_s-0_aug-Bronchiectasis-146.wav
# 196_1b1_Pr_sc_Meditron_r-5348_s-0_aug-Bronchiectasis-147.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/196_1b1_Pr_sc_Meditron_r-5348_s-0_aug-Bronchiectasis-147.wav
# 201_1b2_Al_sc_Meditron_r-5590_s-0_aug-Bronchiectasis-148.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b2_Al_sc_Meditron_r-5590_s-0_aug-Bronchiectasis-148.wav
# 196_1b1_Pr_sc_Meditron_r-5345_s-0_aug-Bronchiectasis-149.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/196_1b1_Pr_sc_Meditron_r-5345_s-0_aug-Bronchiectasis-149.wav
# 169_1b2_Ll_sc_Meditron_r-3784_s-0_aug-Bronchiectasis-150.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/169_1b2_Ll_sc_Meditron_r-3784_s-0_aug-Bronchiectasis-150.wav
# 116_1b2_Tc_sc_Meditron_r-627_s-0_aug-Bronchiectasis-151.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/116_1b2_Tc_sc_Meditron_r-627_s-0_aug-Bronchiectasis-151.wav
# 116_1b2_Pl_sc_Meditron_r-620_s-0_aug-Bronchiectasis-152.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/116_1b2_Pl_sc_Meditron_r-620_s-0_aug-Bronchiectasis-152.wav
# 201_1b1_Ar_sc_Meditron_r-5581_s-0_aug-Bronchiectasis-153.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b1_Ar_sc_Meditron_r-5581_s-0_aug-Bronchiectasis-153.wav
# 201_1b1_Ar_sc_Meditron_r-5579_s-0_aug-Bronchiectasis-154.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b1_Ar_sc_Meditron_r-5579_s-0_aug-Bronchiectasis-154.wav
# 111_1b3_Tc_sc_Meditron_r-472_s-0_aug-Bronchiectasis-155.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/111_1b3_Tc_sc_Meditron_r-472_s-0_aug-Bronchiectasis-155.wav
# 201_1b3_Ar_sc_Meditron_r-5612_s-0_aug-Bronchiectasis-156.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b3_Ar_sc_Meditron_r-5612_s-0_aug-Bronchiectasis-156.wav
# 111_1b2_Tc_sc_Meditron_r-467_s-0_aug-Bronchiectasis-157.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/111_1b2_Tc_sc_Meditron_r-467_s-0_aug-Bronchiectasis-157.wav
# 111_1b3_Tc_sc_Meditron_r-475_s-0_aug-Bronchiectasis-158.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/111_1b3_Tc_sc_Meditron_r-475_s-0_aug-Bronchiectasis-158.wav
# 116_1b2_Pl_sc_Meditron_r-621_s-1_aug-Bronchiectasis-159.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/116_1b2_Pl_sc_Meditron_r-621_s-1_aug-Bronchiectasis-159.wav
# 201_1b2_Ar_sc_Meditron_r-5596_s-0_aug-Bronchiectasis-160.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b2_Ar_sc_Meditron_r-5596_s-0_aug-Bronchiectasis-160.wav
# 116_1b2_Pl_sc_Meditron_r-622_s-0_aug-Bronchiectasis-161.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/116_1b2_Pl_sc_Meditron_r-622_s-0_aug-Bronchiectasis-161.wav
# 215_1b2_Ar_sc_Meditron_r-6445_s-0_aug-Bronchiectasis-162.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/215_1b2_Ar_sc_Meditron_r-6445_s-0_aug-Bronchiectasis-162.wav
# 201_1b3_Al_sc_Meditron_r-5603_s-0_aug-Bronchiectasis-163.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b3_Al_sc_Meditron_r-5603_s-0_aug-Bronchiectasis-163.wav
# 196_1b1_Pr_sc_Meditron_r-5348_s-0_aug-Bronchiectasis-164.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/196_1b1_Pr_sc_Meditron_r-5348_s-0_aug-Bronchiectasis-164.wav
# 201_1b2_Al_sc_Meditron_r-5592_s-0_aug-Bronchiectasis-165.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b2_Al_sc_Meditron_r-5592_s-0_aug-Bronchiectasis-165.wav
# 111_1b3_Tc_sc_Meditron_r-469_s-0_aug-Bronchiectasis-166.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/111_1b3_Tc_sc_Meditron_r-469_s-0_aug-Bronchiectasis-166.wav
# 169_1b2_Ll_sc_Meditron_r-3787_s-0_aug-Bronchiectasis-167.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/169_1b2_Ll_sc_Meditron_r-3787_s-0_aug-Bronchiectasis-167.wav
# 169_1b2_Ll_sc_Meditron_r-3786_s-0_aug-Bronchiectasis-168.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/169_1b2_Ll_sc_Meditron_r-3786_s-0_aug-Bronchiectasis-168.wav
# 201_1b2_Al_sc_Meditron_r-5592_s-0_aug-Bronchiectasis-169.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b2_Al_sc_Meditron_r-5592_s-0_aug-Bronchiectasis-169.wav
# 201_1b1_Al_sc_Meditron_r-5575_s-0_aug-Bronchiectasis-170.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b1_Al_sc_Meditron_r-5575_s-0_aug-Bronchiectasis-170.wav
# 201_1b1_Ar_sc_Meditron_r-5583_s-0_aug-Bronchiectasis-171.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b1_Ar_sc_Meditron_r-5583_s-0_aug-Bronchiectasis-171.wav
# 168_1b1_Al_sc_Meditron_r-3770_s-0_aug-Bronchiectasis-172.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/168_1b1_Al_sc_Meditron_r-3770_s-0_aug-Bronchiectasis-172.wav
# 201_1b2_Al_sc_Meditron_r-5586_s-0_aug-Bronchiectasis-173.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b2_Al_sc_Meditron_r-5586_s-0_aug-Bronchiectasis-173.wav
# 111_1b2_Tc_sc_Meditron_r-462_s-0_aug-Bronchiectasis-174.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/111_1b2_Tc_sc_Meditron_r-462_s-0_aug-Bronchiectasis-174.wav
# 201_1b3_Al_sc_Meditron_r-5603_s-0_aug-Bronchiectasis-175.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b3_Al_sc_Meditron_r-5603_s-0_aug-Bronchiectasis-175.wav
# 201_1b3_Ar_sc_Meditron_r-5608_s-0_aug-Bronchiectasis-176.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b3_Ar_sc_Meditron_r-5608_s-0_aug-Bronchiectasis-176.wav
# 111_1b3_Tc_sc_Meditron_r-475_s-0_aug-Bronchiectasis-177.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/111_1b3_Tc_sc_Meditron_r-475_s-0_aug-Bronchiectasis-177.wav
# 201_1b3_Al_sc_Meditron_r-5603_s-0_aug-Bronchiectasis-178.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b3_Al_sc_Meditron_r-5603_s-0_aug-Bronchiectasis-178.wav
# 201_1b1_Ar_sc_Meditron_r-5584_s-0_aug-Bronchiectasis-179.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b1_Ar_sc_Meditron_r-5584_s-0_aug-Bronchiectasis-179.wav
# 201_1b3_Ar_sc_Meditron_r-5612_s-0_aug-Bronchiectasis-180.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b3_Ar_sc_Meditron_r-5612_s-0_aug-Bronchiectasis-180.wav
# 168_1b1_Al_sc_Meditron_r-3772_s-0_aug-Bronchiectasis-181.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/168_1b1_Al_sc_Meditron_r-3772_s-0_aug-Bronchiectasis-181.wav
# 215_1b2_Ar_sc_Meditron_r-6442_s-0_aug-Bronchiectasis-182.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/215_1b2_Ar_sc_Meditron_r-6442_s-0_aug-Bronchiectasis-182.wav
# 201_1b2_Ar_sc_Meditron_r-5598_s-0_aug-Bronchiectasis-183.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b2_Ar_sc_Meditron_r-5598_s-0_aug-Bronchiectasis-183.wav
# 169_1b2_Ll_sc_Meditron_r-3781_s-0_aug-Bronchiectasis-184.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/169_1b2_Ll_sc_Meditron_r-3781_s-0_aug-Bronchiectasis-184.wav
# 111_1b3_Tc_sc_Meditron_r-475_s-0_aug-Bronchiectasis-185.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/111_1b3_Tc_sc_Meditron_r-475_s-0_aug-Bronchiectasis-185.wav
# 169_1b1_Lr_sc_Meditron_r-3775_s-0_aug-Bronchiectasis-186.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/169_1b1_Lr_sc_Meditron_r-3775_s-0_aug-Bronchiectasis-186.wav
# 196_1b1_Pr_sc_Meditron_r-5349_s-0_aug-Bronchiectasis-187.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/196_1b1_Pr_sc_Meditron_r-5349_s-0_aug-Bronchiectasis-187.wav
# 116_1b2_Pl_sc_Meditron_r-622_s-0_aug-Bronchiectasis-188.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/116_1b2_Pl_sc_Meditron_r-622_s-0_aug-Bronchiectasis-188.wav
# 201_1b1_Al_sc_Meditron_r-5574_s-0_aug-Bronchiectasis-189.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b1_Al_sc_Meditron_r-5574_s-0_aug-Bronchiectasis-189.wav
# 111_1b2_Tc_sc_Meditron_r-461_s-0_aug-Bronchiectasis-190.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/111_1b2_Tc_sc_Meditron_r-461_s-0_aug-Bronchiectasis-190.wav
# 201_1b3_Ar_sc_Meditron_r-5608_s-0_aug-Bronchiectasis-191.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b3_Ar_sc_Meditron_r-5608_s-0_aug-Bronchiectasis-191.wav
# 201_1b3_Ar_sc_Meditron_r-5608_s-0_aug-Bronchiectasis-192.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b3_Ar_sc_Meditron_r-5608_s-0_aug-Bronchiectasis-192.wav
# 168_1b1_Al_sc_Meditron_r-3771_s-0_aug-Bronchiectasis-193.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/168_1b1_Al_sc_Meditron_r-3771_s-0_aug-Bronchiectasis-193.wav
# 201_1b1_Ar_sc_Meditron_r-5580_s-0_aug-Bronchiectasis-194.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b1_Ar_sc_Meditron_r-5580_s-0_aug-Bronchiectasis-194.wav
# 215_1b2_Ar_sc_Meditron_r-6441_s-0_aug-Bronchiectasis-195.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/215_1b2_Ar_sc_Meditron_r-6441_s-0_aug-Bronchiectasis-195.wav
# 116_1b2_Pl_sc_Meditron_r-623_s-0_aug-Bronchiectasis-196.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/116_1b2_Pl_sc_Meditron_r-623_s-0_aug-Bronchiectasis-196.wav
# 201_1b1_Ar_sc_Meditron_r-5580_s-0_aug-Bronchiectasis-197.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b1_Ar_sc_Meditron_r-5580_s-0_aug-Bronchiectasis-197.wav
# 111_1b3_Tc_sc_Meditron_r-474_s-0_aug-Bronchiectasis-198.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/111_1b3_Tc_sc_Meditron_r-474_s-0_aug-Bronchiectasis-198.wav
# 201_1b2_Ar_sc_Meditron_r-5596_s-0_aug-Bronchiectasis-199.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b2_Ar_sc_Meditron_r-5596_s-0_aug-Bronchiectasis-199.wav
# 169_1b1_Lr_sc_Meditron_r-3776_s-0_aug-Bronchiectasis-200.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/169_1b1_Lr_sc_Meditron_r-3776_s-0_aug-Bronchiectasis-200.wav
# 215_1b3_Tc_sc_Meditron_r-6451_s-0_aug-Bronchiectasis-201.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/215_1b3_Tc_sc_Meditron_r-6451_s-0_aug-Bronchiectasis-201.wav
# 201_1b2_Ar_sc_Meditron_r-5597_s-0_aug-Bronchiectasis-202.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b2_Ar_sc_Meditron_r-5597_s-0_aug-Bronchiectasis-202.wav
# 201_1b1_Ar_sc_Meditron_r-5580_s-0_aug-Bronchiectasis-203.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b1_Ar_sc_Meditron_r-5580_s-0_aug-Bronchiectasis-203.wav
# 201_1b2_Ar_sc_Meditron_r-5593_s-0_aug-Bronchiectasis-204.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b2_Ar_sc_Meditron_r-5593_s-0_aug-Bronchiectasis-204.wav
# 116_1b2_Tc_sc_Meditron_r-625_s-0_aug-Bronchiectasis-205.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/116_1b2_Tc_sc_Meditron_r-625_s-0_aug-Bronchiectasis-205.wav
# 116_1b2_Pl_sc_Meditron_r-621_s-1_aug-Bronchiectasis-206.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/116_1b2_Pl_sc_Meditron_r-621_s-1_aug-Bronchiectasis-206.wav
# 169_1b2_Ll_sc_Meditron_r-3785_s-0_aug-Bronchiectasis-207.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/169_1b2_Ll_sc_Meditron_r-3785_s-0_aug-Bronchiectasis-207.wav
# 215_1b2_Ar_sc_Meditron_r-6441_s-0_aug-Bronchiectasis-208.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/215_1b2_Ar_sc_Meditron_r-6441_s-0_aug-Bronchiectasis-208.wav
# 116_1b2_Pl_sc_Meditron_r-622_s-0_aug-Bronchiectasis-209.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/116_1b2_Pl_sc_Meditron_r-622_s-0_aug-Bronchiectasis-209.wav
# 201_1b1_Ar_sc_Meditron_r-5585_s-0_aug-Bronchiectasis-210.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b1_Ar_sc_Meditron_r-5585_s-0_aug-Bronchiectasis-210.wav
# 215_1b2_Ar_sc_Meditron_r-6443_s-0_aug-Bronchiectasis-211.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/215_1b2_Ar_sc_Meditron_r-6443_s-0_aug-Bronchiectasis-211.wav
# 201_1b1_Ar_sc_Meditron_r-5583_s-0_aug-Bronchiectasis-212.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b1_Ar_sc_Meditron_r-5583_s-0_aug-Bronchiectasis-212.wav
# 111_1b2_Tc_sc_Meditron_r-461_s-0_aug-Bronchiectasis-213.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/111_1b2_Tc_sc_Meditron_r-461_s-0_aug-Bronchiectasis-213.wav
# 201_1b2_Al_sc_Meditron_r-5592_s-0_aug-Bronchiectasis-214.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/201_1b2_Al_sc_Meditron_r-5592_s-0_aug-Bronchiectasis-214.wav
# ...
# 210_1b1_Ar_sc_Meditron_r-6175_s-0_aug-URTI-177.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/210_1b1_Ar_sc_Meditron_r-6175_s-0_aug-URTI-177.wav
# 150_1b2_Al_sc_Meditron_r-2444_s-0_aug-URTI-178.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/150_1b2_Al_sc_Meditron_r-2444_s-0_aug-URTI-178.wav
# 148_1b1_Al_sc_Meditron_r-2383_s-0_aug-URTI-179.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/148_1b1_Al_sc_Meditron_r-2383_s-0_aug-URTI-179.wav
# 188_1b1_Ar_sc_Meditron_r-5001_s-0_aug-URTI-180.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/188_1b1_Ar_sc_Meditron_r-5001_s-0_aug-URTI-180.wav
# 188_1b1_Pl_sc_Meditron_r-5012_s-0_aug-URTI-181.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/188_1b1_Pl_sc_Meditron_r-5012_s-0_aug-URTI-181.wav
# 188_1b1_Ar_sc_Meditron_r-5003_s-0_aug-URTI-182.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/188_1b1_Ar_sc_Meditron_r-5003_s-0_aug-URTI-182.wav
# 150_1b2_Al_sc_Meditron_r-2455_s-0_aug-URTI-183.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/150_1b2_Al_sc_Meditron_r-2455_s-0_aug-URTI-183.wav
# 119_1b1_Ar_sc_Meditron_r-682_s-0_aug-URTI-184.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/119_1b1_Ar_sc_Meditron_r-682_s-0_aug-URTI-184.wav
# 188_1b1_Al_sc_Meditron_r-4986_s-0_aug-URTI-185.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/188_1b1_Al_sc_Meditron_r-4986_s-0_aug-URTI-185.wav
# 188_1b1_Pl_sc_Meditron_r-5015_s-0_aug-URTI-186.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/188_1b1_Pl_sc_Meditron_r-5015_s-0_aug-URTI-186.wav
# 210_1b1_Ar_sc_Meditron_r-6181_s-0_aug-URTI-187.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/210_1b1_Ar_sc_Meditron_r-6181_s-0_aug-URTI-187.wav
# 101_1b1_Pr_sc_Meditron_r-21_s-0_aug-URTI-188.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/101_1b1_Pr_sc_Meditron_r-21_s-0_aug-URTI-188.wav
# 148_1b1_Al_sc_Meditron_r-2383_s-0_aug-URTI-189.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/148_1b1_Al_sc_Meditron_r-2383_s-0_aug-URTI-189.wav
# 188_1b1_Al_sc_Meditron_r-4977_s-0_aug-URTI-190.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/188_1b1_Al_sc_Meditron_r-4977_s-0_aug-URTI-190.wav
# 150_1b2_Al_sc_Meditron_r-2451_s-0_aug-URTI-191.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/150_1b2_Al_sc_Meditron_r-2451_s-0_aug-URTI-191.wav
# 188_1b1_Ar_sc_Meditron_r-4998_s-0_aug-URTI-192.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/188_1b1_Ar_sc_Meditron_r-4998_s-0_aug-URTI-192.wav
# 190_1b1_Tc_sc_Meditron_r-5041_s-0_aug-URTI-193.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/190_1b1_Tc_sc_Meditron_r-5041_s-0_aug-URTI-193.wav
# 148_1b1_Al_sc_Meditron_r-2388_s-0_aug-URTI-194.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/148_1b1_Al_sc_Meditron_r-2388_s-0_aug-URTI-194.wav
# 197_1b1_Al_sc_Meditron_r-5352_s-0_aug-URTI-195.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/197_1b1_Al_sc_Meditron_r-5352_s-0_aug-URTI-195.wav
# 119_1b1_Ar_sc_Meditron_r-681_s-0_aug-URTI-196.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/119_1b1_Ar_sc_Meditron_r-681_s-0_aug-URTI-196.wav
# 188_1b1_Pl_sc_Meditron_r-5005_s-0_aug-URTI-197.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/188_1b1_Pl_sc_Meditron_r-5005_s-0_aug-URTI-197.wav
# 188_1b1_Pl_sc_Meditron_r-5013_s-0_aug-URTI-198.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/188_1b1_Pl_sc_Meditron_r-5013_s-0_aug-URTI-198.wav
# 197_1b1_Tc_sc_Meditron_r-5355_s-0_aug-URTI-199.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/197_1b1_Tc_sc_Meditron_r-5355_s-0_aug-URTI-199.wav
# 210_1b1_Ar_sc_Meditron_r-6183_s-0_aug-URTI-200.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/210_1b1_Ar_sc_Meditron_r-6183_s-0_aug-URTI-200.wav
# 188_1b1_Tc_sc_Meditron_r-5023_s-0_aug-URTI-201.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/188_1b1_Tc_sc_Meditron_r-5023_s-0_aug-URTI-201.wav
# 188_1b1_Pl_sc_Meditron_r-5009_s-0_aug-URTI-202.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/188_1b1_Pl_sc_Meditron_r-5009_s-0_aug-URTI-202.wav
# 210_1b1_Ar_sc_Meditron_r-6174_s-0_aug-URTI-203.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/210_1b1_Ar_sc_Meditron_r-6174_s-0_aug-URTI-203.wav
# 165_1b1_Pr_sc_Meditron_r-3620_s-0_aug-URTI-204.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/165_1b1_Pr_sc_Meditron_r-3620_s-0_aug-URTI-204.wav
# 105_1b1_Tc_sc_Meditron_r-91_s-0_aug-URTI-205.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/105_1b1_Tc_sc_Meditron_r-91_s-0_aug-URTI-205.wav
# 188_1b1_Ar_sc_Meditron_r-4999_s-0_aug-URTI-206.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/188_1b1_Ar_sc_Meditron_r-4999_s-0_aug-URTI-206.wav
# 188_1b1_Pl_sc_Meditron_r-5005_s-0_aug-URTI-207.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/188_1b1_Pl_sc_Meditron_r-5005_s-0_aug-URTI-207.wav
# 164_1b1_Ll_sc_Meditron_r-3594_s-0_aug-URTI-208.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/164_1b1_Ll_sc_Meditron_r-3594_s-0_aug-URTI-208.wav
# 165_1b1_Pr_sc_Meditron_r-3616_s-0_aug-URTI-209.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/165_1b1_Pr_sc_Meditron_r-3616_s-0_aug-URTI-209.wav
# 150_1b2_Al_sc_Meditron_r-2447_s-0_aug-URTI-210.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/150_1b2_Al_sc_Meditron_r-2447_s-0_aug-URTI-210.wav
# 101_1b1_Al_sc_Meditron_r-4_s-0_aug-URTI-211.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/101_1b1_Al_sc_Meditron_r-4_s-0_aug-URTI-211.wav
# 150_1b2_Al_sc_Meditron_r-2447_s-0_aug-URTI-212.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/150_1b2_Al_sc_Meditron_r-2447_s-0_aug-URTI-212.wav
# 148_1b1_Al_sc_Meditron_r-2383_s-0_aug-URTI-213.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/148_1b1_Al_sc_Meditron_r-2383_s-0_aug-URTI-213.wav
# 129_1b1_Ar_sc_Meditron_r-972_s-0_aug-URTI-214.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/129_1b1_Ar_sc_Meditron_r-972_s-0_aug-URTI-214.wav
# 210_1b1_Ar_sc_Meditron_r-6184_s-0_aug-URTI-215.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/210_1b1_Ar_sc_Meditron_r-6184_s-0_aug-URTI-215.wav
# 131_1b1_Al_sc_Meditron_r-1487_s-0_aug-URTI-216.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/131_1b1_Al_sc_Meditron_r-1487_s-0_aug-URTI-216.wav
# 148_1b1_Al_sc_Meditron_r-2391_s-0_aug-URTI-217.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/148_1b1_Al_sc_Meditron_r-2391_s-0_aug-URTI-217.wav
# 210_1b1_Ar_sc_Meditron_r-6183_s-0_aug-URTI-218.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/210_1b1_Ar_sc_Meditron_r-6183_s-0_aug-URTI-218.wav
# 188_1b1_Tc_sc_Meditron_r-5030_s-0_aug-URTI-219.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/188_1b1_Tc_sc_Meditron_r-5030_s-0_aug-URTI-219.wav
# 165_1b1_Pl_sc_Meditron_r-3610_s-0_aug-URTI-220.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/165_1b1_Pl_sc_Meditron_r-3610_s-0_aug-URTI-220.wav
# 131_1b1_Al_sc_Meditron_r-1482_s-0_aug-URTI-221.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/131_1b1_Al_sc_Meditron_r-1482_s-0_aug-URTI-221.wav
# 131_1b1_Al_sc_Meditron_r-1490_s-0_aug-URTI-222.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/131_1b1_Al_sc_Meditron_r-1490_s-0_aug-URTI-222.wav
# 119_1b1_Ar_sc_Meditron_r-684_s-0_aug-URTI-223.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/119_1b1_Ar_sc_Meditron_r-684_s-0_aug-URTI-223.wav
# 119_1b1_Ar_sc_Meditron_r-688_s-0_aug-URTI-224.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/119_1b1_Ar_sc_Meditron_r-688_s-0_aug-URTI-224.wav
# 101_1b1_Pr_sc_Meditron_r-19_s-0_aug-URTI-225.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/101_1b1_Pr_sc_Meditron_r-19_s-0_aug-URTI-225.wav
# 137_1b1_Ll_sc_Meditron_r-1834_s-0_aug-URTI-226.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/137_1b1_Ll_sc_Meditron_r-1834_s-0_aug-URTI-226.wav
# 210_1b1_Al_sc_Meditron_r-6157_s-0_aug-URTI-227.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/210_1b1_Al_sc_Meditron_r-6157_s-0_aug-URTI-227.wav
# 190_1b1_Tc_sc_Meditron_r-5040_s-0_aug-URTI-228.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/190_1b1_Tc_sc_Meditron_r-5040_s-0_aug-URTI-228.wav
# 105_1b1_Tc_sc_Meditron_r-93_s-0_aug-URTI-229.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/105_1b1_Tc_sc_Meditron_r-93_s-0_aug-URTI-229.wav
# 165_1b1_Pl_sc_Meditron_r-3615_s-0_aug-URTI-230.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/165_1b1_Pl_sc_Meditron_r-3615_s-0_aug-URTI-230.wav
# 188_1b1_Tc_sc_Meditron_r-5031_s-0_aug-URTI-231.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/188_1b1_Tc_sc_Meditron_r-5031_s-0_aug-URTI-231.wav
# 188_1b1_Al_sc_Meditron_r-4972_s-0_aug-URTI-232.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/188_1b1_Al_sc_Meditron_r-4972_s-0_aug-URTI-232.wav
# 197_1b1_Tc_sc_Meditron_r-5356_s-0_aug-URTI-233.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/197_1b1_Tc_sc_Meditron_r-5356_s-0_aug-URTI-233.wav
# 188_1b1_Tc_sc_Meditron_r-5023_s-0_aug-URTI-234.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/188_1b1_Tc_sc_Meditron_r-5023_s-0_aug-URTI-234.wav
# 210_1b1_Al_sc_Meditron_r-6167_s-0_aug-URTI-235.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/210_1b1_Al_sc_Meditron_r-6167_s-0_aug-URTI-235.wav
# 165_1b1_Pr_sc_Meditron_r-3620_s-0_aug-URTI-236.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/165_1b1_Pr_sc_Meditron_r-3620_s-0_aug-URTI-236.wav
# 101_1b1_Al_sc_Meditron_r-9_s-0_aug-URTI-237.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/101_1b1_Al_sc_Meditron_r-9_s-0_aug-URTI-237.wav
# 188_1b1_Ar_sc_Meditron_r-5003_s-0_aug-URTI-238.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/188_1b1_Ar_sc_Meditron_r-5003_s-0_aug-URTI-238.wav
# 148_1b1_Al_sc_Meditron_r-2390_s-0_aug-URTI-239.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/148_1b1_Al_sc_Meditron_r-2390_s-0_aug-URTI-239.wav
# 210_1b1_Al_sc_Meditron_r-6165_s-0_aug-URTI-240.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/210_1b1_Al_sc_Meditron_r-6165_s-0_aug-URTI-240.wav
# 188_1b1_Tc_sc_Meditron_r-5030_s-0_aug-URTI-241.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/188_1b1_Tc_sc_Meditron_r-5030_s-0_aug-URTI-241.wav
# 188_1b1_Ar_sc_Meditron_r-4992_s-0_aug-URTI-242.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/188_1b1_Ar_sc_Meditron_r-4992_s-0_aug-URTI-242.wav
# 119_1b1_Ar_sc_Meditron_r-682_s-0_aug-URTI-243.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/119_1b1_Ar_sc_Meditron_r-682_s-0_aug-URTI-243.wav
# 188_1b1_Al_sc_Meditron_r-4986_s-0_aug-URTI-244.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/188_1b1_Al_sc_Meditron_r-4986_s-0_aug-URTI-244.wav
# 150_1b2_Al_sc_Meditron_r-2451_s-0_aug-URTI-245.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/150_1b2_Al_sc_Meditron_r-2451_s-0_aug-URTI-245.wav
# 119_1b1_Ar_sc_Meditron_r-688_s-0_aug-URTI-246.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/119_1b1_Ar_sc_Meditron_r-688_s-0_aug-URTI-246.wav
# 129_1b1_Ar_sc_Meditron_r-967_s-0_aug-URTI-247.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/129_1b1_Ar_sc_Meditron_r-967_s-0_aug-URTI-247.wav
# 129_1b1_Ar_sc_Meditron_r-972_s-0_aug-URTI-248.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/129_1b1_Ar_sc_Meditron_r-972_s-0_aug-URTI-248.wav
# 197_1b1_Tc_sc_Meditron_r-5355_s-0_aug-URTI-249.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/197_1b1_Tc_sc_Meditron_r-5355_s-0_aug-URTI-249.wav
# 188_1b1_Pl_sc_Meditron_r-5011_s-0_aug-URTI-250.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/188_1b1_Pl_sc_Meditron_r-5011_s-0_aug-URTI-250.wav
# 188_1b1_Tc_sc_Meditron_r-5031_s-0_aug-URTI-251.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/188_1b1_Tc_sc_Meditron_r-5031_s-0_aug-URTI-251.wav
# 188_1b1_Ar_sc_Meditron_r-4993_s-0_aug-URTI-252.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/188_1b1_Ar_sc_Meditron_r-4993_s-0_aug-URTI-252.wav
# 197_1b1_Al_sc_Meditron_r-5351_s-0_aug-URTI-253.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/197_1b1_Al_sc_Meditron_r-5351_s-0_aug-URTI-253.wav
# 210_1b1_Al_sc_Meditron_r-6172_s-0_aug-URTI-254.wav  writing to:  /home/rithik-tank/Desktop/Auscultate/preprocessing/outputs/augmentation_outputs/segments/210_1b1_Al_sc_Meditron_r-6172_s-0_aug-URTI-254.wav
# 	Final count: 500

# %%
# Read segments data
seg_df = pd.read_csv("outputs/augmentation_outputs/segments.csv")

# Count segments per disease
disease_counts = seg_df['disease'].value_counts()

# Create the bar chart
plt.figure(figsize=(12, 6))
bars = plt.bar(disease_counts.index, disease_counts.values, 
               color=['skyblue', 'lightcoral', 'lightgreen', 'orange', 'purple', 'brown', 'gray'])

# Add value labels on bars
for bar, count in zip(bars, disease_counts.values):
    plt.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 5, 
             f'{count:,}', ha='center', va='bottom', fontweight='bold')

plt.title('Number of Audio Segments per Disease Class', fontsize=14, fontweight='bold')
plt.xlabel('Disease Class', fontsize=12)
plt.ylabel('Number of Segments', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', alpha=0.3)

# Add some padding to top for labels
plt.ylim(0, disease_counts.max() * 1.1)

plt.tight_layout()
plt.show()

# Print the counts
print("Segment counts per disease:")
print(disease_counts)
# Out:
# Segment counts per disease:
# disease
# Bronchiectasis    500
# Bronchiolitis     500
# COPD              500
# Healthy           500
# Pneumonia         500
# URTI              500
# Name: count, dtype: int64

# %% [markdown]
# ### 3. Completely Random split Split

# %% [markdown]
# This script performs a random split for lung sound datasets (data leaks are expected).
#
# Properties:
# - Same patient could appear in train and test
# - Model performance will look artificially high
# - 90% development / 10% unseen
# - 80/20 train/test inside development
# - Reproducible with random seed
#
# Input CSV format (one row per segment or file):
# pid, disease, filepath,...
#
# Output:
# train_pids.txt
# test_pids.txt
# val_pids.txt

# %%
UNSEEN_RATIO = 0.10
TEST_RATIO_WITHIN_DEV = 0.20

def random_split(
    pid_df,
    segments_source_dir,
    output_root_dir,
    seed=42
):
    rng = np.random.default_rng(seed)

    # --------------------------------------------------
    # 1️⃣ Shuffle entire dataframe randomly (row-level)
    # --------------------------------------------------
    shuffled_df = pid_df.sample(frac=1, random_state=seed).reset_index(drop=True)

    total = len(shuffled_df)

    unseen_size = int(round(total * UNSEEN_RATIO))

    val_df = shuffled_df.iloc[:unseen_size]
    dev_df = shuffled_df.iloc[unseen_size:]

    test_size = int(round(len(dev_df) * TEST_RATIO_WITHIN_DEV))

    test_df = dev_df.iloc[:test_size]
    train_df = dev_df.iloc[test_size:]

    # --------------------------------------------------
    # 2️⃣ Save CSV outputs
    # --------------------------------------------------
    split_csv_dir = "outputs/final"
    os.makedirs(split_csv_dir, exist_ok=True)

    train_df.to_csv(f"{split_csv_dir}/train_segments.csv", index=False)
    test_df.to_csv(f"{split_csv_dir}/test_segments.csv", index=False)
    val_df.to_csv(f"{split_csv_dir}/val_segments.csv", index=False)

    # --------------------------------------------------
    # 3️⃣ Prepare segment directories
    # --------------------------------------------------
    train_dir = os.path.join(output_root_dir, "train_segments")
    test_dir  = os.path.join(output_root_dir, "test_segments")
    val_dir   = os.path.join(output_root_dir, "val_segments")

    # Remove old folders
    shutil.rmtree(train_dir, ignore_errors=True)
    shutil.rmtree(test_dir, ignore_errors=True)
    shutil.rmtree(val_dir, ignore_errors=True)

    os.makedirs(train_dir, exist_ok=True)
    os.makedirs(test_dir, exist_ok=True)
    os.makedirs(val_dir, exist_ok=True)

    # --------------------------------------------------
    # 4️⃣ Function to copy files
    # --------------------------------------------------
    def copy_files(df, destination_dir):
        count = 0
        for file in df["segment_file"]:
            src_path = os.path.join(segments_source_dir, file)


            dest_path = os.path.join(destination_dir, os.path.basename(file))
            if not os.path.exists(src_path):
                print("Missing path:", src_path)
                count+=1
                continue

            shutil.copy(src_path, dest_path)
        print("TOTAL MISSING: ", count)
        

    # Copy segments
    copy_files(train_df, train_dir)
    copy_files(test_df, test_dir)
    copy_files(val_df, val_dir)

    print("\nSplit complete.")
    print(f"Train: {len(train_df)} segments")
    print(f"Test:  {len(test_df)} segments")
    print(f"Val:   {len(val_df)} segments")

    return train_df, test_df, val_df

train_strat, test_strat, val_strat = random_split(
    train_augmented,
    os.path.join(ROOT_DIR, SEGMENTS_AUGMENTED_DIR),
    os.path.join(ROOT_DIR, SPLIT_DIR),
    seed=42
)
# Out:
# TOTAL MISSING:  0
# TOTAL MISSING:  0
# TOTAL MISSING:  0
#
# Split complete.
# Train: 2160 segments
# Test:  540 segments
# Val:   300 segments

# %%
# Read segments data
seg_df = pd.read_csv('outputs/augmentation_outputs/val_segments.csv')

# Count segments per disease
disease_counts = seg_df['disease'].value_counts()

# Create the bar chart
plt.figure(figsize=(12, 6))
bars = plt.bar(disease_counts.index, disease_counts.values, 
               color=['skyblue', 'lightcoral', 'lightgreen', 'orange', 'purple', 'brown', 'gray'])

# Add value labels on bars
for bar, count in zip(bars, disease_counts.values):
    plt.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 5, 
             f'{count:,}', ha='center', va='bottom', fontweight='bold')

plt.title('Number of Audio Segments per Disease Class', fontsize=14, fontweight='bold')
plt.xlabel('Disease Class', fontsize=12)
plt.ylabel('Number of Segments', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', alpha=0.3)

# Add some padding to top for labels
plt.ylim(0, disease_counts.max() * 1.1)

plt.tight_layout()
plt.show()

# Print the counts
print("Segment counts per disease:")
print(disease_counts)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[53], line 2
#       1 # Read segments data
# ----> 2 seg_df = pd.read_csv('outputs/augmentation_outputs/val_segments.csv')
#       4 # Count segments per disease
#       5 disease_counts = seg_df['disease'].value_counts()
#
# File ~/enter/envs/tf_gpu/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/enter/envs/tf_gpu/lib/python3.10/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/enter/envs/tf_gpu/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/enter/envs/tf_gpu/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/enter/envs/tf_gpu/lib/python3.10/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'outputs/augmentation_outputs/val_segments.csv'

# %%
# shutil.copytree(os.path.join(ROOT_DIR, SEGMENTS_DIR, "test_segments"),
#                 "../dataset/test-segments")

# shutil.copy(os.path.join(ROOT_DIR, "outputs/segmentation_outputs/test_segments.csv"),
#                 "../dataset/test_segments.csv")



# shutil.copytree(os.path.join(ROOT_DIR, SEGMENTS_DIR, "val_segments"),
#                 "../dataset/val-segments")

# shutil.copy(os.path.join(ROOT_DIR, "outputs/segmentation_outputs/val_segments.csv"),
#                 "../dataset/val_segments.csv")



shutil.copytree(os.path.join(ROOT_DIR, 'outputs/final/train_segments'),
                "../dataset/train-segments")

shutil.copy(os.path.join(ROOT_DIR, "outputs/final/train_segments.csv"),
                "../dataset/train_segments.csv")



shutil.copytree(os.path.join(ROOT_DIR, 'outputs/final/test_segments'),
                "../dataset/test-segments")

shutil.copy(os.path.join(ROOT_DIR, "outputs/final/test_segments.csv"),
                "../dataset/test_segments.csv")


shutil.copytree(os.path.join(ROOT_DIR, 'outputs/final/val_segments'),
                "../dataset/val-segments")

shutil.copy(os.path.join(ROOT_DIR, "outputs/final/val_segments.csv"),
                "../dataset/val_segments.csv")
# Out:
# '../dataset/val_segments.csv'
