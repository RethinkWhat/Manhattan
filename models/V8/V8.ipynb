# %% [markdown]
# # PyTorch Training & Evaluation Notebook
# Dual-Channel CNN–LSTM (MFCC + Chroma)
#
# This notebook extends the pure TF→PyTorch model translation with a full training / testing / validation workflow: early stopping, checkpoints, LR scheduling, metrics, plots, and confusion matrix.
#
# **Expected inputs** (NumPy arrays):
# - `X_mfcc`: shape `[N, 40, 679]`
# - `X_chroma`: shape `[N, 12, 259]`
# - `y`: integer labels shape `[N]` (0..C-1)

# %% [markdown]
# ## 1) Imports & Reproducibility

# %%
import os
import random
from dataclasses import dataclass

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix, classification_report

# -----------------------
# Reproducibility
# -----------------------
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %% [markdown]
# ## 2) Data Loading (replace with your feature files)
# If you already have train/test/val splits saved, load them here.
# A common approach is to store arrays in a single `.npz` file.

# %%
import numpy as np
import pandas as pd
import librosa as lb

# -----------------------------------
# Paths
# -----------------------------------
BASE_DIR = "../../dataset"

TRAIN_DIR = os.path.join(BASE_DIR, "train-segments")
TEST_DIR = os.path.join(BASE_DIR, "test-segments")
VAL_DIR = os.path.join(BASE_DIR, "val-segments")

TRAIN_CSV = os.path.join(BASE_DIR, "train_segments.csv")
TEST_CSV = os.path.join(BASE_DIR, "test_segments.csv")
VAL_CSV = os.path.join(BASE_DIR, "val_segments.csv")

# -----------------------------------
# Feature parameters
# -----------------------------------
SR = 4000
N_MFCC = 40
TARGET_MFCC_T = 679
TARGET_CHROMA_T = 259

# %%
def extract_mfcc_and_chroma(y, sr):
    mfcc = lb.feature.mfcc(y=y, sr=sr, n_mfcc=N_MFCC)
    chroma = lb.feature.chroma_stft(y=y, sr=sr)
    return mfcc, chroma


def pad_or_crop(feat, target_T):
    F, T = feat.shape

    if T > target_T:
        return feat[:, :target_T]

    if T < target_T:
        pad_width = target_T - T
        return np.pad(feat, ((0, 0), (0, pad_width)), mode="constant")

    return feat

# %%
def build_features_from_csv(csv_path, audio_dir):
    df = pd.read_csv(csv_path)

    mfcc_list = []
    chroma_list = []
    labels = []

    # Create consistent label mapping
    diseases = sorted(df["disease"].unique())
    label_map = {d: i for i, d in enumerate(diseases)}

    for _, row in df.iterrows():
        filename = os.path.basename(row["segment_file"])
        label = row["disease"]

        file_path = os.path.join(audio_dir, filename)

        if not os.path.exists(file_path):
            raise FileNotFoundError(f"Missing file: {file_path}")

        # Load audio
        y, sr = lb.load(file_path, sr=SR)

        # Extract features
        mfcc, chroma = extract_mfcc_and_chroma(y, sr)

        # Pad / crop
        mfcc = pad_or_crop(mfcc, TARGET_MFCC_T)
        chroma = pad_or_crop(chroma, TARGET_CHROMA_T)

        mfcc_list.append(mfcc)
        chroma_list.append(chroma)
        labels.append(label_map[label])

    X_mfcc = np.stack(mfcc_list)
    X_chroma = np.stack(chroma_list)
    y = np.array(labels)

    return X_mfcc, X_chroma, y, label_map

# %%
X_mfcc_train, X_chroma_train, y_train, label_map = build_features_from_csv(
    TRAIN_CSV, TRAIN_DIR
)

X_mfcc_test, X_chroma_test, y_test, _ = build_features_from_csv(
    TEST_CSV, TEST_DIR
)

X_mfcc_val, X_chroma_val, y_val, _ = build_features_from_csv(
    VAL_CSV, VAL_DIR
)
# Out:
# /home/rithik-tank/enter/envs/tf_gpu/lib/python3.10/site-packages/librosa/core/pitch.py:103: UserWarning: Trying to estimate tuning from empty frequency set.
#   return pitch_tuning(
# /home/rithik-tank/enter/envs/tf_gpu/lib/python3.10/site-packages/librosa/core/pitch.py:103: UserWarning: Trying to estimate tuning from empty frequency set.
#   return pitch_tuning(
# /home/rithik-tank/enter/envs/tf_gpu/lib/python3.10/site-packages/librosa/core/pitch.py:103: UserWarning: Trying to estimate tuning from empty frequency set.
#   return pitch_tuning(

# %%
X_mfcc_train = torch.from_numpy(X_mfcc_train).float()
X_chroma_train = torch.from_numpy(X_chroma_train).float()
y_train = torch.from_numpy(y_train).long()

X_mfcc_test = torch.from_numpy(X_mfcc_test).float()
X_chroma_test = torch.from_numpy(X_chroma_test).float()
y_test = torch.from_numpy(y_test).long()

X_mfcc_unseen = torch.from_numpy(X_mfcc_val).float()
X_chroma_unseen = torch.from_numpy(X_chroma_val).float()
y_unseen = torch.from_numpy(y_val).long()

# %%
# ------------------------------------------------------------
# (PLACEHOLDER) MFCC & Chroma extraction
# Your classmate will implement the real extraction pipeline here.
# This scaffold shows the expected inputs/outputs for the model.
# ------------------------------------------------------------
# Expected model inputs:
#   mfcc:   torch.FloatTensor [B, 40, 679]
#   chroma: torch.FloatTensor [B, 12, 259]
#
# Notes:
# - In your final pipeline, you will likely:
#   1) load audio (already resampled/filtered/segmented/normalized)
#   2) extract MFCC and chroma per 3-second segment
#   3) pad/crop along time axis to fixed lengths (679 and 259 here)
#
# If librosa is available, this is a minimal template:
#
# import librosa as lb
# import numpy as np
#
# def extract_mfcc_and_chroma(y: np.ndarray, sr: int):
#     # MFCC: shape [n_mfcc, T_mfcc]
#     mfcc = lb.feature.mfcc(y=y, sr=sr, n_mfcc=40)
#     # Chroma: shape [12, T_chr]
#     chroma = lb.feature.chroma_stft(y=y, sr=sr)
#     return mfcc, chroma
#
# def pad_or_crop(feat: np.ndarray, target_T: int):
#     # feat: [F, T]
#     F, T = feat.shape
#     if T == target_T:
#         return feat
#     if T > target_T:
#         return feat[:, :target_T]
#     # pad on the right
#     pad_width = target_T - T
#     return np.pad(feat, ((0,0),(0,pad_width)), mode="constant")
#
# In the dataloader, convert to torch:
#   mfcc = torch.from_numpy(mfcc).float()
#   chroma = torch.from_numpy(chroma).float()

# %%
# Example loader (edit paths / keys to match your pipeline)
# data = np.load("features_splits.npz", allow_pickle=True)
# X_mfcc_train = data["X_mfcc_train"]     # [N, 40, 679]
# X_chroma_train = data["X_chroma_train"] # [N, 12, 259]
# y_train = data["y_train"]               # [N]
# X_mfcc_test = data["X_mfcc_test"]
# X_chroma_test = data["X_chroma_test"]
# y_test = data["y_test"]
# X_mfcc_unseen = data["X_mfcc_unseen"]
# X_chroma_unseen = data["X_chroma_unseen"]
# y_unseen = data["y_unseen"]

# -----------------------
# TEMP: dummy data (delete once you load real arrays)
# -----------------------
num_classes = 6
N_train, N_test, N_unseen = 256, 64, 64

# X_mfcc_train = np.random.randn(N_train, 40, 679).astype(np.float32)
# X_chroma_train = np.random.randn(N_train, 12, 259).astype(np.float32)
# y_train = np.random.randint(0, num_classes, size=(N_train,)).astype(np.int64)

# X_mfcc_test = np.random.randn(N_test, 40, 679).astype(np.float32)
# X_chroma_test = np.random.randn(N_test, 12, 259).astype(np.float32)
# y_test = np.random.randint(0, num_classes, size=(N_test,)).astype(np.int64)

# X_mfcc_unseen = np.random.randn(N_unseen, 40, 679).astype(np.float32)
# X_chroma_unseen = np.random.randn(N_unseen, 12, 259).astype(np.float32)
# y_unseen = np.random.randint(0, num_classes, size=(N_unseen,)).astype(np.int64)

print("Train:", X_mfcc_train.shape, X_chroma_train.shape, y_train.shape)
print("Test: ", X_mfcc_test.shape, X_chroma_test.shape, y_test.shape)
print("Unseen:", X_mfcc_unseen.shape, X_chroma_unseen.shape, y_unseen.shape)
# Out:
# Train: torch.Size([3000, 40, 679]) torch.Size([3000, 12, 259]) torch.Size([3000])
# Test:  torch.Size([1691, 40, 679]) torch.Size([1691, 12, 259]) torch.Size([1691])
# Unseen: torch.Size([931, 40, 679]) torch.Size([931, 12, 259]) torch.Size([931])

# %% [markdown]
# ## 3) Dataset & DataLoader

# %%
class DualFeatureDataset(Dataset):
    def __init__(self, X_mfcc: np.ndarray, X_chroma: np.ndarray, y: np.ndarray):
        assert len(X_mfcc) == len(X_chroma) == len(y)
        self.X_mfcc = X_mfcc
        self.X_chroma = X_chroma
        self.y = y

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        return (
            self.X_mfcc[idx],
            self.X_chroma[idx],
            self.y[idx]
        )

batch_size = 32

train_loader = DataLoader(DualFeatureDataset(X_mfcc_train, X_chroma_train, y_train),
                          batch_size=batch_size, shuffle=True, num_workers=0, pin_memory=True)

test_loader = DataLoader(DualFeatureDataset(X_mfcc_test, X_chroma_test, y_test),
                         batch_size=batch_size, shuffle=False, num_workers=0, pin_memory=True)

unseen_loader = DataLoader(DualFeatureDataset(X_mfcc_unseen, X_chroma_unseen, y_unseen),
                           batch_size=batch_size, shuffle=False, num_workers=0, pin_memory=True)

# %% [markdown]
# ## 4) Model Definition (pure translation)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


class GatedFusion(nn.Module):
    def __init__(self, dim: int, hidden: int = 128, dropout: float = 0.1):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(dim * 2, hidden),
            nn.ReLU(inplace=True),
            nn.Dropout(dropout),
            nn.Linear(hidden, dim),
        )

    def forward(self, a: torch.Tensor, b: torch.Tensor):
        w = torch.sigmoid(self.net(torch.cat([a, b], dim=1)))
        fused = w * a + (1.0 - w) * b
        return fused, w


class DualChannelCNNLSTM_WithAttentionFusion(nn.Module):

    def __init__(self, num_classes: int = 8, dropout_p: float = 0.4, fuse_dim: int = 64):
        super().__init__()
        self.fuse_dim = fuse_dim

        # -------------------------------
        # MFCC CNN
        # -------------------------------
        self.mfcc_cnn = nn.Sequential(
            nn.Conv2d(1, 32, 3, padding=1),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(32),
            nn.MaxPool2d(2),
            nn.Dropout(0.2),

            nn.Conv2d(32, 64, 3, padding=1),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(64),
            nn.MaxPool2d(2),
            nn.Dropout(0.2),

            nn.Conv2d(64, 128, 3, padding=1),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(128),
            nn.MaxPool2d(2),
            nn.Dropout(0.2),
        )

        # -------------------------------
        # CHROMA CNN
        # -------------------------------
        self.chroma_cnn = nn.Sequential(
            nn.Conv2d(1, 32, 3, padding=1),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(32),
            nn.MaxPool2d(2),
            nn.Dropout(0.2),

            nn.Conv2d(32, 64, 3, padding=1),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(64),
            nn.MaxPool2d(2),
            nn.Dropout(0.2),

            nn.Conv2d(64, 128, 3, padding=1),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(128),
            nn.MaxPool2d(2),
            nn.Dropout(0.2),
        )

        self.gap2d = nn.AdaptiveAvgPool2d((1, 1))

        self.mfcc_cnn_proj = nn.Linear(128, fuse_dim)
        self.chroma_cnn_proj = nn.Linear(128, fuse_dim)

        # -------------------------------
        # MFCC LSTM (with dropout)
        # -------------------------------
        self.mfcc_lstm1 = nn.LSTM(40, 128, batch_first=True)
        self.mfcc_lstm2 = nn.LSTM(128, 64, batch_first=True, dropout=0.2)
        self.mfcc_lstm3 = nn.LSTM(64, fuse_dim, batch_first=True)

        # -------------------------------
        # CHROMA LSTM (with dropout)
        # -------------------------------
        self.chroma_lstm1 = nn.LSTM(12, 128, batch_first=True)
        self.chroma_lstm2 = nn.LSTM(128, 64, batch_first=True, dropout=0.2)
        self.chroma_lstm3 = nn.LSTM(64, fuse_dim, batch_first=True)

        # -------------------------------
        # Fusion modules
        # -------------------------------
        self.fuse_cnn_modality = GatedFusion(dim=fuse_dim)
        self.fuse_lstm_modality = GatedFusion(dim=fuse_dim)
        self.fuse_extractor = GatedFusion(dim=fuse_dim)

        # -------------------------------
        # Classifier
        # -------------------------------
        self.fc1 = nn.Linear(fuse_dim, 128)
        self.dropout = nn.Dropout(p=dropout_p)
        self.fc_out = nn.Linear(128, num_classes)

    def forward(self, mfcc, chroma, return_attn=False):

        mfcc_cnn = self.mfcc_cnn(mfcc.unsqueeze(1))
        mfcc_cnn_vec = self.gap2d(mfcc_cnn).flatten(1)
        mfcc_cnn_vec = self.mfcc_cnn_proj(mfcc_cnn_vec)

        chroma_cnn = self.chroma_cnn(chroma.unsqueeze(1))
        chroma_cnn_vec = self.gap2d(chroma_cnn).flatten(1)
        chroma_cnn_vec = self.chroma_cnn_proj(chroma_cnn_vec)

        mfcc_lstm = mfcc.transpose(1, 2)
        x,_ = self.mfcc_lstm1(mfcc_lstm)
        x,_ = self.mfcc_lstm2(x)
        x,_ = self.mfcc_lstm3(x)
        mfcc_lstm_vec = x[:,-1,:]

        chroma_lstm = chroma.transpose(1,2)
        y,_ = self.chroma_lstm1(chroma_lstm)
        y,_ = self.chroma_lstm2(y)
        y,_ = self.chroma_lstm3(y)
        chroma_lstm_vec = y[:,-1,:]

        cnn_fused, w_cnn = self.fuse_cnn_modality(mfcc_cnn_vec, chroma_cnn_vec)
        lstm_fused, w_lstm = self.fuse_lstm_modality(mfcc_lstm_vec, chroma_lstm_vec)
        final_fused, w_inter = self.fuse_extractor(cnn_fused, lstm_fused)

        z = F.relu(self.fc1(final_fused))
        z = self.dropout(z)
        logits = self.fc_out(z)

        if return_attn:
            attn = {
                "w_cnn_mean": float(w_cnn.mean().item()),
                "w_lstm_mean": float(w_lstm.mean().item()),
                "w_inter_mean": float(w_inter.mean().item()),
            }
            return logits, attn

        return logits

# %% [markdown]
# ## 5) Loss, Optimizer, Scheduler (Keras-like)

# %%
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

y_dev = np.concatenate([y_train, y_test], axis=0)

class_weights = compute_class_weight(
    class_weight="balanced",
    classes=np.unique(y_dev),
    y=y_dev
)

class_weights = torch.tensor(class_weights, dtype=torch.float32).to(device)

# %%
model = DualChannelCNNLSTM_WithAttentionFusion(
    num_classes=num_classes,
    dropout_p=0.4,
    fuse_dim=64
).to(device)

criterion = nn.CrossEntropyLoss(
    weight=class_weights,
    label_smoothing=0.05
)

optimizer = torch.optim.AdamW(
    model.parameters(),
    lr=5e-5,
    weight_decay=1e-4
)

scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode="min",
    factor=0.5,
    patience=6,
    min_lr=1e-6
)
# Out:
# /home/rithik-tank/enter/envs/tf_gpu/lib/python3.10/site-packages/torch/nn/modules/rnn.py:1013: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   super().__init__("LSTM", *args, **kwargs)

# %% [markdown]
# ## 6) Early Stopping + Checkpointing

# %%
@dataclass
class EarlyStopping:
    patience: int = 7
    min_delta: float = 0.0
    best: float = float("inf")
    num_bad_epochs: int = 0
    stopped: bool = False

    def step(self, current: float) -> bool:
        # returns True if we should stop
        improved = (self.best - current) > self.min_delta
        if improved:
            self.best = current
            self.num_bad_epochs = 0
        else:
            self.num_bad_epochs += 1
            if self.num_bad_epochs >= self.patience:
                self.stopped = True
        return self.stopped

checkpoint_path = "best_model.pt"
early = EarlyStopping(
    patience=15, 
    min_delta=1e-4
)

# %% [markdown]
# ## 7) Train / Eval loops (loss + accuracy + macro F1)

# %%
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, balanced_accuracy_score

def run_epoch(model, loader, optimizer=None):

    is_train = optimizer is not None
    model.train(is_train)

    all_losses = []
    all_preds = []
    all_targets = []

    attn_w_cnn = []
    attn_w_lstm = []
    attn_w_inter = []

    for mfcc, chroma, y in loader:

        mfcc = mfcc.to(device)
        chroma = chroma.to(device)
        y = y.to(device)

        logits, attn = model(mfcc, chroma, return_attn=True)
        loss = criterion(logits, y)

        if is_train:
            optimizer.zero_grad(set_to_none=True)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step()

        all_losses.append(loss.item())

        preds = torch.argmax(logits, dim=1)

        all_preds.append(preds.detach().cpu().numpy())
        all_targets.append(y.detach().cpu().numpy())

        attn_w_cnn.append(attn['w_cnn_mean'])
        attn_w_lstm.append(attn['w_lstm_mean'])
        attn_w_inter.append(attn['w_inter_mean'])

    all_preds = np.concatenate(all_preds)
    all_targets = np.concatenate(all_targets)

    acc = accuracy_score(all_targets, all_preds)
    bal_acc = balanced_accuracy_score(all_targets, all_preds)

    prec, rec, f1, _ = precision_recall_fscore_support(
        all_targets,
        all_preds,
        average="macro",
        zero_division=0
    )

    return (
        float(np.mean(all_losses)),
        acc,
        bal_acc,
        prec,
        rec,
        f1,
        float(np.mean(attn_w_cnn)),
        float(np.mean(attn_w_lstm)),
        float(np.mean(attn_w_inter))
    )

# %% [markdown]
# ## 8) Training Run (history like Keras)

# %%
# 10-Fold Cross-Validation on the *development* set (train+test), then final evaluation on the unseen set.
from sklearn.model_selection import StratifiedKFold
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

epochs = 500
n_splits = 10
batch_size = 32  # keep consistent

# Combine the dev split (train+test) for CV
X_mfcc_dev = np.concatenate([X_mfcc_train, X_mfcc_test], axis=0)
X_chroma_dev = np.concatenate([X_chroma_train, X_chroma_test], axis=0)

skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=SEED)

fold_summaries = []
best_fold_loss = float("inf")
best_fold_state = None

for fold, (tr_idx, va_idx) in enumerate(skf.split(np.zeros(len(y_dev)), y_dev), start=1):
    print(f"\n========== Fold {fold}/{n_splits} ==========")

    # Fold loaders
    fold_train_loader = DataLoader(
        DualFeatureDataset(X_mfcc_dev[tr_idx], X_chroma_dev[tr_idx], y_dev[tr_idx]),
        batch_size=batch_size, shuffle=True, num_workers=0, pin_memory=True
    )
    fold_val_loader = DataLoader(
        DualFeatureDataset(X_mfcc_dev[va_idx], X_chroma_dev[va_idx], y_dev[va_idx]),
        batch_size=batch_size, shuffle=False, num_workers=0, pin_memory=True
    )

    # Fresh model per fold
    model = DualChannelCNNLSTM_WithAttentionFusion(
        num_classes=num_classes,
        dropout_p=0.4,
        fuse_dim=64
    ).to(device)
    
    # Loss
    criterion = nn.CrossEntropyLoss(
        weight=class_weights,
        label_smoothing=0.05
    )

    # Optimizer
    optimizer = torch.optim.AdamW(
        model.parameters(),
        lr=5e-5,
        weight_decay=1e-4
    )

    # Scheduler (same as before)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer,
        mode="min",
        factor=0.5,
        patience=6,
        min_lr=1e-6
    )

    # Early stopping
    early = EarlyStopping(
        patience=15,
        min_delta=1e-4
    )

    history = {
        "train_loss": [], "train_acc": [], "train_f1": [],
        "val_loss": [], "val_acc": [], "val_f1": [],
        "lr": [],
        "train_w_cnn": [], "train_w_lstm": [], "train_w_inter": [],
        "val_w_cnn": [], "val_w_lstm": [], "val_w_inter": []
    }

    best_this_fold = float("inf")
    best_state_this_fold = None

    for epoch in range(1, epochs + 1):
        (train_loss, train_acc, train_bal_acc, train_prec, train_rec, train_f1,
         train_w_cnn, train_w_lstm, train_w_inter) = run_epoch(model, fold_train_loader, optimizer=optimizer)
        
        (val_loss, val_acc, val_bal_acc, val_prec, val_rec, val_f1,
         val_w_cnn, val_w_lstm, val_w_inter) = run_epoch(model, fold_val_loader, optimizer=None)
        
        scheduler.step(val_loss)
        lr = optimizer.param_groups[0]["lr"]

        history["lr"].append(lr)
        history["train_loss"].append(train_loss)
        history["train_acc"].append(train_acc)
        history["train_f1"].append(train_f1)
        history["val_loss"].append(val_loss)
        history["val_acc"].append(val_acc)
        history["val_f1"].append(val_f1)

        history["train_w_cnn"].append(train_w_cnn)
        history["train_w_lstm"].append(train_w_lstm)
        history["train_w_inter"].append(train_w_inter)
        history["val_w_cnn"].append(val_w_cnn)
        history["val_w_lstm"].append(val_w_lstm)
        history["val_w_inter"].append(val_w_inter)

        print(
            f"Fold {fold} | Epoch {epoch:03d} | "
            f"train loss {train_loss:.4f} acc {train_acc:.4f} bal_acc {train_bal_acc:.4f} f1 {train_f1:.4f} | "
            f"val loss {val_loss:.4f} acc {val_acc:.4f} bal_acc {val_bal_acc:.4f} f1 {val_f1:.4f} | "
            f"attn(cnn={val_w_cnn:.3f}, lstm={val_w_lstm:.3f}, inter={val_w_inter:.3f}) | "
            f"lr {lr:.2e}"
        )

        if val_loss <= best_this_fold - early.min_delta:
            best_this_fold = val_loss
            best_state_this_fold = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}

        if early.step(val_loss):
            print("Early stopping triggered.")
            break

    fold_summaries.append({
        "fold": fold,
        "best_val_loss": best_this_fold,
        "best_val_acc": max(history["val_acc"]) if len(history["val_acc"]) else float("nan"),
        "best_val_f1": max(history["val_f1"]) if len(history["val_f1"]) else float("nan"),
        "history": history,  # keep last fold history for plots below (optional)
    })

    # Track the single best fold model (lowest val loss)
    if best_this_fold < best_fold_loss and best_state_this_fold is not None:
        best_fold_loss = best_this_fold
        best_fold_state = best_state_this_fold

print("\n========== CV Summary ==========")
for s in fold_summaries:
    print(f"Fold {s['fold']}: best val loss={s['best_val_loss']:.4f} | best val acc={s['best_val_acc']:.4f} | best val f1={s['best_val_f1']:.4f}")

mean_acc = np.nanmean([s["best_val_acc"] for s in fold_summaries])
mean_f1 = np.nanmean([s["best_val_f1"] for s in fold_summaries])
print(f"Mean(best val acc) across folds: {mean_acc:.4f}")
print(f"Mean(best val f1 ) across folds: {mean_f1:.4f}")

# Save the best fold checkpoint for the unseen evaluation cell below
if best_fold_state is not None:
    torch.save(best_fold_state, checkpoint_path)
    print("Saved best-fold checkpoint to:", checkpoint_path)
else:
    print("WARNING: best_fold_state is None; no checkpoint saved.")
# Out:
# ========== Fold 1/10 ==========
# /home/rithik-tank/enter/envs/tf_gpu/lib/python3.10/site-packages/torch/nn/modules/rnn.py:1013: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   super().__init__("LSTM", *args, **kwargs)
# Fold 1 | Epoch 001 | train loss 1.8162 acc 0.2687 bal_acc 0.1761 f1 0.1445 | val loss 1.8427 acc 0.1362 bal_acc 0.1766 f1 0.0624 | attn(cnn=0.499, lstm=0.500, inter=0.500) | lr 5.00e-05
# Fold 1 | Epoch 002 | train loss 1.8119 acc 0.2478 bal_acc 0.1923 f1 0.1676 | val loss 1.8413 acc 0.1787 bal_acc 0.2302 f1 0.1055 | attn(cnn=0.498, lstm=0.500, inter=0.501) | lr 5.00e-05
# Fold 1 | Epoch 003 | train loss 1.8060 acc 0.2961 bal_acc 0.2132 f1 0.2094 | val loss 1.8355 acc 0.2000 bal_acc 0.2448 f1 0.1418 | attn(cnn=0.497, lstm=0.500, inter=0.503) | lr 5.00e-05
# Fold 1 | Epoch 004 | train loss 1.7975 acc 0.2893 bal_acc 0.2125 f1 0.2069 | val loss 1.8327 acc 0.1872 bal_acc 0.2216 f1 0.1405 | attn(cnn=0.495, lstm=0.500, inter=0.506) | lr 5.00e-05
# Fold 1 | Epoch 005 | train loss 1.7881 acc 0.2672 bal_acc 0.2360 f1 0.2099 | val loss 1.8308 acc 0.1851 bal_acc 0.2140 f1 0.1463 | attn(cnn=0.494, lstm=0.500, inter=0.512) | lr 5.00e-05
# Fold 1 | Epoch 006 | train loss 1.7725 acc 0.2961 bal_acc 0.2574 f1 0.2357 | val loss 1.8331 acc 0.1851 bal_acc 0.2184 f1 0.1500 | attn(cnn=0.494, lstm=0.500, inter=0.522) | lr 5.00e-05
# Fold 1 | Epoch 007 | train loss 1.7462 acc 0.2947 bal_acc 0.2759 f1 0.2446 | val loss 1.8149 acc 0.2085 bal_acc 0.2408 f1 0.1820 | attn(cnn=0.492, lstm=0.500, inter=0.569) | lr 5.00e-05
# Fold 1 | Epoch 008 | train loss 1.6897 acc 0.3303 bal_acc 0.3031 f1 0.2730 | val loss 1.8670 acc 0.1681 bal_acc 0.2129 f1 0.1256 | attn(cnn=0.491, lstm=0.494, inter=0.705) | lr 5.00e-05
# Fold 1 | Epoch 009 | train loss 1.6448 acc 0.3461 bal_acc 0.3283 f1 0.2985 | val loss 1.8716 acc 0.2021 bal_acc 0.2609 f1 0.1911 | attn(cnn=0.490, lstm=0.490, inter=0.763) | lr 5.00e-05
# Fold 1 | Epoch 010 | train loss 1.6145 acc 0.3608 bal_acc 0.3374 f1 0.3125 | val loss 1.8614 acc 0.2106 bal_acc 0.2717 f1 0.2045 | attn(cnn=0.487, lstm=0.487, inter=0.796) | lr 5.00e-05
# Fold 1 | Epoch 011 | train loss 1.5907 acc 0.3712 bal_acc 0.3491 f1 0.3267 | val loss 1.9623 acc 0.1660 bal_acc 0.2247 f1 0.1468 | attn(cnn=0.482, lstm=0.485, inter=0.805) | lr 5.00e-05
# Fold 1 | Epoch 012 | train loss 1.5763 acc 0.3824 bal_acc 0.3626 f1 0.3399 | val loss 1.9169 acc 0.1894 bal_acc 0.2483 f1 0.1715 | attn(cnn=0.482, lstm=0.483, inter=0.826) | lr 5.00e-05
# Fold 1 | Epoch 013 | train loss 1.5586 acc 0.3928 bal_acc 0.3798 f1 0.3502 | val loss 2.0276 acc 0.1532 bal_acc 0.2105 f1 0.1284 | attn(cnn=0.475, lstm=0.481, inter=0.824) | lr 5.00e-05
# Fold 1 | Epoch 014 | train loss 1.5495 acc 0.3928 bal_acc 0.3667 f1 0.3471 | val loss 2.0190 acc 0.1574 bal_acc 0.2182 f1 0.1329 | attn(cnn=0.476, lstm=0.480, inter=0.840) | lr 2.50e-05
# Fold 1 | Epoch 015 | train loss 1.5288 acc 0.3904 bal_acc 0.3842 f1 0.3579 | val loss 2.0480 acc 0.1638 bal_acc 0.2234 f1 0.1423 | attn(cnn=0.473, lstm=0.479, inter=0.847) | lr 2.50e-05
# Fold 1 | Epoch 016 | train loss 1.5232 acc 0.4139 bal_acc 0.3909 f1 0.3672 | val loss 2.0500 acc 0.1553 bal_acc 0.2151 f1 0.1296 | attn(cnn=0.473, lstm=0.478, inter=0.850) | lr 2.50e-05
# Fold 1 | Epoch 017 | train loss 1.5204 acc 0.4023 bal_acc 0.3867 f1 0.3616 | val loss 2.1225 acc 0.1574 bal_acc 0.2209 f1 0.1405 | attn(cnn=0.468, lstm=0.477, inter=0.851) | lr 2.50e-05
# Fold 1 | Epoch 018 | train loss 1.5071 acc 0.4236 bal_acc 0.3997 f1 0.3778 | val loss 2.1287 acc 0.1489 bal_acc 0.2076 f1 0.1182 | attn(cnn=0.469, lstm=0.477, inter=0.854) | lr 2.50e-05
# Fold 1 | Epoch 019 | train loss 1.5007 acc 0.4039 bal_acc 0.3921 f1 0.3655 | val loss 2.0893 acc 0.1553 bal_acc 0.2122 f1 0.1262 | attn(cnn=0.471, lstm=0.476, inter=0.858) | lr 2.50e-05
# Fold 1 | Epoch 020 | train loss 1.4952 acc 0.4179 bal_acc 0.3991 f1 0.3736 | val loss 2.1628 acc 0.1553 bal_acc 0.2166 f1 0.1285 | attn(cnn=0.467, lstm=0.475, inter=0.858) | lr 2.50e-05
# Fold 1 | Epoch 021 | train loss 1.4858 acc 0.4120 bal_acc 0.4034 f1 0.3766 | val loss 2.0787 acc 0.1638 bal_acc 0.2178 f1 0.1377 | attn(cnn=0.469, lstm=0.474, inter=0.867) | lr 1.25e-05
# Fold 1 | Epoch 022 | train loss 1.4800 acc 0.4300 bal_acc 0.4110 f1 0.3888 | val loss 2.1779 acc 0.1489 bal_acc 0.2075 f1 0.1216 | attn(cnn=0.465, lstm=0.473, inter=0.864) | lr 1.25e-05
# Early stopping triggered.
#
# ========== Fold 2/10 ==========
# /home/rithik-tank/enter/envs/tf_gpu/lib/python3.10/site-packages/torch/nn/modules/rnn.py:1013: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   super().__init__("LSTM", *args, **kwargs)
# Fold 2 | Epoch 001 | train loss 1.8161 acc 0.1277 bal_acc 0.1818 f1 0.0964 | val loss 1.8508 acc 0.1343 bal_acc 0.1896 f1 0.0702 | attn(cnn=0.500, lstm=0.501, inter=0.499) | lr 5.00e-05
# Fold 2 | Epoch 002 | train loss 1.8130 acc 0.1499 bal_acc 0.1946 f1 0.1319 | val loss 1.8510 acc 0.1471 bal_acc 0.1987 f1 0.0818 | attn(cnn=0.499, lstm=0.501, inter=0.500) | lr 5.00e-05
# Fold 2 | Epoch 003 | train loss 1.8092 acc 0.1930 bal_acc 0.2101 f1 0.1790 | val loss 1.8483 acc 0.1620 bal_acc 0.2120 f1 0.1002 | attn(cnn=0.498, lstm=0.501, inter=0.502) | lr 5.00e-05
# Fold 2 | Epoch 004 | train loss 1.8025 acc 0.2586 bal_acc 0.2398 f1 0.2154 | val loss 1.8398 acc 0.2026 bal_acc 0.2362 f1 0.1585 | attn(cnn=0.495, lstm=0.501, inter=0.510) | lr 5.00e-05
# Fold 2 | Epoch 005 | train loss 1.7890 acc 0.3333 bal_acc 0.2645 f1 0.2598 | val loss 1.8290 acc 0.2431 bal_acc 0.2775 f1 0.2117 | attn(cnn=0.489, lstm=0.501, inter=0.535) | lr 5.00e-05
# Fold 2 | Epoch 006 | train loss 1.7590 acc 0.3543 bal_acc 0.2833 f1 0.2776 | val loss 1.7968 acc 0.2836 bal_acc 0.3066 f1 0.2568 | attn(cnn=0.483, lstm=0.502, inter=0.605) | lr 5.00e-05
# Fold 2 | Epoch 007 | train loss 1.7080 acc 0.3524 bal_acc 0.3075 f1 0.2971 | val loss 1.7093 acc 0.3625 bal_acc 0.3312 f1 0.2934 | attn(cnn=0.483, lstm=0.504, inter=0.757) | lr 5.00e-05
# Fold 2 | Epoch 008 | train loss 1.6388 acc 0.3993 bal_acc 0.3459 f1 0.3382 | val loss 1.6864 acc 0.2836 bal_acc 0.2979 f1 0.2584 | attn(cnn=0.494, lstm=0.507, inter=0.842) | lr 5.00e-05
# Fold 2 | Epoch 009 | train loss 1.6046 acc 0.4064 bal_acc 0.3598 f1 0.3464 | val loss 1.6959 acc 0.2729 bal_acc 0.3242 f1 0.2623 | attn(cnn=0.508, lstm=0.507, inter=0.872) | lr 5.00e-05
# Fold 2 | Epoch 010 | train loss 1.5662 acc 0.4145 bal_acc 0.3763 f1 0.3649 | val loss 1.6662 acc 0.3006 bal_acc 0.3501 f1 0.2947 | attn(cnn=0.513, lstm=0.504, inter=0.891) | lr 5.00e-05
# Fold 2 | Epoch 011 | train loss 1.5412 acc 0.4211 bal_acc 0.3817 f1 0.3685 | val loss 1.8686 acc 0.2132 bal_acc 0.2774 f1 0.2292 | attn(cnn=0.522, lstm=0.503, inter=0.890) | lr 5.00e-05
# Fold 2 | Epoch 012 | train loss 1.5075 acc 0.4424 bal_acc 0.4069 f1 0.3906 | val loss 1.8311 acc 0.2388 bal_acc 0.3122 f1 0.2667 | attn(cnn=0.522, lstm=0.501, inter=0.906) | lr 5.00e-05
# Fold 2 | Epoch 013 | train loss 1.4898 acc 0.4405 bal_acc 0.4163 f1 0.3876 | val loss 1.7670 acc 0.2601 bal_acc 0.3268 f1 0.2815 | attn(cnn=0.523, lstm=0.500, inter=0.912) | lr 5.00e-05
# Fold 2 | Epoch 014 | train loss 1.4598 acc 0.4550 bal_acc 0.4283 f1 0.4043 | val loss 1.9177 acc 0.2260 bal_acc 0.2973 f1 0.2474 | attn(cnn=0.528, lstm=0.500, inter=0.912) | lr 5.00e-05
# Fold 2 | Epoch 015 | train loss 1.4518 acc 0.4548 bal_acc 0.4324 f1 0.4065 | val loss 1.8826 acc 0.2431 bal_acc 0.3227 f1 0.2616 | attn(cnn=0.527, lstm=0.499, inter=0.917) | lr 5.00e-05
# Fold 2 | Epoch 016 | train loss 1.4461 acc 0.4529 bal_acc 0.4358 f1 0.4056 | val loss 1.9979 acc 0.2196 bal_acc 0.2956 f1 0.2381 | attn(cnn=0.531, lstm=0.497, inter=0.919) | lr 5.00e-05
# Fold 2 | Epoch 017 | train loss 1.4093 acc 0.4680 bal_acc 0.4502 f1 0.4198 | val loss 1.8887 acc 0.2473 bal_acc 0.3306 f1 0.2679 | attn(cnn=0.529, lstm=0.496, inter=0.923) | lr 2.50e-05
# Fold 2 | Epoch 018 | train loss 1.4078 acc 0.4559 bal_acc 0.4463 f1 0.4133 | val loss 1.9624 acc 0.2303 bal_acc 0.3068 f1 0.2465 | attn(cnn=0.529, lstm=0.495, inter=0.923) | lr 2.50e-05
# Fold 2 | Epoch 019 | train loss 1.3899 acc 0.4723 bal_acc 0.4533 f1 0.4215 | val loss 1.9061 acc 0.2495 bal_acc 0.3320 f1 0.2742 | attn(cnn=0.525, lstm=0.495, inter=0.925) | lr 2.50e-05
# Fold 2 | Epoch 020 | train loss 1.3848 acc 0.4763 bal_acc 0.4648 f1 0.4309 | val loss 2.0154 acc 0.2260 bal_acc 0.3051 f1 0.2400 | attn(cnn=0.530, lstm=0.494, inter=0.923) | lr 2.50e-05
# Fold 2 | Epoch 021 | train loss 1.3917 acc 0.4676 bal_acc 0.4516 f1 0.4187 | val loss 2.0656 acc 0.2154 bal_acc 0.2902 f1 0.2185 | attn(cnn=0.530, lstm=0.494, inter=0.923) | lr 2.50e-05
# Fold 2 | Epoch 022 | train loss 1.3769 acc 0.4732 bal_acc 0.4596 f1 0.4273 | val loss 2.0712 acc 0.2175 bal_acc 0.2931 f1 0.2255 | attn(cnn=0.526, lstm=0.494, inter=0.924) | lr 2.50e-05
# Fold 2 | Epoch 023 | train loss 1.3761 acc 0.4858 bal_acc 0.4685 f1 0.4359 | val loss 2.1096 acc 0.2196 bal_acc 0.2964 f1 0.2221 | attn(cnn=0.525, lstm=0.494, inter=0.924) | lr 2.50e-05
# Fold 2 | Epoch 024 | train loss 1.3706 acc 0.4784 bal_acc 0.4645 f1 0.4324 | val loss 2.1607 acc 0.2068 bal_acc 0.2803 f1 0.2136 | attn(cnn=0.521, lstm=0.494, inter=0.924) | lr 1.25e-05
# Fold 2 | Epoch 025 | train loss 1.3587 acc 0.4841 bal_acc 0.4769 f1 0.4411 | val loss 2.1317 acc 0.2111 bal_acc 0.2863 f1 0.2129 | attn(cnn=0.526, lstm=0.494, inter=0.924) | lr 1.25e-05
# Early stopping triggered.
#
# ========== Fold 3/10 ==========
# /home/rithik-tank/enter/envs/tf_gpu/lib/python3.10/site-packages/torch/nn/modules/rnn.py:1013: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   super().__init__("LSTM", *args, **kwargs)
# Fold 3 | Epoch 001 | train loss 1.8172 acc 0.1414 bal_acc 0.1698 f1 0.0826 | val loss 1.8514 acc 0.1151 bal_acc 0.1667 f1 0.0344 | attn(cnn=0.500, lstm=0.499, inter=0.502) | lr 5.00e-05
# Fold 3 | Epoch 002 | train loss 1.8149 acc 0.1495 bal_acc 0.1720 f1 0.0977 | val loss 1.8517 acc 0.1215 bal_acc 0.1692 f1 0.0396 | attn(cnn=0.500, lstm=0.499, inter=0.502) | lr 5.00e-05
# Fold 3 | Epoch 003 | train loss 1.8116 acc 0.1651 bal_acc 0.1978 f1 0.1200 | val loss 1.8511 acc 0.1301 bal_acc 0.1726 f1 0.0464 | attn(cnn=0.500, lstm=0.499, inter=0.503) | lr 5.00e-05
# Fold 3 | Epoch 004 | train loss 1.8067 acc 0.2136 bal_acc 0.2131 f1 0.1644 | val loss 1.8491 acc 0.1343 bal_acc 0.1743 f1 0.0497 | attn(cnn=0.499, lstm=0.499, inter=0.506) | lr 5.00e-05
# Fold 3 | Epoch 005 | train loss 1.7940 acc 0.2717 bal_acc 0.2327 f1 0.2119 | val loss 1.8446 acc 0.1407 bal_acc 0.1769 f1 0.0544 | attn(cnn=0.497, lstm=0.499, inter=0.517) | lr 5.00e-05
# Fold 3 | Epoch 006 | train loss 1.7726 acc 0.2856 bal_acc 0.2493 f1 0.2298 | val loss 1.8451 acc 0.1663 bal_acc 0.2074 f1 0.1077 | attn(cnn=0.498, lstm=0.500, inter=0.543) | lr 5.00e-05
# Fold 3 | Epoch 007 | train loss 1.7290 acc 0.3072 bal_acc 0.2674 f1 0.2512 | val loss 1.8144 acc 0.1983 bal_acc 0.2498 f1 0.1592 | attn(cnn=0.502, lstm=0.500, inter=0.607) | lr 5.00e-05
# Fold 3 | Epoch 008 | train loss 1.6790 acc 0.3110 bal_acc 0.2874 f1 0.2665 | val loss 1.7955 acc 0.2452 bal_acc 0.3128 f1 0.2080 | attn(cnn=0.502, lstm=0.502, inter=0.684) | lr 5.00e-05
# Fold 3 | Epoch 009 | train loss 1.6452 acc 0.3323 bal_acc 0.3068 f1 0.2851 | val loss 1.8306 acc 0.2217 bal_acc 0.2851 f1 0.1884 | attn(cnn=0.493, lstm=0.509, inter=0.754) | lr 5.00e-05
# Fold 3 | Epoch 010 | train loss 1.6155 acc 0.3321 bal_acc 0.3127 f1 0.2861 | val loss 1.7983 acc 0.2345 bal_acc 0.2988 f1 0.2080 | attn(cnn=0.496, lstm=0.513, inter=0.783) | lr 5.00e-05
# Fold 3 | Epoch 011 | train loss 1.5950 acc 0.3664 bal_acc 0.3431 f1 0.3190 | val loss 1.7716 acc 0.2580 bal_acc 0.3327 f1 0.2145 | attn(cnn=0.503, lstm=0.515, inter=0.798) | lr 5.00e-05
# Fold 3 | Epoch 012 | train loss 1.5877 acc 0.3631 bal_acc 0.3441 f1 0.3171 | val loss 1.7708 acc 0.2537 bal_acc 0.3265 f1 0.2144 | attn(cnn=0.502, lstm=0.515, inter=0.811) | lr 5.00e-05
# Fold 3 | Epoch 013 | train loss 1.5657 acc 0.3835 bal_acc 0.3606 f1 0.3375 | val loss 1.7800 acc 0.2601 bal_acc 0.3355 f1 0.2202 | attn(cnn=0.504, lstm=0.517, inter=0.822) | lr 5.00e-05
# Fold 3 | Epoch 014 | train loss 1.5562 acc 0.3785 bal_acc 0.3546 f1 0.3285 | val loss 1.7763 acc 0.2687 bal_acc 0.3479 f1 0.2425 | attn(cnn=0.501, lstm=0.518, inter=0.830) | lr 5.00e-05
# Fold 3 | Epoch 015 | train loss 1.5382 acc 0.3861 bal_acc 0.3731 f1 0.3443 | val loss 1.7576 acc 0.2751 bal_acc 0.3578 f1 0.2435 | attn(cnn=0.506, lstm=0.518, inter=0.839) | lr 5.00e-05
# Fold 3 | Epoch 016 | train loss 1.5372 acc 0.3934 bal_acc 0.3789 f1 0.3510 | val loss 1.7977 acc 0.2665 bal_acc 0.3451 f1 0.2435 | attn(cnn=0.498, lstm=0.517, inter=0.846) | lr 5.00e-05
# Fold 3 | Epoch 017 | train loss 1.5193 acc 0.4024 bal_acc 0.3889 f1 0.3606 | val loss 1.7508 acc 0.2814 bal_acc 0.3648 f1 0.2482 | attn(cnn=0.506, lstm=0.518, inter=0.856) | lr 5.00e-05
# Fold 3 | Epoch 018 | train loss 1.5168 acc 0.4036 bal_acc 0.3938 f1 0.3662 | val loss 1.7135 acc 0.2878 bal_acc 0.3721 f1 0.2529 | attn(cnn=0.510, lstm=0.519, inter=0.864) | lr 5.00e-05
# Fold 3 | Epoch 019 | train loss 1.5009 acc 0.4157 bal_acc 0.3951 f1 0.3684 | val loss 1.8111 acc 0.2729 bal_acc 0.3567 f1 0.2390 | attn(cnn=0.509, lstm=0.519, inter=0.867) | lr 5.00e-05
# Fold 3 | Epoch 020 | train loss 1.4850 acc 0.4098 bal_acc 0.4148 f1 0.3752 | val loss 1.7427 acc 0.2814 bal_acc 0.3627 f1 0.2334 | attn(cnn=0.516, lstm=0.519, inter=0.875) | lr 5.00e-05
# Fold 3 | Epoch 021 | train loss 1.4644 acc 0.4422 bal_acc 0.4395 f1 0.4045 | val loss 1.9673 acc 0.2324 bal_acc 0.3074 f1 0.2130 | attn(cnn=0.497, lstm=0.520, inter=0.882) | lr 5.00e-05
# Fold 3 | Epoch 022 | train loss 1.4549 acc 0.4315 bal_acc 0.4340 f1 0.3947 | val loss 1.9917 acc 0.2217 bal_acc 0.2965 f1 0.1840 | attn(cnn=0.501, lstm=0.521, inter=0.886) | lr 5.00e-05
# Fold 3 | Epoch 023 | train loss 1.4457 acc 0.4365 bal_acc 0.4367 f1 0.3985 | val loss 1.8708 acc 0.2644 bal_acc 0.3469 f1 0.2138 | attn(cnn=0.521, lstm=0.522, inter=0.891) | lr 5.00e-05
# Fold 3 | Epoch 024 | train loss 1.4245 acc 0.4422 bal_acc 0.4448 f1 0.4062 | val loss 1.8966 acc 0.2217 bal_acc 0.3029 f1 0.1818 | attn(cnn=0.539, lstm=0.523, inter=0.896) | lr 5.00e-05
# Fold 3 | Epoch 025 | train loss 1.3960 acc 0.4545 bal_acc 0.4652 f1 0.4217 | val loss 2.1581 acc 0.2154 bal_acc 0.3002 f1 0.1587 | attn(cnn=0.528, lstm=0.524, inter=0.896) | lr 2.50e-05
# Fold 3 | Epoch 026 | train loss 1.3907 acc 0.4559 bal_acc 0.4649 f1 0.4221 | val loss 1.9257 acc 0.2409 bal_acc 0.3232 f1 0.1931 | attn(cnn=0.531, lstm=0.524, inter=0.902) | lr 2.50e-05
# Fold 3 | Epoch 027 | train loss 1.3906 acc 0.4526 bal_acc 0.4642 f1 0.4177 | val loss 1.8533 acc 0.2388 bal_acc 0.3181 f1 0.1937 | attn(cnn=0.534, lstm=0.525, inter=0.903) | lr 2.50e-05
# Fold 3 | Epoch 028 | train loss 1.3830 acc 0.4616 bal_acc 0.4628 f1 0.4213 | val loss 1.9568 acc 0.2473 bal_acc 0.3300 f1 0.1976 | attn(cnn=0.530, lstm=0.525, inter=0.904) | lr 2.50e-05
# Fold 3 | Epoch 029 | train loss 1.3748 acc 0.4628 bal_acc 0.4772 f1 0.4317 | val loss 2.0403 acc 0.2388 bal_acc 0.3246 f1 0.1890 | attn(cnn=0.528, lstm=0.525, inter=0.906) | lr 2.50e-05
# Fold 3 | Epoch 030 | train loss 1.3666 acc 0.4680 bal_acc 0.4825 f1 0.4334 | val loss 2.0307 acc 0.2111 bal_acc 0.2859 f1 0.1683 | attn(cnn=0.540, lstm=0.526, inter=0.908) | lr 2.50e-05
# Fold 3 | Epoch 031 | train loss 1.3675 acc 0.4659 bal_acc 0.4677 f1 0.4255 | val loss 1.9958 acc 0.2175 bal_acc 0.2906 f1 0.1757 | attn(cnn=0.546, lstm=0.526, inter=0.910) | lr 2.50e-05
# Fold 3 | Epoch 032 | train loss 1.3669 acc 0.4557 bal_acc 0.4643 f1 0.4231 | val loss 2.0230 acc 0.2473 bal_acc 0.3303 f1 0.1962 | attn(cnn=0.531, lstm=0.526, inter=0.910) | lr 1.25e-05
# Fold 3 | Epoch 033 | train loss 1.3478 acc 0.4716 bal_acc 0.4858 f1 0.4403 | val loss 2.0001 acc 0.2260 bal_acc 0.3005 f1 0.1850 | attn(cnn=0.540, lstm=0.526, inter=0.911) | lr 1.25e-05
# Early stopping triggered.
#
# ========== Fold 4/10 ==========
# /home/rithik-tank/enter/envs/tf_gpu/lib/python3.10/site-packages/torch/nn/modules/rnn.py:1013: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   super().__init__("LSTM", *args, **kwargs)
# Fold 4 | Epoch 001 | train loss 1.8163 acc 0.1191 bal_acc 0.1696 f1 0.0746 | val loss 1.8450 acc 0.1237 bal_acc 0.1820 f1 0.0586 | attn(cnn=0.501, lstm=0.497, inter=0.501) | lr 5.00e-05
# Fold 4 | Epoch 002 | train loss 1.8134 acc 0.1542 bal_acc 0.1998 f1 0.1192 | val loss 1.8431 acc 0.1748 bal_acc 0.2560 f1 0.0970 | attn(cnn=0.500, lstm=0.497, inter=0.502) | lr 5.00e-05
# Fold 4 | Epoch 003 | train loss 1.8111 acc 0.2153 bal_acc 0.2168 f1 0.1828 | val loss 1.8396 acc 0.1855 bal_acc 0.2624 f1 0.1047 | attn(cnn=0.499, lstm=0.497, inter=0.504) | lr 5.00e-05
# Fold 4 | Epoch 004 | train loss 1.8049 acc 0.2956 bal_acc 0.2450 f1 0.2300 | val loss 1.8354 acc 0.2004 bal_acc 0.2663 f1 0.1170 | attn(cnn=0.498, lstm=0.497, inter=0.508) | lr 5.00e-05
# Fold 4 | Epoch 005 | train loss 1.7929 acc 0.2894 bal_acc 0.2405 f1 0.2223 | val loss 1.8237 acc 0.2111 bal_acc 0.2659 f1 0.1251 | attn(cnn=0.495, lstm=0.497, inter=0.524) | lr 5.00e-05
# Fold 4 | Epoch 006 | train loss 1.7555 acc 0.3335 bal_acc 0.2676 f1 0.2502 | val loss 1.8302 acc 0.1983 bal_acc 0.2604 f1 0.1472 | attn(cnn=0.484, lstm=0.497, inter=0.573) | lr 5.00e-05
# Fold 4 | Epoch 007 | train loss 1.6902 acc 0.3449 bal_acc 0.2882 f1 0.2757 | val loss 1.8765 acc 0.1748 bal_acc 0.2379 f1 0.1213 | attn(cnn=0.471, lstm=0.497, inter=0.639) | lr 5.00e-05
# Fold 4 | Epoch 008 | train loss 1.6390 acc 0.3515 bal_acc 0.3096 f1 0.2930 | val loss 1.8959 acc 0.1855 bal_acc 0.2559 f1 0.1395 | attn(cnn=0.471, lstm=0.499, inter=0.721) | lr 5.00e-05
# Fold 4 | Epoch 009 | train loss 1.6039 acc 0.3832 bal_acc 0.3226 f1 0.3125 | val loss 1.8861 acc 0.1855 bal_acc 0.2539 f1 0.1292 | attn(cnn=0.469, lstm=0.504, inter=0.762) | lr 5.00e-05
# Fold 4 | Epoch 010 | train loss 1.5789 acc 0.3837 bal_acc 0.3269 f1 0.3183 | val loss 2.0244 acc 0.1748 bal_acc 0.2444 f1 0.1432 | attn(cnn=0.463, lstm=0.508, inter=0.770) | lr 5.00e-05
# Fold 4 | Epoch 011 | train loss 1.5662 acc 0.3937 bal_acc 0.3444 f1 0.3317 | val loss 1.9891 acc 0.1919 bal_acc 0.2645 f1 0.1673 | attn(cnn=0.463, lstm=0.514, inter=0.801) | lr 5.00e-05
# Fold 4 | Epoch 012 | train loss 1.5487 acc 0.4069 bal_acc 0.3616 f1 0.3490 | val loss 1.8364 acc 0.1983 bal_acc 0.2622 f1 0.1777 | attn(cnn=0.463, lstm=0.524, inter=0.846) | lr 2.50e-05
# Fold 4 | Epoch 013 | train loss 1.5410 acc 0.4259 bal_acc 0.3649 f1 0.3532 | val loss 2.0298 acc 0.1770 bal_acc 0.2420 f1 0.1412 | attn(cnn=0.460, lstm=0.525, inter=0.839) | lr 2.50e-05
# Fold 4 | Epoch 014 | train loss 1.5326 acc 0.4166 bal_acc 0.3619 f1 0.3483 | val loss 1.9498 acc 0.1834 bal_acc 0.2516 f1 0.1508 | attn(cnn=0.462, lstm=0.527, inter=0.850) | lr 2.50e-05
# Fold 4 | Epoch 015 | train loss 1.5216 acc 0.4098 bal_acc 0.3676 f1 0.3516 | val loss 1.9783 acc 0.1812 bal_acc 0.2483 f1 0.1456 | attn(cnn=0.461, lstm=0.529, inter=0.856) | lr 2.50e-05
# Fold 4 | Epoch 016 | train loss 1.5109 acc 0.4282 bal_acc 0.3778 f1 0.3650 | val loss 1.9841 acc 0.1855 bal_acc 0.2521 f1 0.1531 | attn(cnn=0.459, lstm=0.531, inter=0.863) | lr 2.50e-05
# Fold 4 | Epoch 017 | train loss 1.5152 acc 0.4135 bal_acc 0.3673 f1 0.3508 | val loss 1.9123 acc 0.1812 bal_acc 0.2388 f1 0.1453 | attn(cnn=0.461, lstm=0.532, inter=0.872) | lr 2.50e-05
# Fold 4 | Epoch 018 | train loss 1.4874 acc 0.4320 bal_acc 0.3892 f1 0.3704 | val loss 1.9657 acc 0.1919 bal_acc 0.2591 f1 0.1581 | attn(cnn=0.457, lstm=0.533, inter=0.874) | lr 2.50e-05
# Fold 4 | Epoch 019 | train loss 1.4966 acc 0.4387 bal_acc 0.3924 f1 0.3754 | val loss 2.0038 acc 0.1898 bal_acc 0.2560 f1 0.1566 | attn(cnn=0.457, lstm=0.534, inter=0.877) | lr 1.25e-05
# Fold 4 | Epoch 020 | train loss 1.4883 acc 0.4209 bal_acc 0.3850 f1 0.3640 | val loss 1.9530 acc 0.1898 bal_acc 0.2561 f1 0.1526 | attn(cnn=0.459, lstm=0.535, inter=0.881) | lr 1.25e-05
# Early stopping triggered.
#
# ========== Fold 5/10 ==========
# /home/rithik-tank/enter/envs/tf_gpu/lib/python3.10/site-packages/torch/nn/modules/rnn.py:1013: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   super().__init__("LSTM", *args, **kwargs)
# Fold 5 | Epoch 001 | train loss 1.8165 acc 0.1222 bal_acc 0.1758 f1 0.0846 | val loss 1.8495 acc 0.1301 bal_acc 0.1903 f1 0.0658 | attn(cnn=0.503, lstm=0.500, inter=0.500) | lr 5.00e-05
# Fold 5 | Epoch 002 | train loss 1.8143 acc 0.1319 bal_acc 0.1891 f1 0.0957 | val loss 1.8478 acc 0.1471 bal_acc 0.2121 f1 0.0792 | attn(cnn=0.503, lstm=0.500, inter=0.501) | lr 5.00e-05
# Fold 5 | Epoch 003 | train loss 1.8114 acc 0.1478 bal_acc 0.2080 f1 0.1322 | val loss 1.8456 acc 0.1365 bal_acc 0.1955 f1 0.0746 | attn(cnn=0.503, lstm=0.500, inter=0.502) | lr 5.00e-05
# Fold 5 | Epoch 004 | train loss 1.8063 acc 0.1649 bal_acc 0.2212 f1 0.1641 | val loss 1.8427 acc 0.1322 bal_acc 0.1874 f1 0.0909 | attn(cnn=0.502, lstm=0.500, inter=0.506) | lr 5.00e-05
# Fold 5 | Epoch 005 | train loss 1.7994 acc 0.1874 bal_acc 0.2504 f1 0.1870 | val loss 1.8404 acc 0.1407 bal_acc 0.1989 f1 0.1060 | attn(cnn=0.502, lstm=0.500, inter=0.516) | lr 5.00e-05
# Fold 5 | Epoch 006 | train loss 1.7840 acc 0.2205 bal_acc 0.2776 f1 0.2137 | val loss 1.8312 acc 0.1386 bal_acc 0.1967 f1 0.1203 | attn(cnn=0.500, lstm=0.500, inter=0.541) | lr 5.00e-05
# Fold 5 | Epoch 007 | train loss 1.7540 acc 0.2347 bal_acc 0.2869 f1 0.2308 | val loss 1.8181 acc 0.1642 bal_acc 0.2335 f1 0.1630 | attn(cnn=0.498, lstm=0.500, inter=0.590) | lr 5.00e-05
# Fold 5 | Epoch 008 | train loss 1.7069 acc 0.2577 bal_acc 0.3113 f1 0.2604 | val loss 1.8069 acc 0.1812 bal_acc 0.2555 f1 0.1800 | attn(cnn=0.501, lstm=0.501, inter=0.662) | lr 5.00e-05
# Fold 5 | Epoch 009 | train loss 1.6608 acc 0.2707 bal_acc 0.3310 f1 0.2757 | val loss 1.8681 acc 0.1450 bal_acc 0.2086 f1 0.1078 | attn(cnn=0.487, lstm=0.504, inter=0.729) | lr 5.00e-05
# Fold 5 | Epoch 010 | train loss 1.6252 acc 0.2999 bal_acc 0.3487 f1 0.3008 | val loss 1.8472 acc 0.1748 bal_acc 0.2476 f1 0.1495 | attn(cnn=0.493, lstm=0.515, inter=0.836) | lr 5.00e-05
# Fold 5 | Epoch 011 | train loss 1.5920 acc 0.3321 bal_acc 0.3631 f1 0.3232 | val loss 1.8703 acc 0.1791 bal_acc 0.2548 f1 0.1790 | attn(cnn=0.485, lstm=0.526, inter=0.886) | lr 5.00e-05
# Fold 5 | Epoch 012 | train loss 1.5639 acc 0.3513 bal_acc 0.3761 f1 0.3388 | val loss 1.8697 acc 0.2090 bal_acc 0.2953 f1 0.2057 | attn(cnn=0.491, lstm=0.530, inter=0.909) | lr 5.00e-05
# Fold 5 | Epoch 013 | train loss 1.5504 acc 0.3700 bal_acc 0.3894 f1 0.3536 | val loss 1.8238 acc 0.2260 bal_acc 0.3161 f1 0.2425 | attn(cnn=0.496, lstm=0.535, inter=0.919) | lr 5.00e-05
# Fold 5 | Epoch 014 | train loss 1.5259 acc 0.3685 bal_acc 0.3869 f1 0.3498 | val loss 1.8251 acc 0.2303 bal_acc 0.3210 f1 0.2422 | attn(cnn=0.492, lstm=0.540, inter=0.928) | lr 5.00e-05
# Fold 5 | Epoch 015 | train loss 1.4905 acc 0.4105 bal_acc 0.4163 f1 0.3847 | val loss 1.8314 acc 0.2217 bal_acc 0.3060 f1 0.2259 | attn(cnn=0.496, lstm=0.545, inter=0.938) | lr 2.50e-05
# Fold 5 | Epoch 016 | train loss 1.4743 acc 0.4027 bal_acc 0.4175 f1 0.3806 | val loss 1.8811 acc 0.2217 bal_acc 0.3065 f1 0.2424 | attn(cnn=0.486, lstm=0.547, inter=0.941) | lr 2.50e-05
# Fold 5 | Epoch 017 | train loss 1.4632 acc 0.4289 bal_acc 0.4360 f1 0.4022 | val loss 1.9043 acc 0.2154 bal_acc 0.3036 f1 0.2358 | attn(cnn=0.487, lstm=0.549, inter=0.944) | lr 2.50e-05
# Fold 5 | Epoch 018 | train loss 1.4483 acc 0.4197 bal_acc 0.4369 f1 0.3985 | val loss 1.9468 acc 0.2154 bal_acc 0.3036 f1 0.2389 | attn(cnn=0.483, lstm=0.551, inter=0.944) | lr 2.50e-05
# Fold 5 | Epoch 019 | train loss 1.4458 acc 0.4292 bal_acc 0.4391 f1 0.4021 | val loss 1.9184 acc 0.2175 bal_acc 0.3046 f1 0.2398 | attn(cnn=0.484, lstm=0.553, inter=0.946) | lr 2.50e-05
# Fold 5 | Epoch 020 | train loss 1.4330 acc 0.4188 bal_acc 0.4315 f1 0.3932 | val loss 1.9571 acc 0.2281 bal_acc 0.3205 f1 0.2535 | attn(cnn=0.475, lstm=0.555, inter=0.948) | lr 2.50e-05
# Fold 5 | Epoch 021 | train loss 1.4224 acc 0.4365 bal_acc 0.4434 f1 0.4072 | val loss 1.9021 acc 0.2303 bal_acc 0.3205 f1 0.2494 | attn(cnn=0.485, lstm=0.556, inter=0.950) | lr 2.50e-05
# Fold 5 | Epoch 022 | train loss 1.4305 acc 0.4413 bal_acc 0.4533 f1 0.4117 | val loss 1.9543 acc 0.2111 bal_acc 0.2955 f1 0.2333 | attn(cnn=0.481, lstm=0.557, inter=0.951) | lr 1.25e-05
# Fold 5 | Epoch 023 | train loss 1.4173 acc 0.4522 bal_acc 0.4549 f1 0.4183 | val loss 1.9870 acc 0.2068 bal_acc 0.2919 f1 0.2367 | attn(cnn=0.477, lstm=0.558, inter=0.953) | lr 1.25e-05
# Early stopping triggered.
#
# ========== Fold 6/10 ==========
# /home/rithik-tank/enter/envs/tf_gpu/lib/python3.10/site-packages/torch/nn/modules/rnn.py:1013: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   super().__init__("LSTM", *args, **kwargs)
# Fold 6 | Epoch 001 | train loss 1.8152 acc 0.2518 bal_acc 0.1821 f1 0.1580 | val loss 1.8370 acc 0.4179 bal_acc 0.1667 f1 0.0982 | attn(cnn=0.498, lstm=0.501, inter=0.499) | lr 5.00e-05
# Fold 6 | Epoch 002 | train loss 1.8140 acc 0.2752 bal_acc 0.2017 f1 0.1922 | val loss 1.8368 acc 0.4264 bal_acc 0.2098 f1 0.1663 | attn(cnn=0.498, lstm=0.501, inter=0.500) | lr 5.00e-05
# Fold 6 | Epoch 003 | train loss 1.8102 acc 0.2646 bal_acc 0.2062 f1 0.1966 | val loss 1.8349 acc 0.3092 bal_acc 0.2270 f1 0.1673 | attn(cnn=0.498, lstm=0.501, inter=0.501) | lr 5.00e-05
# Fold 6 | Epoch 004 | train loss 1.8049 acc 0.3081 bal_acc 0.2449 f1 0.2369 | val loss 1.8341 acc 0.1898 bal_acc 0.2283 f1 0.1306 | attn(cnn=0.499, lstm=0.501, inter=0.505) | lr 5.00e-05
# Fold 6 | Epoch 005 | train loss 1.7900 acc 0.2579 bal_acc 0.2536 f1 0.2299 | val loss 1.8209 acc 0.2239 bal_acc 0.2626 f1 0.1858 | attn(cnn=0.500, lstm=0.501, inter=0.521) | lr 5.00e-05
# Fold 6 | Epoch 006 | train loss 1.7371 acc 0.2809 bal_acc 0.2636 f1 0.2461 | val loss 1.7913 acc 0.2196 bal_acc 0.2798 f1 0.1772 | attn(cnn=0.505, lstm=0.501, inter=0.583) | lr 5.00e-05
# Fold 6 | Epoch 007 | train loss 1.6625 acc 0.3096 bal_acc 0.2824 f1 0.2623 | val loss 1.7734 acc 0.2303 bal_acc 0.2751 f1 0.1871 | attn(cnn=0.502, lstm=0.501, inter=0.625) | lr 5.00e-05
# Fold 6 | Epoch 008 | train loss 1.6413 acc 0.3330 bal_acc 0.3037 f1 0.2882 | val loss 1.7423 acc 0.2452 bal_acc 0.3044 f1 0.2158 | attn(cnn=0.499, lstm=0.501, inter=0.666) | lr 5.00e-05
# Fold 6 | Epoch 009 | train loss 1.6218 acc 0.3323 bal_acc 0.3028 f1 0.2863 | val loss 1.6616 acc 0.3177 bal_acc 0.3050 f1 0.2654 | attn(cnn=0.496, lstm=0.502, inter=0.715) | lr 5.00e-05
# Fold 6 | Epoch 010 | train loss 1.6025 acc 0.3524 bal_acc 0.3186 f1 0.3020 | val loss 1.6549 acc 0.3028 bal_acc 0.3260 f1 0.2637 | attn(cnn=0.496, lstm=0.503, inter=0.742) | lr 5.00e-05
# Fold 6 | Epoch 011 | train loss 1.5836 acc 0.3669 bal_acc 0.3253 f1 0.3135 | val loss 1.7376 acc 0.2644 bal_acc 0.3378 f1 0.2659 | attn(cnn=0.494, lstm=0.505, inter=0.759) | lr 5.00e-05
# Fold 6 | Epoch 012 | train loss 1.5723 acc 0.3752 bal_acc 0.3497 f1 0.3283 | val loss 1.7583 acc 0.2473 bal_acc 0.3183 f1 0.2469 | attn(cnn=0.493, lstm=0.508, inter=0.777) | lr 5.00e-05
# Fold 6 | Epoch 013 | train loss 1.5598 acc 0.3747 bal_acc 0.3431 f1 0.3254 | val loss 1.6747 acc 0.2964 bal_acc 0.3591 f1 0.2925 | attn(cnn=0.492, lstm=0.511, inter=0.812) | lr 5.00e-05
# Fold 6 | Epoch 014 | train loss 1.5367 acc 0.3979 bal_acc 0.3700 f1 0.3517 | val loss 1.6728 acc 0.3006 bal_acc 0.3732 f1 0.2971 | attn(cnn=0.490, lstm=0.513, inter=0.832) | lr 5.00e-05
# Fold 6 | Epoch 015 | train loss 1.5371 acc 0.3887 bal_acc 0.3582 f1 0.3391 | val loss 1.7060 acc 0.2729 bal_acc 0.3423 f1 0.2759 | attn(cnn=0.490, lstm=0.513, inter=0.837) | lr 5.00e-05
# Fold 6 | Epoch 016 | train loss 1.5170 acc 0.3965 bal_acc 0.3723 f1 0.3524 | val loss 1.6807 acc 0.2921 bal_acc 0.3614 f1 0.2925 | attn(cnn=0.488, lstm=0.515, inter=0.852) | lr 5.00e-05
# Fold 6 | Epoch 017 | train loss 1.5101 acc 0.4003 bal_acc 0.3843 f1 0.3618 | val loss 1.6264 acc 0.3241 bal_acc 0.3835 f1 0.3153 | attn(cnn=0.487, lstm=0.516, inter=0.863) | lr 5.00e-05
# Fold 6 | Epoch 018 | train loss 1.4925 acc 0.4266 bal_acc 0.3954 f1 0.3753 | val loss 1.6469 acc 0.3092 bal_acc 0.3711 f1 0.3029 | attn(cnn=0.486, lstm=0.516, inter=0.871) | lr 5.00e-05
# Fold 6 | Epoch 019 | train loss 1.4816 acc 0.4083 bal_acc 0.3889 f1 0.3661 | val loss 1.6651 acc 0.3092 bal_acc 0.3811 f1 0.3056 | attn(cnn=0.486, lstm=0.516, inter=0.876) | lr 5.00e-05
# Fold 6 | Epoch 020 | train loss 1.4690 acc 0.4138 bal_acc 0.4035 f1 0.3757 | val loss 1.6232 acc 0.3028 bal_acc 0.3624 f1 0.3015 | attn(cnn=0.487, lstm=0.518, inter=0.881) | lr 5.00e-05
# Fold 6 | Epoch 021 | train loss 1.4548 acc 0.4254 bal_acc 0.4148 f1 0.3865 | val loss 1.7100 acc 0.2665 bal_acc 0.3387 f1 0.2725 | attn(cnn=0.486, lstm=0.517, inter=0.886) | lr 5.00e-05
# Fold 6 | Epoch 022 | train loss 1.4495 acc 0.4185 bal_acc 0.4134 f1 0.3835 | val loss 1.6191 acc 0.3006 bal_acc 0.3573 f1 0.2992 | attn(cnn=0.487, lstm=0.518, inter=0.895) | lr 5.00e-05
# Fold 6 | Epoch 023 | train loss 1.4293 acc 0.4434 bal_acc 0.4349 f1 0.4050 | val loss 1.5709 acc 0.3198 bal_acc 0.3954 f1 0.3206 | attn(cnn=0.488, lstm=0.518, inter=0.900) | lr 5.00e-05
# Fold 6 | Epoch 024 | train loss 1.4183 acc 0.4387 bal_acc 0.4354 f1 0.4023 | val loss 1.4837 acc 0.3412 bal_acc 0.4122 f1 0.3384 | attn(cnn=0.490, lstm=0.519, inter=0.907) | lr 5.00e-05
# Fold 6 | Epoch 025 | train loss 1.4061 acc 0.4529 bal_acc 0.4520 f1 0.4160 | val loss 1.5227 acc 0.3369 bal_acc 0.4104 f1 0.3343 | attn(cnn=0.489, lstm=0.520, inter=0.911) | lr 5.00e-05
# Fold 6 | Epoch 026 | train loss 1.3968 acc 0.4358 bal_acc 0.4445 f1 0.4069 | val loss 1.5261 acc 0.3220 bal_acc 0.3952 f1 0.3205 | attn(cnn=0.492, lstm=0.520, inter=0.914) | lr 5.00e-05
# Fold 6 | Epoch 027 | train loss 1.3754 acc 0.4548 bal_acc 0.4660 f1 0.4260 | val loss 1.4874 acc 0.3348 bal_acc 0.4111 f1 0.3316 | attn(cnn=0.494, lstm=0.521, inter=0.917) | lr 5.00e-05
# Fold 6 | Epoch 028 | train loss 1.3659 acc 0.4600 bal_acc 0.4678 f1 0.4290 | val loss 1.5522 acc 0.3220 bal_acc 0.4068 f1 0.3274 | attn(cnn=0.492, lstm=0.522, inter=0.920) | lr 5.00e-05
# Fold 6 | Epoch 029 | train loss 1.3482 acc 0.4543 bal_acc 0.4662 f1 0.4213 | val loss 1.4870 acc 0.3241 bal_acc 0.4039 f1 0.3142 | attn(cnn=0.496, lstm=0.523, inter=0.925) | lr 5.00e-05
# Fold 6 | Epoch 030 | train loss 1.3300 acc 0.4699 bal_acc 0.4856 f1 0.4420 | val loss 1.5013 acc 0.3284 bal_acc 0.4126 f1 0.3257 | attn(cnn=0.496, lstm=0.523, inter=0.926) | lr 5.00e-05
# Fold 6 | Epoch 031 | train loss 1.3183 acc 0.4768 bal_acc 0.4896 f1 0.4472 | val loss 1.4212 acc 0.3603 bal_acc 0.4390 f1 0.3629 | attn(cnn=0.498, lstm=0.524, inter=0.929) | lr 5.00e-05
# Fold 6 | Epoch 032 | train loss 1.3132 acc 0.4694 bal_acc 0.4880 f1 0.4391 | val loss 1.4129 acc 0.3348 bal_acc 0.4076 f1 0.3150 | attn(cnn=0.502, lstm=0.524, inter=0.931) | lr 5.00e-05
# Fold 6 | Epoch 033 | train loss 1.3030 acc 0.4744 bal_acc 0.4952 f1 0.4471 | val loss 1.4223 acc 0.3582 bal_acc 0.4352 f1 0.3495 | attn(cnn=0.499, lstm=0.524, inter=0.931) | lr 5.00e-05
# Fold 6 | Epoch 034 | train loss 1.2796 acc 0.4929 bal_acc 0.5089 f1 0.4610 | val loss 1.4302 acc 0.3497 bal_acc 0.4295 f1 0.3512 | attn(cnn=0.501, lstm=0.526, inter=0.934) | lr 5.00e-05
# Fold 6 | Epoch 035 | train loss 1.2989 acc 0.4938 bal_acc 0.5134 f1 0.4675 | val loss 1.5739 acc 0.3049 bal_acc 0.3919 f1 0.3110 | attn(cnn=0.501, lstm=0.526, inter=0.930) | lr 5.00e-05
# Fold 6 | Epoch 036 | train loss 1.2832 acc 0.4813 bal_acc 0.4999 f1 0.4494 | val loss 1.4172 acc 0.3518 bal_acc 0.4394 f1 0.3634 | attn(cnn=0.504, lstm=0.528, inter=0.934) | lr 5.00e-05
# Fold 6 | Epoch 037 | train loss 1.2722 acc 0.4934 bal_acc 0.5076 f1 0.4623 | val loss 1.4516 acc 0.3348 bal_acc 0.4214 f1 0.3392 | attn(cnn=0.503, lstm=0.529, inter=0.934) | lr 5.00e-05
# Fold 6 | Epoch 038 | train loss 1.2645 acc 0.4983 bal_acc 0.5151 f1 0.4664 | val loss 1.4745 acc 0.3433 bal_acc 0.4359 f1 0.3507 | attn(cnn=0.501, lstm=0.530, inter=0.935) | lr 5.00e-05
# Fold 6 | Epoch 039 | train loss 1.2538 acc 0.5019 bal_acc 0.5233 f1 0.4754 | val loss 1.4194 acc 0.3454 bal_acc 0.4300 f1 0.3509 | attn(cnn=0.506, lstm=0.530, inter=0.934) | lr 2.50e-05
# Fold 6 | Epoch 040 | train loss 1.2358 acc 0.5220 bal_acc 0.5392 f1 0.4933 | val loss 1.4810 acc 0.3156 bal_acc 0.4047 f1 0.3180 | attn(cnn=0.506, lstm=0.530, inter=0.933) | lr 2.50e-05
# Fold 6 | Epoch 041 | train loss 1.2319 acc 0.5116 bal_acc 0.5371 f1 0.4870 | val loss 1.4652 acc 0.3305 bal_acc 0.4174 f1 0.3353 | attn(cnn=0.505, lstm=0.530, inter=0.933) | lr 2.50e-05
# Fold 6 | Epoch 042 | train loss 1.2274 acc 0.5173 bal_acc 0.5357 f1 0.4868 | val loss 1.4586 acc 0.3326 bal_acc 0.4203 f1 0.3330 | attn(cnn=0.505, lstm=0.530, inter=0.933) | lr 2.50e-05
# Fold 6 | Epoch 043 | train loss 1.2330 acc 0.5147 bal_acc 0.5392 f1 0.4900 | val loss 1.3920 acc 0.3689 bal_acc 0.4617 f1 0.3770 | attn(cnn=0.504, lstm=0.531, inter=0.936) | lr 2.50e-05
# Fold 6 | Epoch 044 | train loss 1.2198 acc 0.5270 bal_acc 0.5477 f1 0.4989 | val loss 1.4163 acc 0.3518 bal_acc 0.4412 f1 0.3573 | attn(cnn=0.505, lstm=0.531, inter=0.935) | lr 2.50e-05
# Fold 6 | Epoch 045 | train loss 1.2231 acc 0.5097 bal_acc 0.5306 f1 0.4822 | val loss 1.4296 acc 0.3475 bal_acc 0.4355 f1 0.3592 | attn(cnn=0.505, lstm=0.531, inter=0.935) | lr 2.50e-05
# Fold 6 | Epoch 046 | train loss 1.2009 acc 0.5324 bal_acc 0.5497 f1 0.4999 | val loss 1.4472 acc 0.3326 bal_acc 0.4159 f1 0.3323 | attn(cnn=0.506, lstm=0.531, inter=0.935) | lr 2.50e-05
# Fold 6 | Epoch 047 | train loss 1.1988 acc 0.5365 bal_acc 0.5521 f1 0.5072 | val loss 1.4142 acc 0.3497 bal_acc 0.4364 f1 0.3574 | attn(cnn=0.504, lstm=0.532, inter=0.937) | lr 2.50e-05
# Fold 6 | Epoch 048 | train loss 1.2076 acc 0.5251 bal_acc 0.5512 f1 0.4988 | val loss 1.4593 acc 0.3284 bal_acc 0.4167 f1 0.3341 | attn(cnn=0.503, lstm=0.532, inter=0.937) | lr 2.50e-05
# Fold 6 | Epoch 049 | train loss 1.2144 acc 0.5315 bal_acc 0.5532 f1 0.5023 | val loss 1.4097 acc 0.3497 bal_acc 0.4366 f1 0.3651 | attn(cnn=0.505, lstm=0.532, inter=0.937) | lr 2.50e-05
# Fold 6 | Epoch 050 | train loss 1.2030 acc 0.5334 bal_acc 0.5622 f1 0.5115 | val loss 1.4158 acc 0.3561 bal_acc 0.4393 f1 0.3717 | attn(cnn=0.503, lstm=0.533, inter=0.938) | lr 1.25e-05
# Fold 6 | Epoch 051 | train loss 1.1940 acc 0.5474 bal_acc 0.5637 f1 0.5181 | val loss 1.3712 acc 0.3838 bal_acc 0.4726 f1 0.4040 | attn(cnn=0.502, lstm=0.533, inter=0.939) | lr 1.25e-05
# Fold 6 | Epoch 052 | train loss 1.1776 acc 0.5417 bal_acc 0.5693 f1 0.5166 | val loss 1.3929 acc 0.3774 bal_acc 0.4675 f1 0.3938 | attn(cnn=0.502, lstm=0.533, inter=0.939) | lr 1.25e-05
# Fold 6 | Epoch 053 | train loss 1.1732 acc 0.5445 bal_acc 0.5593 f1 0.5153 | val loss 1.3878 acc 0.3689 bal_acc 0.4598 f1 0.3867 | attn(cnn=0.503, lstm=0.533, inter=0.940) | lr 1.25e-05
# Fold 6 | Epoch 054 | train loss 1.1842 acc 0.5407 bal_acc 0.5674 f1 0.5167 | val loss 1.4309 acc 0.3454 bal_acc 0.4367 f1 0.3553 | attn(cnn=0.503, lstm=0.533, inter=0.940) | lr 1.25e-05
# Fold 6 | Epoch 055 | train loss 1.1577 acc 0.5673 bal_acc 0.5869 f1 0.5384 | val loss 1.4007 acc 0.3689 bal_acc 0.4596 f1 0.3872 | attn(cnn=0.503, lstm=0.534, inter=0.940) | lr 1.25e-05
# Fold 6 | Epoch 056 | train loss 1.1771 acc 0.5547 bal_acc 0.5776 f1 0.5290 | val loss 1.3846 acc 0.3817 bal_acc 0.4735 f1 0.4000 | attn(cnn=0.502, lstm=0.534, inter=0.940) | lr 1.25e-05
# Fold 6 | Epoch 057 | train loss 1.1661 acc 0.5531 bal_acc 0.5694 f1 0.5222 | val loss 1.3876 acc 0.3774 bal_acc 0.4698 f1 0.3977 | attn(cnn=0.503, lstm=0.534, inter=0.940) | lr 1.25e-05
# Fold 6 | Epoch 058 | train loss 1.1837 acc 0.5429 bal_acc 0.5655 f1 0.5140 | val loss 1.3875 acc 0.3731 bal_acc 0.4658 f1 0.3913 | attn(cnn=0.502, lstm=0.534, inter=0.940) | lr 6.25e-06
# Fold 6 | Epoch 059 | train loss 1.1691 acc 0.5500 bal_acc 0.5755 f1 0.5236 | val loss 1.4297 acc 0.3539 bal_acc 0.4468 f1 0.3694 | attn(cnn=0.503, lstm=0.534, inter=0.940) | lr 6.25e-06
# Fold 6 | Epoch 060 | train loss 1.1789 acc 0.5514 bal_acc 0.5707 f1 0.5210 | val loss 1.3874 acc 0.3753 bal_acc 0.4688 f1 0.3923 | attn(cnn=0.502, lstm=0.534, inter=0.940) | lr 6.25e-06
# Fold 6 | Epoch 061 | train loss 1.1514 acc 0.5613 bal_acc 0.5800 f1 0.5314 | val loss 1.3918 acc 0.3731 bal_acc 0.4656 f1 0.3900 | attn(cnn=0.502, lstm=0.534, inter=0.940) | lr 6.25e-06
# Fold 6 | Epoch 062 | train loss 1.1714 acc 0.5426 bal_acc 0.5606 f1 0.5108 | val loss 1.3638 acc 0.3710 bal_acc 0.4629 f1 0.3918 | attn(cnn=0.504, lstm=0.534, inter=0.941) | lr 6.25e-06
# Fold 6 | Epoch 063 | train loss 1.1571 acc 0.5592 bal_acc 0.5815 f1 0.5316 | val loss 1.4179 acc 0.3582 bal_acc 0.4552 f1 0.3757 | attn(cnn=0.502, lstm=0.534, inter=0.940) | lr 6.25e-06
# Fold 6 | Epoch 064 | train loss 1.1664 acc 0.5559 bal_acc 0.5728 f1 0.5262 | val loss 1.3676 acc 0.3753 bal_acc 0.4690 f1 0.3974 | attn(cnn=0.504, lstm=0.534, inter=0.940) | lr 6.25e-06
# Fold 6 | Epoch 065 | train loss 1.1625 acc 0.5523 bal_acc 0.5755 f1 0.5264 | val loss 1.3813 acc 0.3795 bal_acc 0.4749 f1 0.4003 | attn(cnn=0.503, lstm=0.534, inter=0.941) | lr 6.25e-06
# Fold 6 | Epoch 066 | train loss 1.1631 acc 0.5464 bal_acc 0.5719 f1 0.5207 | val loss 1.3986 acc 0.3689 bal_acc 0.4659 f1 0.3868 | attn(cnn=0.504, lstm=0.534, inter=0.940) | lr 6.25e-06
# Fold 6 | Epoch 067 | train loss 1.1573 acc 0.5512 bal_acc 0.5769 f1 0.5275 | val loss 1.3966 acc 0.3689 bal_acc 0.4640 f1 0.3888 | attn(cnn=0.503, lstm=0.534, inter=0.940) | lr 6.25e-06
# Fold 6 | Epoch 068 | train loss 1.1587 acc 0.5673 bal_acc 0.5858 f1 0.5400 | val loss 1.3797 acc 0.3689 bal_acc 0.4597 f1 0.3892 | attn(cnn=0.504, lstm=0.534, inter=0.941) | lr 6.25e-06
# Fold 6 | Epoch 069 | train loss 1.1667 acc 0.5516 bal_acc 0.5710 f1 0.5233 | val loss 1.4106 acc 0.3646 bal_acc 0.4599 f1 0.3826 | attn(cnn=0.503, lstm=0.534, inter=0.941) | lr 3.13e-06
# Fold 6 | Epoch 070 | train loss 1.1647 acc 0.5547 bal_acc 0.5803 f1 0.5291 | val loss 1.3719 acc 0.3753 bal_acc 0.4691 f1 0.3988 | attn(cnn=0.502, lstm=0.534, inter=0.941) | lr 3.13e-06
# Fold 6 | Epoch 071 | train loss 1.1574 acc 0.5483 bal_acc 0.5731 f1 0.5230 | val loss 1.4260 acc 0.3603 bal_acc 0.4536 f1 0.3745 | attn(cnn=0.502, lstm=0.534, inter=0.941) | lr 3.13e-06
# Fold 6 | Epoch 072 | train loss 1.1510 acc 0.5578 bal_acc 0.5766 f1 0.5284 | val loss 1.3762 acc 0.3753 bal_acc 0.4690 f1 0.3960 | attn(cnn=0.502, lstm=0.534, inter=0.941) | lr 3.13e-06
# Fold 6 | Epoch 073 | train loss 1.1673 acc 0.5495 bal_acc 0.5715 f1 0.5221 | val loss 1.4367 acc 0.3582 bal_acc 0.4551 f1 0.3754 | attn(cnn=0.502, lstm=0.534, inter=0.941) | lr 3.13e-06
# Fold 6 | Epoch 074 | train loss 1.1571 acc 0.5661 bal_acc 0.5859 f1 0.5381 | val loss 1.4008 acc 0.3731 bal_acc 0.4678 f1 0.3918 | attn(cnn=0.503, lstm=0.534, inter=0.941) | lr 3.13e-06
# Fold 6 | Epoch 075 | train loss 1.1596 acc 0.5538 bal_acc 0.5714 f1 0.5259 | val loss 1.3624 acc 0.3795 bal_acc 0.4752 f1 0.4016 | attn(cnn=0.502, lstm=0.534, inter=0.942) | lr 3.13e-06
# Fold 6 | Epoch 076 | train loss 1.1511 acc 0.5734 bal_acc 0.5900 f1 0.5423 | val loss 1.3513 acc 0.3838 bal_acc 0.4704 f1 0.4068 | attn(cnn=0.504, lstm=0.535, inter=0.941) | lr 3.13e-06
# Fold 6 | Epoch 077 | train loss 1.1545 acc 0.5580 bal_acc 0.5784 f1 0.5312 | val loss 1.3991 acc 0.3753 bal_acc 0.4708 f1 0.3924 | attn(cnn=0.502, lstm=0.535, inter=0.941) | lr 3.13e-06
# Fold 6 | Epoch 078 | train loss 1.1621 acc 0.5507 bal_acc 0.5683 f1 0.5229 | val loss 1.3813 acc 0.3795 bal_acc 0.4749 f1 0.4000 | attn(cnn=0.502, lstm=0.535, inter=0.941) | lr 3.13e-06
# Fold 6 | Epoch 079 | train loss 1.1590 acc 0.5590 bal_acc 0.5757 f1 0.5302 | val loss 1.3869 acc 0.3710 bal_acc 0.4650 f1 0.3930 | attn(cnn=0.503, lstm=0.535, inter=0.942) | lr 3.13e-06
# Fold 6 | Epoch 080 | train loss 1.1627 acc 0.5550 bal_acc 0.5765 f1 0.5294 | val loss 1.3459 acc 0.3881 bal_acc 0.4741 f1 0.4065 | attn(cnn=0.504, lstm=0.535, inter=0.942) | lr 3.13e-06
# Fold 6 | Epoch 081 | train loss 1.1561 acc 0.5505 bal_acc 0.5720 f1 0.5192 | val loss 1.3704 acc 0.3817 bal_acc 0.4760 f1 0.4044 | attn(cnn=0.503, lstm=0.535, inter=0.941) | lr 3.13e-06
# Fold 6 | Epoch 082 | train loss 1.1530 acc 0.5523 bal_acc 0.5732 f1 0.5244 | val loss 1.3907 acc 0.3710 bal_acc 0.4649 f1 0.3923 | attn(cnn=0.503, lstm=0.535, inter=0.942) | lr 3.13e-06
# Fold 6 | Epoch 083 | train loss 1.1498 acc 0.5640 bal_acc 0.5874 f1 0.5403 | val loss 1.3929 acc 0.3667 bal_acc 0.4588 f1 0.3859 | attn(cnn=0.504, lstm=0.535, inter=0.942) | lr 3.13e-06
# Fold 6 | Epoch 084 | train loss 1.1528 acc 0.5566 bal_acc 0.5775 f1 0.5293 | val loss 1.3758 acc 0.3689 bal_acc 0.4598 f1 0.3883 | attn(cnn=0.504, lstm=0.535, inter=0.942) | lr 3.13e-06
# Fold 6 | Epoch 085 | train loss 1.1573 acc 0.5457 bal_acc 0.5693 f1 0.5209 | val loss 1.3945 acc 0.3646 bal_acc 0.4580 f1 0.3863 | attn(cnn=0.504, lstm=0.535, inter=0.941) | lr 3.13e-06
# Fold 6 | Epoch 086 | train loss 1.1577 acc 0.5599 bal_acc 0.5798 f1 0.5313 | val loss 1.3802 acc 0.3689 bal_acc 0.4618 f1 0.3893 | attn(cnn=0.504, lstm=0.535, inter=0.941) | lr 3.13e-06
# Fold 6 | Epoch 087 | train loss 1.1573 acc 0.5635 bal_acc 0.5798 f1 0.5345 | val loss 1.3756 acc 0.3710 bal_acc 0.4627 f1 0.3904 | attn(cnn=0.503, lstm=0.535, inter=0.941) | lr 1.56e-06
# Fold 6 | Epoch 088 | train loss 1.1565 acc 0.5580 bal_acc 0.5803 f1 0.5314 | val loss 1.3862 acc 0.3795 bal_acc 0.4748 f1 0.4003 | attn(cnn=0.502, lstm=0.535, inter=0.941) | lr 1.56e-06
# Fold 6 | Epoch 089 | train loss 1.1661 acc 0.5509 bal_acc 0.5707 f1 0.5220 | val loss 1.3904 acc 0.3625 bal_acc 0.4549 f1 0.3835 | attn(cnn=0.505, lstm=0.535, inter=0.941) | lr 1.56e-06
# Fold 6 | Epoch 090 | train loss 1.1540 acc 0.5590 bal_acc 0.5781 f1 0.5297 | val loss 1.3903 acc 0.3667 bal_acc 0.4589 f1 0.3881 | attn(cnn=0.504, lstm=0.535, inter=0.942) | lr 1.56e-06
# Fold 6 | Epoch 091 | train loss 1.1547 acc 0.5578 bal_acc 0.5832 f1 0.5323 | val loss 1.3593 acc 0.3795 bal_acc 0.4686 f1 0.3997 | attn(cnn=0.503, lstm=0.535, inter=0.941) | lr 1.56e-06
# Fold 6 | Epoch 092 | train loss 1.1505 acc 0.5677 bal_acc 0.5852 f1 0.5376 | val loss 1.3858 acc 0.3795 bal_acc 0.4771 f1 0.3988 | attn(cnn=0.502, lstm=0.535, inter=0.942) | lr 1.56e-06
# Fold 6 | Epoch 093 | train loss 1.1457 acc 0.5668 bal_acc 0.5864 f1 0.5398 | val loss 1.3711 acc 0.3774 bal_acc 0.4698 f1 0.3996 | attn(cnn=0.503, lstm=0.535, inter=0.942) | lr 1.56e-06
# Fold 6 | Epoch 094 | train loss 1.1426 acc 0.5687 bal_acc 0.5874 f1 0.5419 | val loss 1.3665 acc 0.3731 bal_acc 0.4638 f1 0.3918 | attn(cnn=0.503, lstm=0.535, inter=0.942) | lr 1.00e-06
# Fold 6 | Epoch 095 | train loss 1.1428 acc 0.5694 bal_acc 0.5907 f1 0.5412 | val loss 1.3677 acc 0.3859 bal_acc 0.4820 f1 0.4073 | attn(cnn=0.502, lstm=0.535, inter=0.942) | lr 1.00e-06
# Early stopping triggered.
#
# ========== Fold 7/10 ==========
# /home/rithik-tank/enter/envs/tf_gpu/lib/python3.10/site-packages/torch/nn/modules/rnn.py:1013: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   super().__init__("LSTM", *args, **kwargs)
# Fold 7 | Epoch 001 | train loss 1.8158 acc 0.3607 bal_acc 0.1706 f1 0.1316 | val loss 1.8345 acc 0.4200 bal_acc 0.1667 f1 0.0986 | attn(cnn=0.497, lstm=0.502, inter=0.498) | lr 5.00e-05
# Fold 7 | Epoch 002 | train loss 1.8138 acc 0.2402 bal_acc 0.1915 f1 0.1740 | val loss 1.8359 acc 0.2665 bal_acc 0.2200 f1 0.1218 | attn(cnn=0.496, lstm=0.502, inter=0.499) | lr 5.00e-05
# Fold 7 | Epoch 003 | train loss 1.8102 acc 0.2376 bal_acc 0.2144 f1 0.1965 | val loss 1.8344 acc 0.2665 bal_acc 0.2178 f1 0.1207 | attn(cnn=0.497, lstm=0.502, inter=0.501) | lr 5.00e-05
# Fold 7 | Epoch 004 | train loss 1.8053 acc 0.2148 bal_acc 0.2307 f1 0.1990 | val loss 1.8332 acc 0.1983 bal_acc 0.2259 f1 0.1331 | attn(cnn=0.498, lstm=0.502, inter=0.504) | lr 5.00e-05
# Fold 7 | Epoch 005 | train loss 1.7915 acc 0.2229 bal_acc 0.2417 f1 0.1980 | val loss 1.8317 acc 0.1684 bal_acc 0.2378 f1 0.1361 | attn(cnn=0.500, lstm=0.502, inter=0.519) | lr 5.00e-05
# Fold 7 | Epoch 006 | train loss 1.7408 acc 0.2319 bal_acc 0.2689 f1 0.2176 | val loss 1.8751 acc 0.1215 bal_acc 0.1758 f1 0.0513 | attn(cnn=0.489, lstm=0.502, inter=0.557) | lr 5.00e-05
# Fold 7 | Epoch 007 | train loss 1.6758 acc 0.2859 bal_acc 0.3014 f1 0.2613 | val loss 1.8970 acc 0.1130 bal_acc 0.1637 f1 0.0618 | attn(cnn=0.483, lstm=0.502, inter=0.625) | lr 5.00e-05
# Fold 7 | Epoch 008 | train loss 1.6495 acc 0.3058 bal_acc 0.3023 f1 0.2723 | val loss 1.8717 acc 0.1450 bal_acc 0.2070 f1 0.1298 | attn(cnn=0.486, lstm=0.503, inter=0.667) | lr 5.00e-05
# Fold 7 | Epoch 009 | train loss 1.6348 acc 0.3361 bal_acc 0.3157 f1 0.2968 | val loss 1.8995 acc 0.1493 bal_acc 0.2090 f1 0.1270 | attn(cnn=0.478, lstm=0.503, inter=0.692) | lr 5.00e-05
# Fold 7 | Epoch 010 | train loss 1.6107 acc 0.3532 bal_acc 0.3248 f1 0.3033 | val loss 2.0198 acc 0.1386 bal_acc 0.2027 f1 0.1040 | attn(cnn=0.457, lstm=0.503, inter=0.714) | lr 5.00e-05
# Fold 7 | Epoch 011 | train loss 1.5954 acc 0.3607 bal_acc 0.3323 f1 0.3140 | val loss 2.0595 acc 0.1301 bal_acc 0.1898 f1 0.1022 | attn(cnn=0.451, lstm=0.503, inter=0.736) | lr 5.00e-05
# Fold 7 | Epoch 012 | train loss 1.5869 acc 0.3657 bal_acc 0.3297 f1 0.3123 | val loss 2.0505 acc 0.1493 bal_acc 0.2128 f1 0.1146 | attn(cnn=0.450, lstm=0.503, inter=0.779) | lr 2.50e-05
# Fold 7 | Epoch 013 | train loss 1.5629 acc 0.3894 bal_acc 0.3508 f1 0.3312 | val loss 2.1017 acc 0.1514 bal_acc 0.2138 f1 0.1255 | attn(cnn=0.445, lstm=0.503, inter=0.804) | lr 2.50e-05
# Fold 7 | Epoch 014 | train loss 1.5674 acc 0.3785 bal_acc 0.3467 f1 0.3256 | val loss 2.1313 acc 0.1493 bal_acc 0.2121 f1 0.1220 | attn(cnn=0.440, lstm=0.503, inter=0.820) | lr 2.50e-05
# Fold 7 | Epoch 015 | train loss 1.5604 acc 0.3861 bal_acc 0.3587 f1 0.3379 | val loss 2.1963 acc 0.1429 bal_acc 0.2028 f1 0.1115 | attn(cnn=0.432, lstm=0.502, inter=0.844) | lr 2.50e-05
# Fold 7 | Epoch 016 | train loss 1.5477 acc 0.3982 bal_acc 0.3633 f1 0.3414 | val loss 2.1178 acc 0.1748 bal_acc 0.2419 f1 0.1401 | attn(cnn=0.441, lstm=0.503, inter=0.853) | lr 2.50e-05
# Fold 7 | Epoch 017 | train loss 1.5511 acc 0.3865 bal_acc 0.3495 f1 0.3269 | val loss 2.2232 acc 0.1514 bal_acc 0.2164 f1 0.1149 | attn(cnn=0.426, lstm=0.503, inter=0.855) | lr 2.50e-05
# Fold 7 | Epoch 018 | train loss 1.5340 acc 0.4060 bal_acc 0.3656 f1 0.3458 | val loss 2.2517 acc 0.1535 bal_acc 0.2192 f1 0.1161 | attn(cnn=0.422, lstm=0.503, inter=0.863) | lr 2.50e-05
# Fold 7 | Epoch 019 | train loss 1.5377 acc 0.4034 bal_acc 0.3651 f1 0.3448 | val loss 2.3002 acc 0.1578 bal_acc 0.2250 f1 0.1223 | attn(cnn=0.415, lstm=0.503, inter=0.868) | lr 1.25e-05
# Fold 7 | Epoch 020 | train loss 1.5323 acc 0.4027 bal_acc 0.3590 f1 0.3367 | val loss 2.2832 acc 0.1599 bal_acc 0.2278 f1 0.1256 | attn(cnn=0.419, lstm=0.503, inter=0.872) | lr 1.25e-05
# Early stopping triggered.
#
# ========== Fold 8/10 ==========
# /home/rithik-tank/enter/envs/tf_gpu/lib/python3.10/site-packages/torch/nn/modules/rnn.py:1013: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   super().__init__("LSTM", *args, **kwargs)
# Fold 8 | Epoch 001 | train loss 1.8158 acc 0.1182 bal_acc 0.1691 f1 0.1162 | val loss 1.8510 acc 0.1237 bal_acc 0.1786 f1 0.0595 | attn(cnn=0.499, lstm=0.500, inter=0.500) | lr 5.00e-05
# Fold 8 | Epoch 002 | train loss 1.8133 acc 0.1442 bal_acc 0.1846 f1 0.1429 | val loss 1.8482 acc 0.1855 bal_acc 0.2465 f1 0.1117 | attn(cnn=0.499, lstm=0.500, inter=0.501) | lr 5.00e-05
# Fold 8 | Epoch 003 | train loss 1.8087 acc 0.1982 bal_acc 0.2106 f1 0.1859 | val loss 1.8461 acc 0.1727 bal_acc 0.2207 f1 0.1222 | attn(cnn=0.498, lstm=0.500, inter=0.502) | lr 5.00e-05
# Fold 8 | Epoch 004 | train loss 1.8001 acc 0.2743 bal_acc 0.2342 f1 0.2179 | val loss 1.8409 acc 0.1834 bal_acc 0.2268 f1 0.1366 | attn(cnn=0.495, lstm=0.500, inter=0.508) | lr 5.00e-05
# Fold 8 | Epoch 005 | train loss 1.7859 acc 0.3186 bal_acc 0.2477 f1 0.2307 | val loss 1.8407 acc 0.1791 bal_acc 0.2162 f1 0.1223 | attn(cnn=0.490, lstm=0.500, inter=0.526) | lr 5.00e-05
# Fold 8 | Epoch 006 | train loss 1.7572 acc 0.3456 bal_acc 0.2589 f1 0.2481 | val loss 1.8664 acc 0.1493 bal_acc 0.1843 f1 0.0789 | attn(cnn=0.482, lstm=0.500, inter=0.564) | lr 5.00e-05
# Fold 8 | Epoch 007 | train loss 1.7101 acc 0.3432 bal_acc 0.2836 f1 0.2714 | val loss 1.8622 acc 0.1535 bal_acc 0.1883 f1 0.0879 | attn(cnn=0.476, lstm=0.501, inter=0.629) | lr 5.00e-05
# Fold 8 | Epoch 008 | train loss 1.6706 acc 0.3567 bal_acc 0.2964 f1 0.2846 | val loss 1.9471 acc 0.1386 bal_acc 0.1819 f1 0.0825 | attn(cnn=0.467, lstm=0.501, inter=0.665) | lr 5.00e-05
# Fold 8 | Epoch 009 | train loss 1.6318 acc 0.3671 bal_acc 0.3241 f1 0.3107 | val loss 2.0823 acc 0.1343 bal_acc 0.1840 f1 0.0709 | attn(cnn=0.457, lstm=0.505, inter=0.764) | lr 5.00e-05
# Fold 8 | Epoch 010 | train loss 1.6111 acc 0.3802 bal_acc 0.3319 f1 0.3215 | val loss 2.1801 acc 0.1301 bal_acc 0.1845 f1 0.0797 | attn(cnn=0.449, lstm=0.504, inter=0.798) | lr 5.00e-05
# Fold 8 | Epoch 011 | train loss 1.5905 acc 0.3865 bal_acc 0.3429 f1 0.3316 | val loss 2.2138 acc 0.1514 bal_acc 0.2118 f1 0.0999 | attn(cnn=0.445, lstm=0.503, inter=0.825) | lr 5.00e-05
# Fold 8 | Epoch 012 | train loss 1.5674 acc 0.4060 bal_acc 0.3514 f1 0.3421 | val loss 2.3021 acc 0.1514 bal_acc 0.2118 f1 0.0999 | attn(cnn=0.439, lstm=0.501, inter=0.836) | lr 2.50e-05
# Fold 8 | Epoch 013 | train loss 1.5498 acc 0.4062 bal_acc 0.3684 f1 0.3537 | val loss 2.2584 acc 0.1642 bal_acc 0.2209 f1 0.1099 | attn(cnn=0.439, lstm=0.501, inter=0.850) | lr 2.50e-05
# Fold 8 | Epoch 014 | train loss 1.5450 acc 0.4164 bal_acc 0.3719 f1 0.3588 | val loss 2.3989 acc 0.1557 bal_acc 0.2155 f1 0.1027 | attn(cnn=0.430, lstm=0.500, inter=0.850) | lr 2.50e-05
# Fold 8 | Epoch 015 | train loss 1.5334 acc 0.4164 bal_acc 0.3788 f1 0.3636 | val loss 2.3530 acc 0.1599 bal_acc 0.2146 f1 0.1062 | attn(cnn=0.431, lstm=0.499, inter=0.862) | lr 2.50e-05
# Fold 8 | Epoch 016 | train loss 1.5336 acc 0.4190 bal_acc 0.3740 f1 0.3598 | val loss 2.3978 acc 0.1620 bal_acc 0.2203 f1 0.1082 | attn(cnn=0.428, lstm=0.499, inter=0.864) | lr 2.50e-05
# Fold 8 | Epoch 017 | train loss 1.5123 acc 0.4360 bal_acc 0.3960 f1 0.3823 | val loss 2.4106 acc 0.1684 bal_acc 0.2291 f1 0.1119 | attn(cnn=0.425, lstm=0.498, inter=0.870) | lr 2.50e-05
# Fold 8 | Epoch 018 | train loss 1.5094 acc 0.4311 bal_acc 0.3949 f1 0.3789 | val loss 2.4772 acc 0.1642 bal_acc 0.2230 f1 0.1089 | attn(cnn=0.421, lstm=0.498, inter=0.872) | lr 2.50e-05
# Fold 8 | Epoch 019 | train loss 1.5024 acc 0.4304 bal_acc 0.3952 f1 0.3778 | val loss 2.4986 acc 0.1620 bal_acc 0.2203 f1 0.1082 | attn(cnn=0.419, lstm=0.497, inter=0.875) | lr 1.25e-05
# Fold 8 | Epoch 020 | train loss 1.4911 acc 0.4285 bal_acc 0.3995 f1 0.3803 | val loss 2.5748 acc 0.1557 bal_acc 0.2175 f1 0.1021 | attn(cnn=0.415, lstm=0.497, inter=0.875) | lr 1.25e-05
# Early stopping triggered.
#
# ========== Fold 9/10 ==========
# /home/rithik-tank/enter/envs/tf_gpu/lib/python3.10/site-packages/torch/nn/modules/rnn.py:1013: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   super().__init__("LSTM", *args, **kwargs)
# Fold 9 | Epoch 001 | train loss 1.8159 acc 0.1653 bal_acc 0.1671 f1 0.1336 | val loss 1.8437 acc 0.1919 bal_acc 0.2035 f1 0.1146 | attn(cnn=0.500, lstm=0.501, inter=0.499) | lr 5.00e-05
# Fold 9 | Epoch 002 | train loss 1.8152 acc 0.1497 bal_acc 0.1757 f1 0.1173 | val loss 1.8438 acc 0.1578 bal_acc 0.2288 f1 0.0854 | attn(cnn=0.500, lstm=0.501, inter=0.499) | lr 5.00e-05
# Fold 9 | Epoch 003 | train loss 1.8136 acc 0.1876 bal_acc 0.2057 f1 0.1785 | val loss 1.8429 acc 0.1748 bal_acc 0.2503 f1 0.0991 | attn(cnn=0.500, lstm=0.501, inter=0.501) | lr 5.00e-05
# Fold 9 | Epoch 004 | train loss 1.8097 acc 0.1990 bal_acc 0.2247 f1 0.1901 | val loss 1.8398 acc 0.1770 bal_acc 0.2530 f1 0.1072 | attn(cnn=0.500, lstm=0.501, inter=0.503) | lr 5.00e-05
# Fold 9 | Epoch 005 | train loss 1.8038 acc 0.1973 bal_acc 0.2192 f1 0.1846 | val loss 1.8364 acc 0.2004 bal_acc 0.2816 f1 0.1675 | attn(cnn=0.501, lstm=0.501, inter=0.511) | lr 5.00e-05
# Fold 9 | Epoch 006 | train loss 1.7891 acc 0.2177 bal_acc 0.2520 f1 0.2142 | val loss 1.8166 acc 0.2537 bal_acc 0.3262 f1 0.2309 | attn(cnn=0.506, lstm=0.501, inter=0.543) | lr 5.00e-05
# Fold 9 | Epoch 007 | train loss 1.7469 acc 0.2520 bal_acc 0.2677 f1 0.2386 | val loss 1.8352 acc 0.1620 bal_acc 0.2213 f1 0.1226 | attn(cnn=0.496, lstm=0.501, inter=0.603) | lr 5.00e-05
# Fold 9 | Epoch 008 | train loss 1.6861 acc 0.3105 bal_acc 0.2936 f1 0.2736 | val loss 1.8752 acc 0.1557 bal_acc 0.2139 f1 0.1014 | attn(cnn=0.486, lstm=0.501, inter=0.678) | lr 5.00e-05
# Fold 9 | Epoch 009 | train loss 1.6437 acc 0.3299 bal_acc 0.3037 f1 0.2877 | val loss 1.9265 acc 0.1301 bal_acc 0.1782 f1 0.0598 | attn(cnn=0.477, lstm=0.502, inter=0.722) | lr 5.00e-05
# Fold 9 | Epoch 010 | train loss 1.6122 acc 0.3662 bal_acc 0.3273 f1 0.3138 | val loss 2.1536 acc 0.1215 bal_acc 0.1707 f1 0.0449 | attn(cnn=0.452, lstm=0.509, inter=0.766) | lr 5.00e-05
# Fold 9 | Epoch 011 | train loss 1.5995 acc 0.3681 bal_acc 0.3364 f1 0.3209 | val loss 2.1927 acc 0.1279 bal_acc 0.1796 f1 0.0560 | attn(cnn=0.447, lstm=0.517, inter=0.801) | lr 5.00e-05
# Fold 9 | Epoch 012 | train loss 1.5748 acc 0.3910 bal_acc 0.3572 f1 0.3404 | val loss 2.1977 acc 0.1279 bal_acc 0.1796 f1 0.0561 | attn(cnn=0.444, lstm=0.526, inter=0.826) | lr 5.00e-05
# Fold 9 | Epoch 013 | train loss 1.5468 acc 0.3993 bal_acc 0.3662 f1 0.3490 | val loss 2.2333 acc 0.1322 bal_acc 0.1853 f1 0.0672 | attn(cnn=0.441, lstm=0.535, inter=0.851) | lr 2.50e-05
# Fold 9 | Epoch 014 | train loss 1.5310 acc 0.3941 bal_acc 0.3701 f1 0.3514 | val loss 2.3995 acc 0.1237 bal_acc 0.1757 f1 0.0538 | attn(cnn=0.429, lstm=0.537, inter=0.855) | lr 2.50e-05
# Fold 9 | Epoch 015 | train loss 1.5361 acc 0.4048 bal_acc 0.3796 f1 0.3588 | val loss 2.3777 acc 0.1237 bal_acc 0.1758 f1 0.0511 | attn(cnn=0.429, lstm=0.541, inter=0.863) | lr 2.50e-05
# Fold 9 | Epoch 016 | train loss 1.5282 acc 0.4081 bal_acc 0.3804 f1 0.3638 | val loss 2.3480 acc 0.1237 bal_acc 0.1757 f1 0.0536 | attn(cnn=0.431, lstm=0.543, inter=0.869) | lr 2.50e-05
# Fold 9 | Epoch 017 | train loss 1.5190 acc 0.4069 bal_acc 0.3872 f1 0.3679 | val loss 2.3290 acc 0.1279 bal_acc 0.1817 f1 0.0592 | attn(cnn=0.434, lstm=0.546, inter=0.877) | lr 2.50e-05
# Fold 9 | Epoch 018 | train loss 1.5065 acc 0.4019 bal_acc 0.3770 f1 0.3577 | val loss 2.4606 acc 0.1237 bal_acc 0.1757 f1 0.0536 | attn(cnn=0.423, lstm=0.548, inter=0.878) | lr 2.50e-05
# Fold 9 | Epoch 019 | train loss 1.4893 acc 0.4100 bal_acc 0.3878 f1 0.3673 | val loss 2.3922 acc 0.1386 bal_acc 0.1964 f1 0.0729 | attn(cnn=0.429, lstm=0.550, inter=0.885) | lr 2.50e-05
# Fold 9 | Epoch 020 | train loss 1.4973 acc 0.4083 bal_acc 0.3931 f1 0.3686 | val loss 2.5348 acc 0.1215 bal_acc 0.1728 f1 0.0471 | attn(cnn=0.419, lstm=0.551, inter=0.886) | lr 1.25e-05
# Fold 9 | Epoch 021 | train loss 1.4784 acc 0.4183 bal_acc 0.3933 f1 0.3724 | val loss 2.4744 acc 0.1279 bal_acc 0.1817 f1 0.0594 | attn(cnn=0.423, lstm=0.552, inter=0.889) | lr 1.25e-05
# Early stopping triggered.
#
# ========== Fold 10/10 ==========
# /home/rithik-tank/enter/envs/tf_gpu/lib/python3.10/site-packages/torch/nn/modules/rnn.py:1013: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   super().__init__("LSTM", *args, **kwargs)
# Fold 10 | Epoch 001 | train loss 1.8168 acc 0.1139 bal_acc 0.1657 f1 0.0649 | val loss 1.8502 acc 0.1130 bal_acc 0.1667 f1 0.0338 | attn(cnn=0.500, lstm=0.500, inter=0.499) | lr 5.00e-05
# Fold 10 | Epoch 002 | train loss 1.8144 acc 0.1246 bal_acc 0.1804 f1 0.0907 | val loss 1.8477 acc 0.1130 bal_acc 0.1667 f1 0.0340 | attn(cnn=0.499, lstm=0.500, inter=0.499) | lr 5.00e-05
# Fold 10 | Epoch 003 | train loss 1.8130 acc 0.1412 bal_acc 0.1979 f1 0.1218 | val loss 1.8447 acc 0.1151 bal_acc 0.1697 f1 0.0397 | attn(cnn=0.499, lstm=0.500, inter=0.500) | lr 5.00e-05
# Fold 10 | Epoch 004 | train loss 1.8089 acc 0.1805 bal_acc 0.2220 f1 0.1476 | val loss 1.8404 acc 0.1301 bal_acc 0.1907 f1 0.0695 | attn(cnn=0.499, lstm=0.500, inter=0.502) | lr 5.00e-05
# Fold 10 | Epoch 005 | train loss 1.8017 acc 0.2089 bal_acc 0.2457 f1 0.1944 | val loss 1.8363 acc 0.1706 bal_acc 0.2451 f1 0.1577 | attn(cnn=0.499, lstm=0.500, inter=0.507) | lr 5.00e-05
# Fold 10 | Epoch 006 | train loss 1.7831 acc 0.2127 bal_acc 0.2569 f1 0.2065 | val loss 1.8220 acc 0.2068 bal_acc 0.2849 f1 0.2097 | attn(cnn=0.498, lstm=0.500, inter=0.530) | lr 5.00e-05
# Fold 10 | Epoch 007 | train loss 1.7350 acc 0.2487 bal_acc 0.2724 f1 0.2345 | val loss 1.8282 acc 0.1855 bal_acc 0.2570 f1 0.1715 | attn(cnn=0.489, lstm=0.501, inter=0.591) | lr 5.00e-05
# Fold 10 | Epoch 008 | train loss 1.6660 acc 0.2994 bal_acc 0.2962 f1 0.2716 | val loss 1.8839 acc 0.1365 bal_acc 0.1941 f1 0.0787 | attn(cnn=0.480, lstm=0.512, inter=0.695) | lr 5.00e-05
# Fold 10 | Epoch 009 | train loss 1.6249 acc 0.3141 bal_acc 0.3185 f1 0.2910 | val loss 1.8909 acc 0.1429 bal_acc 0.1967 f1 0.0840 | attn(cnn=0.481, lstm=0.523, inter=0.746) | lr 5.00e-05
# Fold 10 | Epoch 010 | train loss 1.5959 acc 0.3392 bal_acc 0.3331 f1 0.3070 | val loss 1.9293 acc 0.1365 bal_acc 0.1943 f1 0.0792 | attn(cnn=0.476, lstm=0.537, inter=0.782) | lr 5.00e-05
# Fold 10 | Epoch 011 | train loss 1.5731 acc 0.3847 bal_acc 0.3593 f1 0.3389 | val loss 2.0037 acc 0.1343 bal_acc 0.1888 f1 0.0703 | attn(cnn=0.470, lstm=0.545, inter=0.802) | lr 5.00e-05
# Fold 10 | Epoch 012 | train loss 1.5518 acc 0.3688 bal_acc 0.3587 f1 0.3348 | val loss 2.0100 acc 0.1429 bal_acc 0.2013 f1 0.0846 | attn(cnn=0.471, lstm=0.557, inter=0.829) | lr 5.00e-05
# Fold 10 | Epoch 013 | train loss 1.5320 acc 0.3955 bal_acc 0.3821 f1 0.3554 | val loss 2.0176 acc 0.1514 bal_acc 0.2141 f1 0.0958 | attn(cnn=0.471, lstm=0.566, inter=0.845) | lr 2.50e-05
# Fold 10 | Epoch 014 | train loss 1.5119 acc 0.3979 bal_acc 0.3828 f1 0.3519 | val loss 1.9856 acc 0.1620 bal_acc 0.2252 f1 0.1043 | attn(cnn=0.473, lstm=0.571, inter=0.854) | lr 2.50e-05
# Fold 10 | Epoch 015 | train loss 1.5008 acc 0.3941 bal_acc 0.3950 f1 0.3602 | val loss 2.0239 acc 0.1514 bal_acc 0.2164 f1 0.1053 | attn(cnn=0.470, lstm=0.575, inter=0.858) | lr 2.50e-05
# Fold 10 | Epoch 016 | train loss 1.4957 acc 0.4098 bal_acc 0.3968 f1 0.3683 | val loss 1.9656 acc 0.1727 bal_acc 0.2400 f1 0.1420 | attn(cnn=0.473, lstm=0.578, inter=0.863) | lr 2.50e-05
# Fold 10 | Epoch 017 | train loss 1.4799 acc 0.4102 bal_acc 0.4002 f1 0.3689 | val loss 2.0486 acc 0.1599 bal_acc 0.2261 f1 0.1150 | attn(cnn=0.465, lstm=0.581, inter=0.865) | lr 2.50e-05
# Fold 10 | Epoch 018 | train loss 1.4759 acc 0.4100 bal_acc 0.4075 f1 0.3719 | val loss 2.0204 acc 0.1642 bal_acc 0.2279 f1 0.1203 | attn(cnn=0.467, lstm=0.583, inter=0.870) | lr 2.50e-05
# Fold 10 | Epoch 019 | train loss 1.4691 acc 0.4190 bal_acc 0.4126 f1 0.3775 | val loss 2.1233 acc 0.1514 bal_acc 0.2158 f1 0.1054 | attn(cnn=0.460, lstm=0.586, inter=0.870) | lr 2.50e-05
# Fold 10 | Epoch 020 | train loss 1.4616 acc 0.4202 bal_acc 0.4176 f1 0.3831 | val loss 2.0508 acc 0.1599 bal_acc 0.2262 f1 0.1197 | attn(cnn=0.466, lstm=0.589, inter=0.876) | lr 1.25e-05
# Fold 10 | Epoch 021 | train loss 1.4532 acc 0.4339 bal_acc 0.4231 f1 0.3891 | val loss 2.0504 acc 0.1684 bal_acc 0.2387 f1 0.1284 | attn(cnn=0.466, lstm=0.590, inter=0.879) | lr 1.25e-05
# Early stopping triggered.
#
# ========== CV Summary ==========
# Fold 1: best val loss=1.8149 | best val acc=0.2106 | best val f1=0.2045
# Fold 2: best val loss=1.6662 | best val acc=0.3625 | best val f1=0.2947
# Fold 3: best val loss=1.7135 | best val acc=0.2878 | best val f1=0.2529
# Fold 4: best val loss=1.8237 | best val acc=0.2111 | best val f1=0.1777
# Fold 5: best val loss=1.8069 | best val acc=0.2303 | best val f1=0.2535
# Fold 6: best val loss=1.3459 | best val acc=0.4264 | best val f1=0.4073
# Fold 7: best val loss=1.8317 | best val acc=0.4200 | best val f1=0.1401
# Fold 8: best val loss=1.8407 | best val acc=0.1855 | best val f1=0.1366
# Fold 9: best val loss=1.8166 | best val acc=0.2537 | best val f1=0.2309
# Fold 10: best val loss=1.8220 | best val acc=0.2068 | best val f1=0.2097
# Mean(best val acc) across folds: 0.2795
# Mean(best val f1 ) across folds: 0.2308
# Saved best-fold checkpoint to: best_model.pt

# %% [markdown]
# ## 9) Plot Loss / Accuracy (TF-history equivalent)

# %%
plt.figure(figsize=(10, 5))
plt.plot(history["train_loss"], label="Train loss")
plt.plot(history["val_loss"], label="Val/Test loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.title("Loss Curves")
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(history["train_acc"], label="Train acc")
plt.plot(history["val_acc"], label="Val/Test acc")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.title("Accuracy Curves")
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(history["train_f1"], label="Train macro-F1")
plt.plot(history["val_f1"], label="Val/Test macro-F1")
plt.xlabel("Epoch")
plt.ylabel("Macro-F1")
plt.legend()
plt.title("Macro-F1 Curves")
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(history["val_w_cnn"], label="Val attn w_cnn (MFCC+Chroma CNN)")
plt.plot(history["val_w_lstm"], label="Val attn w_lstm (MFCC+Chroma LSTM)")
plt.plot(history["val_w_inter"], label="Val attn w_inter (CNN+LSTM)")
plt.xlabel("Epoch")
plt.ylabel("Mean gate weight")
plt.legend()
plt.title("Attention/Gated Fusion Weight Trends (Validation)")
plt.show()

# %% [markdown]
# ## 10) Final Evaluation on Unseen Set (Confusion Matrix + Report)
# Loads the best checkpoint (lowest validation loss) and evaluates on the unseen set.

# %%
# Load best checkpoint
model.load_state_dict(torch.load(checkpoint_path, map_location=device))
model.eval()

all_preds = []
all_targets = []

with torch.no_grad():
    for mfcc, chroma, y in unseen_loader:
        mfcc = mfcc.to(device)
        chroma = chroma.to(device)
        logits = model(mfcc, chroma)
        preds = torch.argmax(logits, dim=1).cpu().numpy()
        all_preds.append(preds)
        all_targets.append(y.numpy())

all_preds = np.concatenate(all_preds)
all_targets = np.concatenate(all_targets)

acc = accuracy_score(all_targets, all_preds)
prec, rec, f1, _ = precision_recall_fscore_support(all_targets, all_preds, average="macro", zero_division=0)
print(f"Unseen Accuracy: {acc:.4f}")
print(f"Unseen Macro Precision: {prec:.4f} | Recall: {rec:.4f} | F1: {f1:.4f}")

print("\nClassification report:")
print(classification_report(all_targets, all_preds, digits=4))

cm = confusion_matrix(all_targets, all_preds)
plt.figure(figsize=(7, 6))
plt.imshow(cm, interpolation="nearest")
plt.title("Confusion Matrix (Unseen)")
plt.colorbar()
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()
# Out:
# Unseen Accuracy: 0.2288
# Unseen Macro Precision: 0.3799 | Recall: 0.4245 | F1: 0.2616
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.6522    0.4688    0.5455        32
#            1     0.2727    0.1364    0.1818        22
#            2     0.9632    0.1686    0.2870       777
#            3     0.2180    0.7436    0.3372        39
#            4     0.0531    0.9143    0.1003        35
#            5     0.1200    0.1154    0.1176        26
#
#     accuracy                         0.2288       931
#    macro avg     0.3799    0.4245    0.2616       931
# weighted avg     0.8472    0.2288    0.2837       931
