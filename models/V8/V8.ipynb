# %% [markdown]
# # PyTorch Training & Evaluation Notebook
# Dual-Channel CNN–LSTM (MFCC + Chroma)
#
# This notebook extends the pure TF→PyTorch model translation with a full training / testing / validation workflow: early stopping, checkpoints, LR scheduling, metrics, plots, and confusion matrix.
#
# **Expected inputs** (NumPy arrays):
# - `X_mfcc`: shape `[N, 40, 679]`
# - `X_chroma`: shape `[N, 12, 259]`
# - `y`: integer labels shape `[N]` (0..C-1)

# %% [markdown]
# ## 1) Imports & Reproducibility

# %%
import os
import random
from dataclasses import dataclass

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix, classification_report

# -----------------------
# Reproducibility
# -----------------------
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %% [markdown]
# ## 2) Data Loading (replace with your feature files)
# If you already have train/test/val splits saved, load them here.
# A common approach is to store arrays in a single `.npz` file.

# %%
import numpy as np
import pandas as pd
import librosa as lb

# -----------------------------------
# Paths
# -----------------------------------
BASE_DIR = "../../dataset"

TRAIN_DIR = os.path.join(BASE_DIR, "train-segments")
TEST_DIR = os.path.join(BASE_DIR, "test-segments")
VAL_DIR = os.path.join(BASE_DIR, "val-segments")

TRAIN_CSV = os.path.join(BASE_DIR, "train_segments.csv")
TEST_CSV = os.path.join(BASE_DIR, "test_segments.csv")
VAL_CSV = os.path.join(BASE_DIR, "val_segments.csv")

# -----------------------------------
# Feature parameters
# -----------------------------------
SR = 4000
N_MFCC = 40
TARGET_MFCC_T = 679
TARGET_CHROMA_T = 259

# %%
def extract_mfcc_and_chroma(y, sr):
    mfcc = lb.feature.mfcc(y=y, sr=sr, n_mfcc=N_MFCC)
    chroma = lb.feature.chroma_stft(y=y, sr=sr)
    return mfcc, chroma


def pad_or_crop(feat, target_T):
    F, T = feat.shape

    if T > target_T:
        return feat[:, :target_T]

    if T < target_T:
        pad_width = target_T - T
        return np.pad(feat, ((0, 0), (0, pad_width)), mode="constant")

    return feat

# %%
def build_features_from_csv(csv_path, audio_dir):
    df = pd.read_csv(csv_path)

    mfcc_list = []
    chroma_list = []
    labels = []

    # Create consistent label mapping
    diseases = sorted(df["disease"].unique())
    label_map = {d: i for i, d in enumerate(diseases)}

    for _, row in df.iterrows():
        filename = os.path.basename(row["segment_file"])
        label = row["disease"]

        file_path = os.path.join(audio_dir, filename)

        if not os.path.exists(file_path):
            raise FileNotFoundError(f"Missing file: {file_path}")

        # Load audio
        y, sr = lb.load(file_path, sr=SR)

        # Extract features
        mfcc, chroma = extract_mfcc_and_chroma(y, sr)

        # Pad / crop
        mfcc = pad_or_crop(mfcc, TARGET_MFCC_T)
        chroma = pad_or_crop(chroma, TARGET_CHROMA_T)

        mfcc_list.append(mfcc)
        chroma_list.append(chroma)
        labels.append(label_map[label])

    X_mfcc = np.stack(mfcc_list)
    X_chroma = np.stack(chroma_list)
    y = np.array(labels)

    return X_mfcc, X_chroma, y, label_map

# %%
X_mfcc_train, X_chroma_train, y_train, label_map = build_features_from_csv(
    TRAIN_CSV, TRAIN_DIR
)

X_mfcc_test, X_chroma_test, y_test, _ = build_features_from_csv(
    TEST_CSV, TEST_DIR
)

X_mfcc_val, X_chroma_val, y_val, _ = build_features_from_csv(
    VAL_CSV, VAL_DIR
)
# Out:
# /home/rithik-tank/enter/envs/tf_gpu/lib/python3.10/site-packages/librosa/core/pitch.py:103: UserWarning: Trying to estimate tuning from empty frequency set.
#   return pitch_tuning(
# /home/rithik-tank/enter/envs/tf_gpu/lib/python3.10/site-packages/librosa/core/pitch.py:103: UserWarning: Trying to estimate tuning from empty frequency set.
#   return pitch_tuning(
# /home/rithik-tank/enter/envs/tf_gpu/lib/python3.10/site-packages/librosa/core/pitch.py:103: UserWarning: Trying to estimate tuning from empty frequency set.
#   return pitch_tuning(

# %%
X_mfcc_train = torch.from_numpy(X_mfcc_train).float()
X_chroma_train = torch.from_numpy(X_chroma_train).float()
y_train = torch.from_numpy(y_train).long()

X_mfcc_test = torch.from_numpy(X_mfcc_test).float()
X_chroma_test = torch.from_numpy(X_chroma_test).float()
y_test = torch.from_numpy(y_test).long()

X_mfcc_unseen = torch.from_numpy(X_mfcc_val).float()
X_chroma_unseen = torch.from_numpy(X_chroma_val).float()
y_unseen = torch.from_numpy(y_val).long()

# %%
# ------------------------------------------------------------
# (PLACEHOLDER) MFCC & Chroma extraction
# Your classmate will implement the real extraction pipeline here.
# This scaffold shows the expected inputs/outputs for the model.
# ------------------------------------------------------------
# Expected model inputs:
#   mfcc:   torch.FloatTensor [B, 40, 679]
#   chroma: torch.FloatTensor [B, 12, 259]
#
# Notes:
# - In your final pipeline, you will likely:
#   1) load audio (already resampled/filtered/segmented/normalized)
#   2) extract MFCC and chroma per 3-second segment
#   3) pad/crop along time axis to fixed lengths (679 and 259 here)
#
# If librosa is available, this is a minimal template:
#
# import librosa as lb
# import numpy as np
#
# def extract_mfcc_and_chroma(y: np.ndarray, sr: int):
#     # MFCC: shape [n_mfcc, T_mfcc]
#     mfcc = lb.feature.mfcc(y=y, sr=sr, n_mfcc=40)
#     # Chroma: shape [12, T_chr]
#     chroma = lb.feature.chroma_stft(y=y, sr=sr)
#     return mfcc, chroma
#
# def pad_or_crop(feat: np.ndarray, target_T: int):
#     # feat: [F, T]
#     F, T = feat.shape
#     if T == target_T:
#         return feat
#     if T > target_T:
#         return feat[:, :target_T]
#     # pad on the right
#     pad_width = target_T - T
#     return np.pad(feat, ((0,0),(0,pad_width)), mode="constant")
#
# In the dataloader, convert to torch:
#   mfcc = torch.from_numpy(mfcc).float()
#   chroma = torch.from_numpy(chroma).float()

# %%
# Example loader (edit paths / keys to match your pipeline)
# data = np.load("features_splits.npz", allow_pickle=True)
# X_mfcc_train = data["X_mfcc_train"]     # [N, 40, 679]
# X_chroma_train = data["X_chroma_train"] # [N, 12, 259]
# y_train = data["y_train"]               # [N]
# X_mfcc_test = data["X_mfcc_test"]
# X_chroma_test = data["X_chroma_test"]
# y_test = data["y_test"]
# X_mfcc_unseen = data["X_mfcc_unseen"]
# X_chroma_unseen = data["X_chroma_unseen"]
# y_unseen = data["y_unseen"]

# -----------------------
# TEMP: dummy data (delete once you load real arrays)
# -----------------------
num_classes = 6
N_train, N_test, N_unseen = 256, 64, 64

# X_mfcc_train = np.random.randn(N_train, 40, 679).astype(np.float32)
# X_chroma_train = np.random.randn(N_train, 12, 259).astype(np.float32)
# y_train = np.random.randint(0, num_classes, size=(N_train,)).astype(np.int64)

# X_mfcc_test = np.random.randn(N_test, 40, 679).astype(np.float32)
# X_chroma_test = np.random.randn(N_test, 12, 259).astype(np.float32)
# y_test = np.random.randint(0, num_classes, size=(N_test,)).astype(np.int64)

# X_mfcc_unseen = np.random.randn(N_unseen, 40, 679).astype(np.float32)
# X_chroma_unseen = np.random.randn(N_unseen, 12, 259).astype(np.float32)
# y_unseen = np.random.randint(0, num_classes, size=(N_unseen,)).astype(np.int64)

print("Train:", X_mfcc_train.shape, X_chroma_train.shape, y_train.shape)
print("Test: ", X_mfcc_test.shape, X_chroma_test.shape, y_test.shape)
print("Unseen:", X_mfcc_unseen.shape, X_chroma_unseen.shape, y_unseen.shape)
# Out:
# Train: torch.Size([3000, 40, 679]) torch.Size([3000, 12, 259]) torch.Size([3000])
# Test:  torch.Size([1653, 40, 679]) torch.Size([1653, 12, 259]) torch.Size([1653])
# Unseen: torch.Size([700, 40, 679]) torch.Size([700, 12, 259]) torch.Size([700])

# %% [markdown]
# ## 3) Dataset & DataLoader

# %%
class DualFeatureDataset(Dataset):
    def __init__(self, X_mfcc: np.ndarray, X_chroma: np.ndarray, y: np.ndarray):
        assert len(X_mfcc) == len(X_chroma) == len(y)
        self.X_mfcc = X_mfcc
        self.X_chroma = X_chroma
        self.y = y

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        return (
            self.X_mfcc[idx],
            self.X_chroma[idx],
            self.y[idx]
        )

batch_size = 32

train_loader = DataLoader(DualFeatureDataset(X_mfcc_train, X_chroma_train, y_train),
                          batch_size=batch_size, shuffle=True, num_workers=0, pin_memory=True)

test_loader = DataLoader(DualFeatureDataset(X_mfcc_test, X_chroma_test, y_test),
                         batch_size=batch_size, shuffle=False, num_workers=0, pin_memory=True)

unseen_loader = DataLoader(DualFeatureDataset(X_mfcc_unseen, X_chroma_unseen, y_unseen),
                           batch_size=batch_size, shuffle=False, num_workers=0, pin_memory=True)

# %% [markdown]
# ## 4) Model Definition (pure translation)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


class GatedFusion(nn.Module):
    def __init__(self, dim: int, hidden: int = 128, dropout: float = 0.1):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(dim * 2, hidden),
            nn.ReLU(inplace=True),
            nn.Dropout(dropout),
            nn.Linear(hidden, dim),
        )

    def forward(self, a: torch.Tensor, b: torch.Tensor):
        w = torch.sigmoid(self.net(torch.cat([a, b], dim=1)))
        fused = w * a + (1.0 - w) * b
        return fused, w


class DualChannelCNNLSTM_WithAttentionFusion(nn.Module):

    def __init__(self, num_classes: int = 8, dropout_p: float = 0.4, fuse_dim: int = 64):
        super().__init__()
        self.fuse_dim = fuse_dim

        # -------------------------------
        # MFCC CNN
        # -------------------------------
        self.mfcc_cnn = nn.Sequential(
            nn.Conv2d(1, 32, 3, padding=1),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(32),
            nn.MaxPool2d(2),
            nn.Dropout(0.2),

            nn.Conv2d(32, 64, 3, padding=1),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(64),
            nn.MaxPool2d(2),
            nn.Dropout(0.2),

            nn.Conv2d(64, 128, 3, padding=1),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(128),
            nn.MaxPool2d(2),
            nn.Dropout(0.2),
        )

        # -------------------------------
        # CHROMA CNN
        # -------------------------------
        self.chroma_cnn = nn.Sequential(
            nn.Conv2d(1, 32, 3, padding=1),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(32),
            nn.MaxPool2d(2),
            nn.Dropout(0.2),

            nn.Conv2d(32, 64, 3, padding=1),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(64),
            nn.MaxPool2d(2),
            nn.Dropout(0.2),

            nn.Conv2d(64, 128, 3, padding=1),
            nn.ReLU(inplace=True),
            nn.BatchNorm2d(128),
            nn.MaxPool2d(2),
            nn.Dropout(0.2),
        )

        self.gap2d = nn.AdaptiveAvgPool2d((1, 1))

        self.mfcc_cnn_proj = nn.Linear(128, fuse_dim)
        self.chroma_cnn_proj = nn.Linear(128, fuse_dim)

        # -------------------------------
        # MFCC LSTM (with dropout)
        # -------------------------------
        self.mfcc_lstm1 = nn.LSTM(40, 128, batch_first=True)
        self.mfcc_lstm2 = nn.LSTM(128, 64, batch_first=True, dropout=0.2)
        self.mfcc_lstm3 = nn.LSTM(64, fuse_dim, batch_first=True)

        # -------------------------------
        # CHROMA LSTM (with dropout)
        # -------------------------------
        self.chroma_lstm1 = nn.LSTM(12, 128, batch_first=True)
        self.chroma_lstm2 = nn.LSTM(128, 64, batch_first=True, dropout=0.2)
        self.chroma_lstm3 = nn.LSTM(64, fuse_dim, batch_first=True)

        # -------------------------------
        # Fusion modules
        # -------------------------------
        self.fuse_cnn_modality = GatedFusion(dim=fuse_dim)
        self.fuse_lstm_modality = GatedFusion(dim=fuse_dim)
        self.fuse_extractor = GatedFusion(dim=fuse_dim)

        # -------------------------------
        # Classifier
        # -------------------------------
        self.fc1 = nn.Linear(fuse_dim, 128)
        self.dropout = nn.Dropout(p=dropout_p)
        self.fc_out = nn.Linear(128, num_classes)

    def forward(self, mfcc, chroma, return_attn=False):

        mfcc_cnn = self.mfcc_cnn(mfcc.unsqueeze(1))
        mfcc_cnn_vec = self.gap2d(mfcc_cnn).flatten(1)
        mfcc_cnn_vec = self.mfcc_cnn_proj(mfcc_cnn_vec)

        chroma_cnn = self.chroma_cnn(chroma.unsqueeze(1))
        chroma_cnn_vec = self.gap2d(chroma_cnn).flatten(1)
        chroma_cnn_vec = self.chroma_cnn_proj(chroma_cnn_vec)

        mfcc_lstm = mfcc.transpose(1, 2)
        x,_ = self.mfcc_lstm1(mfcc_lstm)
        x,_ = self.mfcc_lstm2(x)
        x,_ = self.mfcc_lstm3(x)
        mfcc_lstm_vec = x[:,-1,:]

        chroma_lstm = chroma.transpose(1,2)
        y,_ = self.chroma_lstm1(chroma_lstm)
        y,_ = self.chroma_lstm2(y)
        y,_ = self.chroma_lstm3(y)
        chroma_lstm_vec = y[:,-1,:]

        cnn_fused, w_cnn = self.fuse_cnn_modality(mfcc_cnn_vec, chroma_cnn_vec)
        lstm_fused, w_lstm = self.fuse_lstm_modality(mfcc_lstm_vec, chroma_lstm_vec)
        final_fused, w_inter = self.fuse_extractor(cnn_fused, lstm_fused)

        z = F.relu(self.fc1(final_fused))
        z = self.dropout(z)
        logits = self.fc_out(z)

        if return_attn:
            attn = {
                "w_cnn_mean": float(w_cnn.mean().item()),
                "w_lstm_mean": float(w_lstm.mean().item()),
                "w_inter_mean": float(w_inter.mean().item()),
            }
            return logits, attn

        return logits

# %% [markdown]
# ## 5) Loss, Optimizer, Scheduler (Keras-like)

# %%
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

y_dev = np.concatenate([y_train, y_test], axis=0)

class_weights = compute_class_weight(
    class_weight="balanced",
    classes=np.unique(y_dev),
    y=y_dev
)

class_weights = torch.tensor(class_weights, dtype=torch.float32).to(device)

# %%
model = DualChannelCNNLSTM_WithAttentionFusion(
    num_classes=num_classes,
    dropout_p=0.4,
    fuse_dim=64
).to(device)

criterion = nn.CrossEntropyLoss(
    weight=class_weights,
    label_smoothing=0.05
)

optimizer = torch.optim.AdamW(
    model.parameters(),
    lr=5e-5,
    weight_decay=1e-4
)

scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode="min",
    factor=0.5,
    patience=6,
    min_lr=1e-6
)
# Out:
# /home/rithik-tank/enter/envs/tf_gpu/lib/python3.10/site-packages/torch/nn/modules/rnn.py:1013: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   super().__init__("LSTM", *args, **kwargs)

# %% [markdown]
# ## 6) Early Stopping + Checkpointing

# %%
@dataclass
class EarlyStopping:
    patience: int = 7
    min_delta: float = 0.0
    best: float = float("inf")
    num_bad_epochs: int = 0
    stopped: bool = False

    def step(self, current: float) -> bool:
        # returns True if we should stop
        improved = (self.best - current) > self.min_delta
        if improved:
            self.best = current
            self.num_bad_epochs = 0
        else:
            self.num_bad_epochs += 1
            if self.num_bad_epochs >= self.patience:
                self.stopped = True
        return self.stopped

checkpoint_path = "best_model.pt"
early = EarlyStopping(
    patience=15, 
    min_delta=1e-4
)

# %% [markdown]
# ## 7) Train / Eval loops (loss + accuracy + macro F1)

# %%
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, balanced_accuracy_score

def run_epoch(model, loader, optimizer=None):

    is_train = optimizer is not None
    model.train(is_train)

    all_losses = []
    all_preds = []
    all_targets = []

    attn_w_cnn = []
    attn_w_lstm = []
    attn_w_inter = []

    for mfcc, chroma, y in loader:

        mfcc = mfcc.to(device)
        chroma = chroma.to(device)
        y = y.to(device)

        logits, attn = model(mfcc, chroma, return_attn=True)
        loss = criterion(logits, y)

        if is_train:
            optimizer.zero_grad(set_to_none=True)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step()

        all_losses.append(loss.item())

        preds = torch.argmax(logits, dim=1)

        all_preds.append(preds.detach().cpu().numpy())
        all_targets.append(y.detach().cpu().numpy())

        attn_w_cnn.append(attn['w_cnn_mean'])
        attn_w_lstm.append(attn['w_lstm_mean'])
        attn_w_inter.append(attn['w_inter_mean'])

    all_preds = np.concatenate(all_preds)
    all_targets = np.concatenate(all_targets)

    acc = accuracy_score(all_targets, all_preds)
    bal_acc = balanced_accuracy_score(all_targets, all_preds)

    prec, rec, f1, _ = precision_recall_fscore_support(
        all_targets,
        all_preds,
        average="macro",
        zero_division=0
    )

    return (
        float(np.mean(all_losses)),
        acc,
        bal_acc,
        prec,
        rec,
        f1,
        float(np.mean(attn_w_cnn)),
        float(np.mean(attn_w_lstm)),
        float(np.mean(attn_w_inter))
    )

# %% [markdown]
# ## 8) Training Run (history like Keras)

# %%
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

y_dev = np.concatenate([y_train, y_test], axis=0)

class_weights = compute_class_weight(
    class_weight="balanced",
    classes=np.unique(y_dev),
    y=y_dev
)

class_weights = torch.tensor(class_weights, dtype=torch.float32).to(device)

# %%
# 10-Fold Cross-Validation on the *development* set (train+test), then final evaluation on the unseen set.
from sklearn.model_selection import StratifiedKFold
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

epochs = 500
n_splits = 10
batch_size = 32  # keep consistent

# Combine the dev split (train+test) for CV
X_mfcc_dev = np.concatenate([X_mfcc_train, X_mfcc_test], axis=0)
X_chroma_dev = np.concatenate([X_chroma_train, X_chroma_test], axis=0)

skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=SEED)

fold_summaries = []
best_fold_loss = float("inf")
best_fold_state = None

for fold, (tr_idx, va_idx) in enumerate(skf.split(np.zeros(len(y_dev)), y_dev), start=1):
    print(f"\n========== Fold {fold}/{n_splits} ==========")

    # Fold loaders
    fold_train_loader = DataLoader(
        DualFeatureDataset(X_mfcc_dev[tr_idx], X_chroma_dev[tr_idx], y_dev[tr_idx]),
        batch_size=batch_size, shuffle=True, num_workers=0, pin_memory=True
    )
    fold_val_loader = DataLoader(
        DualFeatureDataset(X_mfcc_dev[va_idx], X_chroma_dev[va_idx], y_dev[va_idx]),
        batch_size=batch_size, shuffle=False, num_workers=0, pin_memory=True
    )

    # Fresh model per fold
    model = DualChannelCNNLSTM_WithAttentionFusion(
        num_classes=num_classes,
        dropout_p=0.4,
        fuse_dim=96
    ).to(device)
    
    # Loss
    criterion = nn.CrossEntropyLoss(
        weight=class_weights,
        label_smoothing=0.05
    )

    # Optimizer
    optimizer = torch.optim.AdamW(
        model.parameters(),
        lr=5e-5,
        weight_decay=1e-4
    )

    # Scheduler (same as before)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer,
        mode="min",
        factor=0.5,
        patience=6,
        min_lr=1e-6
    )

    # Early stopping
    early = EarlyStopping(
        patience=15,
        min_delta=1e-4
    )

    history = {
        "train_loss": [], "train_acc": [], "train_f1": [],
        "val_loss": [], "val_acc": [], "val_f1": [],
        "lr": [],
        "train_w_cnn": [], "train_w_lstm": [], "train_w_inter": [],
        "val_w_cnn": [], "val_w_lstm": [], "val_w_inter": []
    }

    best_this_fold = float("inf")
    best_state_this_fold = None

    for epoch in range(1, epochs + 1):
        (train_loss, train_acc, train_bal_acc, train_prec, train_rec, train_f1,
         train_w_cnn, train_w_lstm, train_w_inter) = run_epoch(model, fold_train_loader, optimizer=optimizer)
        
        (val_loss, val_acc, val_bal_acc, val_prec, val_rec, val_f1,
         val_w_cnn, val_w_lstm, val_w_inter) = run_epoch(model, fold_val_loader, optimizer=None)
        
        scheduler.step(val_loss)
        lr = optimizer.param_groups[0]["lr"]

        history["lr"].append(lr)
        history["train_loss"].append(train_loss)
        history["train_acc"].append(train_acc)
        history["train_f1"].append(train_f1)
        history["val_loss"].append(val_loss)
        history["val_acc"].append(val_acc)
        history["val_f1"].append(val_f1)

        history["train_w_cnn"].append(train_w_cnn)
        history["train_w_lstm"].append(train_w_lstm)
        history["train_w_inter"].append(train_w_inter)
        history["val_w_cnn"].append(val_w_cnn)
        history["val_w_lstm"].append(val_w_lstm)
        history["val_w_inter"].append(val_w_inter)

        print(
            f"Fold {fold} | Epoch {epoch:03d} | "
            f"train loss {train_loss:.4f} acc {train_acc:.4f} bal_acc {train_bal_acc:.4f} f1 {train_f1:.4f} | "
            f"val loss {val_loss:.4f} acc {val_acc:.4f} bal_acc {val_bal_acc:.4f} f1 {val_f1:.4f} | "
            f"attn(cnn={val_w_cnn:.3f}, lstm={val_w_lstm:.3f}, inter={val_w_inter:.3f}) | "
            f"lr {lr:.2e}"
        )

        if val_loss <= best_this_fold - early.min_delta:
            best_this_fold = val_loss
            best_state_this_fold = {k: v.detach().cpu().clone() for k, v in model.state_dict().items()}

        if early.step(val_loss):
            print("Early stopping triggered.")
            break

    fold_summaries.append({
        "fold": fold,
        "best_val_loss": best_this_fold,
        "best_val_acc": max(history["val_acc"]) if len(history["val_acc"]) else float("nan"),
        "best_val_f1": max(history["val_f1"]) if len(history["val_f1"]) else float("nan"),
        "history": history,  # keep last fold history for plots below (optional)
    })

    # Track the single best fold model (lowest val loss)
    if best_this_fold < best_fold_loss and best_state_this_fold is not None:
        best_fold_loss = best_this_fold
        best_fold_state = best_state_this_fold

print("\n========== CV Summary ==========")
for s in fold_summaries:
    print(f"Fold {s['fold']}: best val loss={s['best_val_loss']:.4f} | best val acc={s['best_val_acc']:.4f} | best val f1={s['best_val_f1']:.4f}")

mean_acc = np.nanmean([s["best_val_acc"] for s in fold_summaries])
mean_f1 = np.nanmean([s["best_val_f1"] for s in fold_summaries])
print(f"Mean(best val acc) across folds: {mean_acc:.4f}")
print(f"Mean(best val f1 ) across folds: {mean_f1:.4f}")

# Save the best fold checkpoint for the unseen evaluation cell below
if best_fold_state is not None:
    torch.save(best_fold_state, checkpoint_path)
    print("Saved best-fold checkpoint to:", checkpoint_path)
else:
    print("WARNING: best_fold_state is None; no checkpoint saved.")
# Out:
# ========== Fold 1/10 ==========
# /home/rithik-tank/enter/envs/tf_gpu/lib/python3.10/site-packages/torch/nn/modules/rnn.py:1013: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   super().__init__("LSTM", *args, **kwargs)
# Fold 1 | Epoch 001 | train loss 1.8163 acc 0.2627 bal_acc 0.1703 f1 0.1369 | val loss 1.8455 acc 0.1352 bal_acc 0.1720 f1 0.0787 | attn(cnn=0.499, lstm=0.500, inter=0.500) | lr 5.00e-05
# Fold 1 | Epoch 002 | train loss 1.8146 acc 0.2649 bal_acc 0.1760 f1 0.1548 | val loss 1.8426 acc 0.1567 bal_acc 0.1926 f1 0.0959 | attn(cnn=0.499, lstm=0.500, inter=0.501) | lr 5.00e-05
# Fold 1 | Epoch 003 | train loss 1.8101 acc 0.3033 bal_acc 0.1977 f1 0.1844 | val loss 1.8391 acc 0.1373 bal_acc 0.1626 f1 0.0878 | attn(cnn=0.498, lstm=0.500, inter=0.502) | lr 5.00e-05
# Fold 1 | Epoch 004 | train loss 1.8009 acc 0.2933 bal_acc 0.2063 f1 0.1934 | val loss 1.8315 acc 0.1803 bal_acc 0.2203 f1 0.1456 | attn(cnn=0.496, lstm=0.500, inter=0.505) | lr 5.00e-05
# Fold 1 | Epoch 005 | train loss 1.7940 acc 0.2921 bal_acc 0.2165 f1 0.2068 | val loss 1.8261 acc 0.2082 bal_acc 0.2501 f1 0.1608 | attn(cnn=0.495, lstm=0.500, inter=0.509) | lr 5.00e-05
# Fold 1 | Epoch 006 | train loss 1.7854 acc 0.3033 bal_acc 0.2341 f1 0.2229 | val loss 1.8314 acc 0.1953 bal_acc 0.2325 f1 0.1434 | attn(cnn=0.495, lstm=0.500, inter=0.517) | lr 5.00e-05
# Fold 1 | Epoch 007 | train loss 1.7662 acc 0.3671 bal_acc 0.2635 f1 0.2619 | val loss 1.8404 acc 0.1845 bal_acc 0.2216 f1 0.1302 | attn(cnn=0.496, lstm=0.500, inter=0.544) | lr 5.00e-05
# Fold 1 | Epoch 008 | train loss 1.7133 acc 0.4024 bal_acc 0.3067 f1 0.2976 | val loss 1.8751 acc 0.1781 bal_acc 0.2271 f1 0.1218 | attn(cnn=0.501, lstm=0.499, inter=0.662) | lr 5.00e-05
# Fold 1 | Epoch 009 | train loss 1.6561 acc 0.4230 bal_acc 0.3156 f1 0.3077 | val loss 2.0472 acc 0.1223 bal_acc 0.1721 f1 0.0501 | attn(cnn=0.494, lstm=0.490, inter=0.752) | lr 5.00e-05
# Fold 1 | Epoch 010 | train loss 1.6155 acc 0.4180 bal_acc 0.3286 f1 0.3189 | val loss 2.0279 acc 0.1309 bal_acc 0.1805 f1 0.0707 | attn(cnn=0.498, lstm=0.484, inter=0.798) | lr 5.00e-05
# Fold 1 | Epoch 011 | train loss 1.5981 acc 0.4464 bal_acc 0.3475 f1 0.3402 | val loss 2.1605 acc 0.1266 bal_acc 0.1812 f1 0.0657 | attn(cnn=0.494, lstm=0.482, inter=0.805) | lr 5.00e-05
# Fold 1 | Epoch 012 | train loss 1.5695 acc 0.4402 bal_acc 0.3559 f1 0.3455 | val loss 2.1683 acc 0.1459 bal_acc 0.2130 f1 0.0863 | attn(cnn=0.494, lstm=0.479, inter=0.824) | lr 2.50e-05
# Fold 1 | Epoch 013 | train loss 1.5571 acc 0.4481 bal_acc 0.3649 f1 0.3562 | val loss 2.1318 acc 0.1545 bal_acc 0.2186 f1 0.1014 | attn(cnn=0.495, lstm=0.478, inter=0.836) | lr 2.50e-05
# Fold 1 | Epoch 014 | train loss 1.5575 acc 0.4390 bal_acc 0.3531 f1 0.3434 | val loss 2.1058 acc 0.1652 bal_acc 0.2254 f1 0.1204 | attn(cnn=0.497, lstm=0.476, inter=0.845) | lr 2.50e-05
# Fold 1 | Epoch 015 | train loss 1.5465 acc 0.4578 bal_acc 0.3747 f1 0.3653 | val loss 2.1119 acc 0.1524 bal_acc 0.2172 f1 0.1198 | attn(cnn=0.497, lstm=0.474, inter=0.852) | lr 2.50e-05
# Fold 1 | Epoch 016 | train loss 1.5413 acc 0.4521 bal_acc 0.3748 f1 0.3675 | val loss 2.1719 acc 0.1588 bal_acc 0.2242 f1 0.1192 | attn(cnn=0.495, lstm=0.473, inter=0.857) | lr 2.50e-05
# Fold 1 | Epoch 017 | train loss 1.5308 acc 0.4629 bal_acc 0.3798 f1 0.3713 | val loss 2.2020 acc 0.1588 bal_acc 0.2205 f1 0.1161 | attn(cnn=0.494, lstm=0.471, inter=0.861) | lr 2.50e-05
# Fold 1 | Epoch 018 | train loss 1.5185 acc 0.4643 bal_acc 0.3871 f1 0.3778 | val loss 2.1683 acc 0.1545 bal_acc 0.2215 f1 0.1169 | attn(cnn=0.495, lstm=0.470, inter=0.869) | lr 2.50e-05
# Fold 1 | Epoch 019 | train loss 1.5117 acc 0.4774 bal_acc 0.3908 f1 0.3833 | val loss 2.2525 acc 0.1459 bal_acc 0.2089 f1 0.1060 | attn(cnn=0.494, lstm=0.468, inter=0.874) | lr 1.25e-05
# Fold 1 | Epoch 020 | train loss 1.5079 acc 0.4631 bal_acc 0.3902 f1 0.3791 | val loss 2.2524 acc 0.1459 bal_acc 0.2096 f1 0.1014 | attn(cnn=0.494, lstm=0.467, inter=0.877) | lr 1.25e-05
# Early stopping triggered.
#
# ========== Fold 2/10 ==========
# /home/rithik-tank/enter/envs/tf_gpu/lib/python3.10/site-packages/torch/nn/modules/rnn.py:1013: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   super().__init__("LSTM", *args, **kwargs)
# Fold 2 | Epoch 001 | train loss 1.8184 acc 0.1337 bal_acc 0.1750 f1 0.0766 | val loss 1.8487 acc 0.1245 bal_acc 0.1667 f1 0.0370 | attn(cnn=0.500, lstm=0.501, inter=0.500) | lr 5.00e-05
# Fold 2 | Epoch 002 | train loss 1.8154 acc 0.1543 bal_acc 0.1811 f1 0.1052 | val loss 1.8474 acc 0.1395 bal_acc 0.1726 f1 0.0491 | attn(cnn=0.500, lstm=0.501, inter=0.501) | lr 5.00e-05
# Fold 2 | Epoch 003 | train loss 1.8128 acc 0.1904 bal_acc 0.1941 f1 0.1345 | val loss 1.8447 acc 0.1481 bal_acc 0.1738 f1 0.0847 | attn(cnn=0.500, lstm=0.501, inter=0.502) | lr 5.00e-05
# Fold 2 | Epoch 004 | train loss 1.8062 acc 0.2842 bal_acc 0.2159 f1 0.1838 | val loss 1.8365 acc 0.1588 bal_acc 0.1762 f1 0.1057 | attn(cnn=0.498, lstm=0.501, inter=0.508) | lr 5.00e-05
# Fold 2 | Epoch 005 | train loss 1.7911 acc 0.3480 bal_acc 0.2369 f1 0.2300 | val loss 1.8329 acc 0.1824 bal_acc 0.2165 f1 0.1216 | attn(cnn=0.496, lstm=0.501, inter=0.523) | lr 5.00e-05
# Fold 2 | Epoch 006 | train loss 1.7531 acc 0.3680 bal_acc 0.2812 f1 0.2740 | val loss 1.8393 acc 0.1717 bal_acc 0.1980 f1 0.0939 | attn(cnn=0.487, lstm=0.501, inter=0.601) | lr 5.00e-05
# Fold 2 | Epoch 007 | train loss 1.6792 acc 0.4215 bal_acc 0.3149 f1 0.2983 | val loss 1.9153 acc 0.1524 bal_acc 0.1861 f1 0.0731 | attn(cnn=0.481, lstm=0.501, inter=0.757) | lr 5.00e-05
# Fold 2 | Epoch 008 | train loss 1.6287 acc 0.4194 bal_acc 0.3338 f1 0.3164 | val loss 2.0110 acc 0.1438 bal_acc 0.1806 f1 0.0639 | attn(cnn=0.480, lstm=0.502, inter=0.786) | lr 5.00e-05
# Fold 2 | Epoch 009 | train loss 1.5991 acc 0.4244 bal_acc 0.3382 f1 0.3260 | val loss 2.0530 acc 0.1438 bal_acc 0.1825 f1 0.0690 | attn(cnn=0.478, lstm=0.501, inter=0.803) | lr 5.00e-05
# Fold 2 | Epoch 010 | train loss 1.5813 acc 0.4478 bal_acc 0.3567 f1 0.3453 | val loss 2.1778 acc 0.1416 bal_acc 0.1816 f1 0.0672 | attn(cnn=0.471, lstm=0.502, inter=0.817) | lr 5.00e-05
# Fold 2 | Epoch 011 | train loss 1.5582 acc 0.4430 bal_acc 0.3522 f1 0.3420 | val loss 2.2994 acc 0.1545 bal_acc 0.2013 f1 0.0833 | attn(cnn=0.465, lstm=0.504, inter=0.835) | lr 5.00e-05
# Fold 2 | Epoch 012 | train loss 1.5364 acc 0.4535 bal_acc 0.3693 f1 0.3615 | val loss 2.3954 acc 0.1609 bal_acc 0.2100 f1 0.0923 | attn(cnn=0.460, lstm=0.507, inter=0.847) | lr 2.50e-05
# Fold 2 | Epoch 013 | train loss 1.5336 acc 0.4641 bal_acc 0.3793 f1 0.3725 | val loss 2.3303 acc 0.1910 bal_acc 0.2467 f1 0.1317 | attn(cnn=0.463, lstm=0.508, inter=0.859) | lr 2.50e-05
# Fold 2 | Epoch 014 | train loss 1.5108 acc 0.4703 bal_acc 0.3844 f1 0.3765 | val loss 2.4001 acc 0.1695 bal_acc 0.2138 f1 0.1179 | attn(cnn=0.461, lstm=0.510, inter=0.867) | lr 2.50e-05
# Fold 2 | Epoch 015 | train loss 1.5035 acc 0.4741 bal_acc 0.3963 f1 0.3886 | val loss 2.3418 acc 0.1545 bal_acc 0.1904 f1 0.0984 | attn(cnn=0.464, lstm=0.512, inter=0.877) | lr 2.50e-05
# Fold 2 | Epoch 016 | train loss 1.4997 acc 0.4758 bal_acc 0.3944 f1 0.3866 | val loss 2.4188 acc 0.1459 bal_acc 0.1795 f1 0.0808 | attn(cnn=0.460, lstm=0.514, inter=0.884) | lr 2.50e-05
# Fold 2 | Epoch 017 | train loss 1.4896 acc 0.4856 bal_acc 0.4094 f1 0.4003 | val loss 2.4812 acc 0.1438 bal_acc 0.1760 f1 0.0693 | attn(cnn=0.456, lstm=0.515, inter=0.888) | lr 2.50e-05
# Fold 2 | Epoch 018 | train loss 1.4772 acc 0.4798 bal_acc 0.4123 f1 0.4018 | val loss 2.4391 acc 0.1481 bal_acc 0.1793 f1 0.0613 | attn(cnn=0.458, lstm=0.517, inter=0.896) | lr 2.50e-05
# Fold 2 | Epoch 019 | train loss 1.4715 acc 0.4803 bal_acc 0.4094 f1 0.3967 | val loss 2.5981 acc 0.1416 bal_acc 0.1743 f1 0.0526 | attn(cnn=0.451, lstm=0.519, inter=0.898) | lr 1.25e-05
# Fold 2 | Epoch 020 | train loss 1.4628 acc 0.4977 bal_acc 0.4268 f1 0.4165 | val loss 2.4834 acc 0.1459 bal_acc 0.1760 f1 0.0559 | attn(cnn=0.455, lstm=0.520, inter=0.904) | lr 1.25e-05
# Early stopping triggered.
#
# ========== Fold 3/10 ==========
# /home/rithik-tank/enter/envs/tf_gpu/lib/python3.10/site-packages/torch/nn/modules/rnn.py:1013: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   super().__init__("LSTM", *args, **kwargs)
# Fold 3 | Epoch 001 | train loss 1.8167 acc 0.1457 bal_acc 0.1701 f1 0.1242 | val loss 1.8534 acc 0.1202 bal_acc 0.1685 f1 0.0427 | attn(cnn=0.499, lstm=0.499, inter=0.502) | lr 5.00e-05
# Fold 3 | Epoch 002 | train loss 1.8147 acc 0.1813 bal_acc 0.1888 f1 0.1682 | val loss 1.8530 acc 0.1567 bal_acc 0.1877 f1 0.0946 | attn(cnn=0.499, lstm=0.499, inter=0.502) | lr 5.00e-05
# Fold 3 | Epoch 003 | train loss 1.8122 acc 0.1937 bal_acc 0.2116 f1 0.1802 | val loss 1.8516 acc 0.2253 bal_acc 0.2460 f1 0.1774 | attn(cnn=0.498, lstm=0.499, inter=0.503) | lr 5.00e-05
# Fold 3 | Epoch 004 | train loss 1.8086 acc 0.2321 bal_acc 0.2283 f1 0.2111 | val loss 1.8459 acc 0.2747 bal_acc 0.2794 f1 0.2001 | attn(cnn=0.497, lstm=0.499, inter=0.505) | lr 5.00e-05
# Fold 3 | Epoch 005 | train loss 1.7998 acc 0.3193 bal_acc 0.2616 f1 0.2490 | val loss 1.8392 acc 0.3133 bal_acc 0.3486 f1 0.2735 | attn(cnn=0.495, lstm=0.499, inter=0.511) | lr 5.00e-05
# Fold 3 | Epoch 006 | train loss 1.7782 acc 0.3661 bal_acc 0.2833 f1 0.2772 | val loss 1.8290 acc 0.2296 bal_acc 0.2725 f1 0.1900 | attn(cnn=0.491, lstm=0.499, inter=0.541) | lr 5.00e-05
# Fold 3 | Epoch 007 | train loss 1.7193 acc 0.4263 bal_acc 0.3120 f1 0.2917 | val loss 1.8879 acc 0.1459 bal_acc 0.1938 f1 0.0934 | attn(cnn=0.486, lstm=0.499, inter=0.619) | lr 5.00e-05
# Fold 3 | Epoch 008 | train loss 1.6406 acc 0.4349 bal_acc 0.3371 f1 0.3217 | val loss 2.0023 acc 0.1288 bal_acc 0.1787 f1 0.0678 | attn(cnn=0.480, lstm=0.499, inter=0.689) | lr 5.00e-05
# Fold 3 | Epoch 009 | train loss 1.6000 acc 0.4464 bal_acc 0.3579 f1 0.3439 | val loss 2.0930 acc 0.1416 bal_acc 0.1960 f1 0.0824 | attn(cnn=0.484, lstm=0.502, inter=0.784) | lr 5.00e-05
# Fold 3 | Epoch 010 | train loss 1.5648 acc 0.4349 bal_acc 0.3625 f1 0.3470 | val loss 2.2678 acc 0.1352 bal_acc 0.1892 f1 0.0656 | attn(cnn=0.478, lstm=0.504, inter=0.823) | lr 5.00e-05
# Fold 3 | Epoch 011 | train loss 1.5525 acc 0.4483 bal_acc 0.3763 f1 0.3623 | val loss 2.3815 acc 0.1309 bal_acc 0.1827 f1 0.0655 | attn(cnn=0.483, lstm=0.507, inter=0.846) | lr 5.00e-05
# Fold 3 | Epoch 012 | train loss 1.5093 acc 0.4626 bal_acc 0.3965 f1 0.3787 | val loss 2.4683 acc 0.1416 bal_acc 0.2011 f1 0.0747 | attn(cnn=0.485, lstm=0.510, inter=0.870) | lr 5.00e-05
# Fold 3 | Epoch 013 | train loss 1.4955 acc 0.4655 bal_acc 0.4047 f1 0.3857 | val loss 2.5261 acc 0.1459 bal_acc 0.2054 f1 0.0819 | attn(cnn=0.485, lstm=0.512, inter=0.879) | lr 2.50e-05
# Fold 3 | Epoch 014 | train loss 1.4757 acc 0.4676 bal_acc 0.4202 f1 0.3998 | val loss 2.5865 acc 0.1588 bal_acc 0.2216 f1 0.0953 | attn(cnn=0.485, lstm=0.513, inter=0.887) | lr 2.50e-05
# Fold 3 | Epoch 015 | train loss 1.4604 acc 0.4789 bal_acc 0.4219 f1 0.4042 | val loss 2.6293 acc 0.1588 bal_acc 0.2221 f1 0.0962 | attn(cnn=0.485, lstm=0.514, inter=0.893) | lr 2.50e-05
# Fold 3 | Epoch 016 | train loss 1.4606 acc 0.4796 bal_acc 0.4329 f1 0.4137 | val loss 2.6790 acc 0.1588 bal_acc 0.2221 f1 0.0962 | attn(cnn=0.486, lstm=0.515, inter=0.898) | lr 2.50e-05
# Fold 3 | Epoch 017 | train loss 1.4497 acc 0.4786 bal_acc 0.4294 f1 0.4088 | val loss 2.5268 acc 0.1459 bal_acc 0.2006 f1 0.0949 | attn(cnn=0.494, lstm=0.516, inter=0.903) | lr 2.50e-05
# Fold 3 | Epoch 018 | train loss 1.4317 acc 0.4977 bal_acc 0.4432 f1 0.4236 | val loss 2.7372 acc 0.1524 bal_acc 0.2076 f1 0.0966 | attn(cnn=0.487, lstm=0.517, inter=0.906) | lr 2.50e-05
# Fold 3 | Epoch 019 | train loss 1.4248 acc 0.4951 bal_acc 0.4540 f1 0.4320 | val loss 2.7669 acc 0.1609 bal_acc 0.2208 f1 0.1053 | attn(cnn=0.488, lstm=0.517, inter=0.911) | lr 2.50e-05
# Fold 3 | Epoch 020 | train loss 1.4167 acc 0.4896 bal_acc 0.4524 f1 0.4259 | val loss 2.8632 acc 0.1438 bal_acc 0.1962 f1 0.0840 | attn(cnn=0.487, lstm=0.519, inter=0.913) | lr 1.25e-05
# Fold 3 | Epoch 021 | train loss 1.4014 acc 0.4901 bal_acc 0.4526 f1 0.4224 | val loss 2.7374 acc 0.1524 bal_acc 0.2076 f1 0.1004 | attn(cnn=0.491, lstm=0.519, inter=0.917) | lr 1.25e-05
# Early stopping triggered.
#
# ========== Fold 4/10 ==========
# /home/rithik-tank/enter/envs/tf_gpu/lib/python3.10/site-packages/torch/nn/modules/rnn.py:1013: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   super().__init__("LSTM", *args, **kwargs)
# Fold 4 | Epoch 001 | train loss 1.8185 acc 0.2729 bal_acc 0.1707 f1 0.1214 | val loss 1.8380 acc 0.3957 bal_acc 0.2166 f1 0.1478 | attn(cnn=0.503, lstm=0.501, inter=0.500) | lr 5.00e-05
# Fold 4 | Epoch 002 | train loss 1.8164 acc 0.2634 bal_acc 0.1778 f1 0.1443 | val loss 1.8388 acc 0.3247 bal_acc 0.2176 f1 0.1364 | attn(cnn=0.503, lstm=0.501, inter=0.501) | lr 5.00e-05
# Fold 4 | Epoch 003 | train loss 1.8140 acc 0.2794 bal_acc 0.2048 f1 0.1923 | val loss 1.8382 acc 0.2688 bal_acc 0.2120 f1 0.1230 | attn(cnn=0.502, lstm=0.501, inter=0.502) | lr 5.00e-05
# Fold 4 | Epoch 004 | train loss 1.8085 acc 0.3259 bal_acc 0.2304 f1 0.2246 | val loss 1.8329 acc 0.2581 bal_acc 0.2202 f1 0.1332 | attn(cnn=0.501, lstm=0.501, inter=0.505) | lr 5.00e-05
# Fold 4 | Epoch 005 | train loss 1.7963 acc 0.3269 bal_acc 0.2326 f1 0.2277 | val loss 1.8171 acc 0.2151 bal_acc 0.2032 f1 0.1036 | attn(cnn=0.498, lstm=0.501, inter=0.517) | lr 5.00e-05
# Fold 4 | Epoch 006 | train loss 1.7691 acc 0.3357 bal_acc 0.2452 f1 0.2428 | val loss 1.7984 acc 0.2430 bal_acc 0.2467 f1 0.1914 | attn(cnn=0.500, lstm=0.501, inter=0.562) | lr 5.00e-05
# Fold 4 | Epoch 007 | train loss 1.6995 acc 0.3732 bal_acc 0.2861 f1 0.2752 | val loss 1.7743 acc 0.2387 bal_acc 0.2605 f1 0.1832 | attn(cnn=0.517, lstm=0.502, inter=0.691) | lr 5.00e-05
# Fold 4 | Epoch 008 | train loss 1.6258 acc 0.3976 bal_acc 0.3197 f1 0.3061 | val loss 1.8042 acc 0.2108 bal_acc 0.2479 f1 0.2069 | attn(cnn=0.518, lstm=0.502, inter=0.766) | lr 5.00e-05
# Fold 4 | Epoch 009 | train loss 1.6005 acc 0.4033 bal_acc 0.3263 f1 0.3172 | val loss 2.0130 acc 0.1699 bal_acc 0.2154 f1 0.1304 | attn(cnn=0.523, lstm=0.502, inter=0.807) | lr 5.00e-05
# Fold 4 | Epoch 010 | train loss 1.5866 acc 0.4071 bal_acc 0.3155 f1 0.3105 | val loss 1.8489 acc 0.2430 bal_acc 0.2798 f1 0.2175 | attn(cnn=0.518, lstm=0.502, inter=0.826) | lr 5.00e-05
# Fold 4 | Epoch 011 | train loss 1.5670 acc 0.4210 bal_acc 0.3404 f1 0.3305 | val loss 1.8866 acc 0.2366 bal_acc 0.2655 f1 0.2014 | attn(cnn=0.519, lstm=0.503, inter=0.843) | lr 5.00e-05
# Fold 4 | Epoch 012 | train loss 1.5561 acc 0.4186 bal_acc 0.3438 f1 0.3370 | val loss 1.8465 acc 0.2624 bal_acc 0.2781 f1 0.2324 | attn(cnn=0.518, lstm=0.502, inter=0.859) | lr 5.00e-05
# Fold 4 | Epoch 013 | train loss 1.5469 acc 0.4341 bal_acc 0.3552 f1 0.3467 | val loss 1.6745 acc 0.3441 bal_acc 0.3202 f1 0.2628 | attn(cnn=0.515, lstm=0.503, inter=0.873) | lr 5.00e-05
# Fold 4 | Epoch 014 | train loss 1.5296 acc 0.4358 bal_acc 0.3611 f1 0.3514 | val loss 2.0238 acc 0.2043 bal_acc 0.2463 f1 0.1649 | attn(cnn=0.514, lstm=0.503, inter=0.881) | lr 5.00e-05
# Fold 4 | Epoch 015 | train loss 1.5050 acc 0.4501 bal_acc 0.3773 f1 0.3679 | val loss 1.7925 acc 0.2581 bal_acc 0.2865 f1 0.2182 | attn(cnn=0.511, lstm=0.503, inter=0.898) | lr 5.00e-05
# Fold 4 | Epoch 016 | train loss 1.5069 acc 0.4487 bal_acc 0.3726 f1 0.3641 | val loss 1.8773 acc 0.2516 bal_acc 0.2871 f1 0.2152 | attn(cnn=0.508, lstm=0.504, inter=0.907) | lr 5.00e-05
# Fold 4 | Epoch 017 | train loss 1.4900 acc 0.4702 bal_acc 0.3997 f1 0.3885 | val loss 1.8347 acc 0.2366 bal_acc 0.2546 f1 0.1871 | attn(cnn=0.511, lstm=0.505, inter=0.914) | lr 5.00e-05
# Fold 4 | Epoch 018 | train loss 1.4667 acc 0.4766 bal_acc 0.4092 f1 0.3987 | val loss 1.9214 acc 0.2538 bal_acc 0.2886 f1 0.2127 | attn(cnn=0.509, lstm=0.506, inter=0.923) | lr 5.00e-05
# Fold 4 | Epoch 019 | train loss 1.4621 acc 0.4828 bal_acc 0.4161 f1 0.4054 | val loss 2.0657 acc 0.2086 bal_acc 0.2459 f1 0.1769 | attn(cnn=0.511, lstm=0.506, inter=0.931) | lr 5.00e-05
# Fold 4 | Epoch 020 | train loss 1.4637 acc 0.4842 bal_acc 0.4160 f1 0.4055 | val loss 1.9555 acc 0.2645 bal_acc 0.3043 f1 0.2291 | attn(cnn=0.508, lstm=0.507, inter=0.936) | lr 2.50e-05
# Fold 4 | Epoch 021 | train loss 1.4306 acc 0.5017 bal_acc 0.4464 f1 0.4315 | val loss 1.9542 acc 0.2516 bal_acc 0.2947 f1 0.2117 | attn(cnn=0.509, lstm=0.507, inter=0.939) | lr 2.50e-05
# Fold 4 | Epoch 022 | train loss 1.4379 acc 0.5060 bal_acc 0.4342 f1 0.4235 | val loss 2.0764 acc 0.2301 bal_acc 0.2703 f1 0.1919 | attn(cnn=0.512, lstm=0.507, inter=0.942) | lr 2.50e-05
# Fold 4 | Epoch 023 | train loss 1.4329 acc 0.4933 bal_acc 0.4297 f1 0.4176 | val loss 1.8856 acc 0.2559 bal_acc 0.2905 f1 0.2180 | attn(cnn=0.510, lstm=0.507, inter=0.944) | lr 2.50e-05
# Fold 4 | Epoch 024 | train loss 1.4280 acc 0.5038 bal_acc 0.4454 f1 0.4314 | val loss 1.8549 acc 0.2688 bal_acc 0.3188 f1 0.2480 | attn(cnn=0.510, lstm=0.508, inter=0.949) | lr 2.50e-05
# Fold 4 | Epoch 025 | train loss 1.4103 acc 0.5050 bal_acc 0.4454 f1 0.4317 | val loss 1.8802 acc 0.2731 bal_acc 0.3163 f1 0.2571 | attn(cnn=0.508, lstm=0.508, inter=0.951) | lr 2.50e-05
# Fold 4 | Epoch 026 | train loss 1.4089 acc 0.5136 bal_acc 0.4575 f1 0.4425 | val loss 1.8997 acc 0.2538 bal_acc 0.2980 f1 0.2370 | attn(cnn=0.510, lstm=0.509, inter=0.954) | lr 2.50e-05
# Fold 4 | Epoch 027 | train loss 1.4032 acc 0.5069 bal_acc 0.4501 f1 0.4370 | val loss 1.8503 acc 0.2774 bal_acc 0.3180 f1 0.2580 | attn(cnn=0.510, lstm=0.509, inter=0.955) | lr 1.25e-05
# Fold 4 | Epoch 028 | train loss 1.4048 acc 0.5170 bal_acc 0.4532 f1 0.4402 | val loss 1.9512 acc 0.2645 bal_acc 0.3112 f1 0.2448 | attn(cnn=0.511, lstm=0.509, inter=0.956) | lr 1.25e-05
# Early stopping triggered.
#
# ========== Fold 5/10 ==========
# /home/rithik-tank/enter/envs/tf_gpu/lib/python3.10/site-packages/torch/nn/modules/rnn.py:1013: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   super().__init__("LSTM", *args, **kwargs)
# Fold 5 | Epoch 001 | train loss 1.8180 acc 0.1662 bal_acc 0.1662 f1 0.0955 | val loss 1.8449 acc 0.1183 bal_acc 0.1701 f1 0.0399 | attn(cnn=0.503, lstm=0.501, inter=0.502) | lr 5.00e-05
# Fold 5 | Epoch 002 | train loss 1.8148 acc 0.1929 bal_acc 0.1839 f1 0.1393 | val loss 1.8426 acc 0.1376 bal_acc 0.1753 f1 0.0554 | attn(cnn=0.503, lstm=0.501, inter=0.503) | lr 5.00e-05
# Fold 5 | Epoch 003 | train loss 1.8126 acc 0.1984 bal_acc 0.1953 f1 0.1584 | val loss 1.8387 acc 0.1785 bal_acc 0.1842 f1 0.0828 | attn(cnn=0.503, lstm=0.501, inter=0.504) | lr 5.00e-05
# Fold 5 | Epoch 004 | train loss 1.8070 acc 0.2674 bal_acc 0.2297 f1 0.2188 | val loss 1.8280 acc 0.2172 bal_acc 0.1892 f1 0.1134 | attn(cnn=0.501, lstm=0.501, inter=0.508) | lr 5.00e-05
# Fold 5 | Epoch 005 | train loss 1.7964 acc 0.3118 bal_acc 0.2405 f1 0.2354 | val loss 1.8147 acc 0.2667 bal_acc 0.2612 f1 0.1850 | attn(cnn=0.497, lstm=0.501, inter=0.520) | lr 5.00e-05
# Fold 5 | Epoch 006 | train loss 1.7803 acc 0.3166 bal_acc 0.2590 f1 0.2489 | val loss 1.8025 acc 0.2860 bal_acc 0.3129 f1 0.2418 | attn(cnn=0.497, lstm=0.501, inter=0.546) | lr 5.00e-05
# Fold 5 | Epoch 007 | train loss 1.7385 acc 0.3491 bal_acc 0.2897 f1 0.2784 | val loss 1.7360 acc 0.4086 bal_acc 0.3727 f1 0.3491 | attn(cnn=0.498, lstm=0.501, inter=0.641) | lr 5.00e-05
# Fold 5 | Epoch 008 | train loss 1.6638 acc 0.3687 bal_acc 0.3088 f1 0.2978 | val loss 1.6811 acc 0.3978 bal_acc 0.3756 f1 0.3335 | attn(cnn=0.494, lstm=0.494, inter=0.794) | lr 5.00e-05
# Fold 5 | Epoch 009 | train loss 1.6147 acc 0.4133 bal_acc 0.3489 f1 0.3388 | val loss 1.7107 acc 0.3247 bal_acc 0.3465 f1 0.2840 | attn(cnn=0.491, lstm=0.485, inter=0.852) | lr 5.00e-05
# Fold 5 | Epoch 010 | train loss 1.5880 acc 0.4183 bal_acc 0.3489 f1 0.3391 | val loss 1.7567 acc 0.2839 bal_acc 0.3179 f1 0.2383 | attn(cnn=0.484, lstm=0.481, inter=0.874) | lr 5.00e-05
# Fold 5 | Epoch 011 | train loss 1.5619 acc 0.4176 bal_acc 0.3641 f1 0.3495 | val loss 1.8257 acc 0.2387 bal_acc 0.2818 f1 0.1893 | attn(cnn=0.474, lstm=0.479, inter=0.886) | lr 5.00e-05
# Fold 5 | Epoch 012 | train loss 1.5403 acc 0.4284 bal_acc 0.3797 f1 0.3615 | val loss 1.7874 acc 0.2839 bal_acc 0.3217 f1 0.2417 | attn(cnn=0.472, lstm=0.476, inter=0.897) | lr 5.00e-05
# Fold 5 | Epoch 013 | train loss 1.5187 acc 0.4288 bal_acc 0.3851 f1 0.3661 | val loss 1.8953 acc 0.2172 bal_acc 0.2719 f1 0.1597 | attn(cnn=0.460, lstm=0.475, inter=0.904) | lr 5.00e-05
# Fold 5 | Epoch 014 | train loss 1.5089 acc 0.4561 bal_acc 0.3955 f1 0.3812 | val loss 1.9098 acc 0.2151 bal_acc 0.2698 f1 0.1668 | attn(cnn=0.456, lstm=0.474, inter=0.912) | lr 5.00e-05
# Fold 5 | Epoch 015 | train loss 1.4884 acc 0.4568 bal_acc 0.4090 f1 0.3918 | val loss 2.1857 acc 0.1849 bal_acc 0.2391 f1 0.1402 | attn(cnn=0.443, lstm=0.472, inter=0.918) | lr 2.50e-05
# Fold 5 | Epoch 016 | train loss 1.4779 acc 0.4489 bal_acc 0.4104 f1 0.3891 | val loss 2.0475 acc 0.2086 bal_acc 0.2727 f1 0.1833 | attn(cnn=0.446, lstm=0.471, inter=0.921) | lr 2.50e-05
# Fold 5 | Epoch 017 | train loss 1.4669 acc 0.4647 bal_acc 0.4172 f1 0.4003 | val loss 2.0536 acc 0.2108 bal_acc 0.2743 f1 0.1864 | attn(cnn=0.443, lstm=0.471, inter=0.923) | lr 2.50e-05
# Fold 5 | Epoch 018 | train loss 1.4550 acc 0.4752 bal_acc 0.4293 f1 0.4096 | val loss 2.2305 acc 0.1871 bal_acc 0.2452 f1 0.1563 | attn(cnn=0.436, lstm=0.470, inter=0.925) | lr 2.50e-05
# Fold 5 | Epoch 019 | train loss 1.4499 acc 0.4799 bal_acc 0.4321 f1 0.4142 | val loss 2.3352 acc 0.1828 bal_acc 0.2420 f1 0.1475 | attn(cnn=0.429, lstm=0.470, inter=0.926) | lr 2.50e-05
# Fold 5 | Epoch 020 | train loss 1.4482 acc 0.4666 bal_acc 0.4258 f1 0.4024 | val loss 2.1520 acc 0.2065 bal_acc 0.2738 f1 0.1848 | attn(cnn=0.437, lstm=0.469, inter=0.931) | lr 2.50e-05
# Fold 5 | Epoch 021 | train loss 1.4330 acc 0.4661 bal_acc 0.4311 f1 0.4062 | val loss 2.1824 acc 0.2065 bal_acc 0.2745 f1 0.1837 | attn(cnn=0.433, lstm=0.468, inter=0.935) | lr 2.50e-05
# Fold 5 | Epoch 022 | train loss 1.4292 acc 0.4670 bal_acc 0.4269 f1 0.4053 | val loss 2.3241 acc 0.2000 bal_acc 0.2693 f1 0.1731 | attn(cnn=0.427, lstm=0.468, inter=0.935) | lr 1.25e-05
# Fold 5 | Epoch 023 | train loss 1.4158 acc 0.4885 bal_acc 0.4523 f1 0.4289 | val loss 2.1445 acc 0.2129 bal_acc 0.2832 f1 0.1961 | attn(cnn=0.433, lstm=0.467, inter=0.939) | lr 1.25e-05
# Early stopping triggered.
#
# ========== Fold 6/10 ==========
# /home/rithik-tank/enter/envs/tf_gpu/lib/python3.10/site-packages/torch/nn/modules/rnn.py:1013: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   super().__init__("LSTM", *args, **kwargs)
# Fold 6 | Epoch 001 | train loss 1.8172 acc 0.1160 bal_acc 0.1689 f1 0.0582 | val loss 1.8511 acc 0.1097 bal_acc 0.1667 f1 0.0329 | attn(cnn=0.500, lstm=0.501, inter=0.498) | lr 5.00e-05
# Fold 6 | Epoch 002 | train loss 1.8156 acc 0.1366 bal_acc 0.1763 f1 0.0820 | val loss 1.8497 acc 0.1183 bal_acc 0.1701 f1 0.0399 | attn(cnn=0.500, lstm=0.501, inter=0.498) | lr 5.00e-05
# Fold 6 | Epoch 003 | train loss 1.8129 acc 0.1502 bal_acc 0.1804 f1 0.1147 | val loss 1.8481 acc 0.1548 bal_acc 0.1821 f1 0.0671 | attn(cnn=0.499, lstm=0.501, inter=0.500) | lr 5.00e-05
# Fold 6 | Epoch 004 | train loss 1.8087 acc 0.2381 bal_acc 0.2193 f1 0.1806 | val loss 1.8428 acc 0.2086 bal_acc 0.2068 f1 0.1144 | attn(cnn=0.498, lstm=0.501, inter=0.503) | lr 5.00e-05
# Fold 6 | Epoch 005 | train loss 1.7990 acc 0.2985 bal_acc 0.2354 f1 0.2229 | val loss 1.8353 acc 0.1892 bal_acc 0.2064 f1 0.1252 | attn(cnn=0.496, lstm=0.501, inter=0.514) | lr 5.00e-05
# Fold 6 | Epoch 006 | train loss 1.7708 acc 0.3646 bal_acc 0.2780 f1 0.2712 | val loss 1.8348 acc 0.1613 bal_acc 0.1947 f1 0.0970 | attn(cnn=0.490, lstm=0.501, inter=0.562) | lr 5.00e-05
# Fold 6 | Epoch 007 | train loss 1.7038 acc 0.4040 bal_acc 0.3030 f1 0.2884 | val loss 1.9290 acc 0.1548 bal_acc 0.2027 f1 0.0882 | attn(cnn=0.465, lstm=0.501, inter=0.677) | lr 5.00e-05
# Fold 6 | Epoch 008 | train loss 1.6331 acc 0.4224 bal_acc 0.3176 f1 0.2945 | val loss 2.0953 acc 0.1419 bal_acc 0.1899 f1 0.0733 | attn(cnn=0.452, lstm=0.501, inter=0.746) | lr 5.00e-05
# Fold 6 | Epoch 009 | train loss 1.5941 acc 0.4284 bal_acc 0.3427 f1 0.3259 | val loss 2.1300 acc 0.1419 bal_acc 0.1902 f1 0.0724 | attn(cnn=0.458, lstm=0.498, inter=0.831) | lr 5.00e-05
# Fold 6 | Epoch 010 | train loss 1.5679 acc 0.4362 bal_acc 0.3499 f1 0.3375 | val loss 2.2515 acc 0.1505 bal_acc 0.2064 f1 0.0839 | attn(cnn=0.453, lstm=0.495, inter=0.861) | lr 5.00e-05
# Fold 6 | Epoch 011 | train loss 1.5510 acc 0.4558 bal_acc 0.3677 f1 0.3543 | val loss 2.3429 acc 0.1484 bal_acc 0.2078 f1 0.0887 | attn(cnn=0.452, lstm=0.494, inter=0.878) | lr 5.00e-05
# Fold 6 | Epoch 012 | train loss 1.5439 acc 0.4558 bal_acc 0.3660 f1 0.3558 | val loss 2.3872 acc 0.1462 bal_acc 0.1861 f1 0.0730 | attn(cnn=0.452, lstm=0.492, inter=0.891) | lr 5.00e-05
# Fold 6 | Epoch 013 | train loss 1.5069 acc 0.4706 bal_acc 0.3936 f1 0.3839 | val loss 2.6072 acc 0.1333 bal_acc 0.1830 f1 0.0923 | attn(cnn=0.442, lstm=0.490, inter=0.904) | lr 2.50e-05
# Fold 6 | Epoch 014 | train loss 1.4893 acc 0.4840 bal_acc 0.4011 f1 0.3847 | val loss 2.6150 acc 0.1333 bal_acc 0.1776 f1 0.0830 | attn(cnn=0.445, lstm=0.489, inter=0.913) | lr 2.50e-05
# Fold 6 | Epoch 015 | train loss 1.4895 acc 0.4608 bal_acc 0.3892 f1 0.3772 | val loss 2.6768 acc 0.1247 bal_acc 0.1708 f1 0.0759 | attn(cnn=0.442, lstm=0.489, inter=0.918) | lr 2.50e-05
# Fold 6 | Epoch 016 | train loss 1.4727 acc 0.4904 bal_acc 0.4212 f1 0.4081 | val loss 2.7436 acc 0.1204 bal_acc 0.1616 f1 0.0672 | attn(cnn=0.440, lstm=0.488, inter=0.923) | lr 2.50e-05
# Fold 6 | Epoch 017 | train loss 1.4583 acc 0.4976 bal_acc 0.4313 f1 0.4176 | val loss 2.7852 acc 0.1247 bal_acc 0.1620 f1 0.0619 | attn(cnn=0.439, lstm=0.488, inter=0.928) | lr 2.50e-05
# Fold 6 | Epoch 018 | train loss 1.4436 acc 0.4928 bal_acc 0.4264 f1 0.4111 | val loss 2.9495 acc 0.1333 bal_acc 0.1754 f1 0.0632 | attn(cnn=0.433, lstm=0.488, inter=0.931) | lr 2.50e-05
# Fold 6 | Epoch 019 | train loss 1.4515 acc 0.4981 bal_acc 0.4275 f1 0.4157 | val loss 2.7786 acc 0.1312 bal_acc 0.1714 f1 0.0666 | attn(cnn=0.440, lstm=0.487, inter=0.936) | lr 2.50e-05
# Fold 6 | Epoch 020 | train loss 1.4361 acc 0.5069 bal_acc 0.4432 f1 0.4291 | val loss 2.9912 acc 0.1269 bal_acc 0.1677 f1 0.0638 | attn(cnn=0.432, lstm=0.487, inter=0.938) | lr 1.25e-05
# Fold 6 | Epoch 021 | train loss 1.4274 acc 0.5029 bal_acc 0.4439 f1 0.4284 | val loss 3.0150 acc 0.1247 bal_acc 0.1661 f1 0.0599 | attn(cnn=0.431, lstm=0.486, inter=0.940) | lr 1.25e-05
# Early stopping triggered.
#
# ========== Fold 7/10 ==========
# /home/rithik-tank/enter/envs/tf_gpu/lib/python3.10/site-packages/torch/nn/modules/rnn.py:1013: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   super().__init__("LSTM", *args, **kwargs)
# Fold 7 | Epoch 001 | train loss 1.8175 acc 0.1299 bal_acc 0.1735 f1 0.0823 | val loss 1.8486 acc 0.1097 bal_acc 0.1667 f1 0.0329 | attn(cnn=0.499, lstm=0.497, inter=0.500) | lr 5.00e-05
# Fold 7 | Epoch 002 | train loss 1.8144 acc 0.1500 bal_acc 0.1893 f1 0.1227 | val loss 1.8490 acc 0.1097 bal_acc 0.1667 f1 0.0330 | attn(cnn=0.499, lstm=0.497, inter=0.500) | lr 5.00e-05
# Fold 7 | Epoch 003 | train loss 1.8132 acc 0.1578 bal_acc 0.1906 f1 0.1353 | val loss 1.8483 acc 0.1183 bal_acc 0.1701 f1 0.0400 | attn(cnn=0.499, lstm=0.497, inter=0.501) | lr 5.00e-05
# Fold 7 | Epoch 004 | train loss 1.8094 acc 0.1975 bal_acc 0.2045 f1 0.1680 | val loss 1.8451 acc 0.1398 bal_acc 0.1872 f1 0.0733 | attn(cnn=0.498, lstm=0.497, inter=0.503) | lr 5.00e-05
# Fold 7 | Epoch 005 | train loss 1.8010 acc 0.2500 bal_acc 0.2411 f1 0.2164 | val loss 1.8446 acc 0.1398 bal_acc 0.1895 f1 0.0773 | attn(cnn=0.498, lstm=0.497, inter=0.508) | lr 5.00e-05
# Fold 7 | Epoch 006 | train loss 1.7737 acc 0.3450 bal_acc 0.2829 f1 0.2734 | val loss 1.8607 acc 0.1677 bal_acc 0.2234 f1 0.1180 | attn(cnn=0.492, lstm=0.497, inter=0.535) | lr 5.00e-05
# Fold 7 | Epoch 007 | train loss 1.7018 acc 0.3789 bal_acc 0.2905 f1 0.2723 | val loss 1.9439 acc 0.1462 bal_acc 0.2002 f1 0.0873 | attn(cnn=0.484, lstm=0.497, inter=0.599) | lr 5.00e-05
# Fold 7 | Epoch 008 | train loss 1.6267 acc 0.3966 bal_acc 0.3179 f1 0.2978 | val loss 2.1178 acc 0.1333 bal_acc 0.1838 f1 0.0691 | attn(cnn=0.473, lstm=0.498, inter=0.643) | lr 5.00e-05
# Fold 7 | Epoch 009 | train loss 1.6006 acc 0.3909 bal_acc 0.3290 f1 0.3102 | val loss 2.1863 acc 0.1398 bal_acc 0.1924 f1 0.0809 | attn(cnn=0.471, lstm=0.498, inter=0.670) | lr 5.00e-05
# Fold 7 | Epoch 010 | train loss 1.5803 acc 0.4121 bal_acc 0.3498 f1 0.3285 | val loss 2.1833 acc 0.1505 bal_acc 0.2046 f1 0.0899 | attn(cnn=0.472, lstm=0.500, inter=0.737) | lr 5.00e-05
# Fold 7 | Epoch 011 | train loss 1.5592 acc 0.4035 bal_acc 0.3467 f1 0.3365 | val loss 2.3181 acc 0.1355 bal_acc 0.1844 f1 0.0785 | attn(cnn=0.468, lstm=0.501, inter=0.756) | lr 5.00e-05
# Fold 7 | Epoch 012 | train loss 1.5493 acc 0.4176 bal_acc 0.3557 f1 0.3446 | val loss 2.4270 acc 0.1161 bal_acc 0.1540 f1 0.0469 | attn(cnn=0.466, lstm=0.501, inter=0.759) | lr 2.50e-05
# Fold 7 | Epoch 013 | train loss 1.5289 acc 0.4394 bal_acc 0.3685 f1 0.3615 | val loss 2.4481 acc 0.1226 bal_acc 0.1634 f1 0.0540 | attn(cnn=0.465, lstm=0.502, inter=0.773) | lr 2.50e-05
# Fold 7 | Epoch 014 | train loss 1.5268 acc 0.4336 bal_acc 0.3714 f1 0.3594 | val loss 2.4950 acc 0.1183 bal_acc 0.1569 f1 0.0471 | attn(cnn=0.464, lstm=0.502, inter=0.780) | lr 2.50e-05
# Fold 7 | Epoch 015 | train loss 1.5209 acc 0.4260 bal_acc 0.3597 f1 0.3476 | val loss 2.4917 acc 0.1204 bal_acc 0.1619 f1 0.0455 | attn(cnn=0.464, lstm=0.502, inter=0.787) | lr 2.50e-05
# Fold 7 | Epoch 016 | train loss 1.5110 acc 0.4468 bal_acc 0.3772 f1 0.3691 | val loss 2.5116 acc 0.1247 bal_acc 0.1657 f1 0.0476 | attn(cnn=0.463, lstm=0.503, inter=0.794) | lr 2.50e-05
# Fold 7 | Epoch 017 | train loss 1.5052 acc 0.4396 bal_acc 0.3728 f1 0.3642 | val loss 2.5439 acc 0.1269 bal_acc 0.1686 f1 0.0471 | attn(cnn=0.461, lstm=0.503, inter=0.800) | lr 2.50e-05
# Fold 7 | Epoch 018 | train loss 1.5001 acc 0.4515 bal_acc 0.3834 f1 0.3723 | val loss 2.5193 acc 0.1290 bal_acc 0.1715 f1 0.0473 | attn(cnn=0.462, lstm=0.503, inter=0.807) | lr 2.50e-05
# Fold 7 | Epoch 019 | train loss 1.4926 acc 0.4556 bal_acc 0.3853 f1 0.3761 | val loss 2.5554 acc 0.1269 bal_acc 0.1686 f1 0.0480 | attn(cnn=0.461, lstm=0.504, inter=0.812) | lr 1.25e-05
# Fold 7 | Epoch 020 | train loss 1.4779 acc 0.4585 bal_acc 0.3994 f1 0.3852 | val loss 2.5831 acc 0.1247 bal_acc 0.1657 f1 0.0475 | attn(cnn=0.460, lstm=0.504, inter=0.817) | lr 1.25e-05
# Early stopping triggered.
#
# ========== Fold 8/10 ==========
# /home/rithik-tank/enter/envs/tf_gpu/lib/python3.10/site-packages/torch/nn/modules/rnn.py:1013: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   super().__init__("LSTM", *args, **kwargs)
# Fold 8 | Epoch 001 | train loss 1.8169 acc 0.1311 bal_acc 0.1669 f1 0.1044 | val loss 1.8528 acc 0.1355 bal_acc 0.1914 f1 0.0793 | attn(cnn=0.502, lstm=0.500, inter=0.500) | lr 5.00e-05
# Fold 8 | Epoch 002 | train loss 1.8148 acc 0.1970 bal_acc 0.1913 f1 0.1636 | val loss 1.8516 acc 0.1656 bal_acc 0.2202 f1 0.1002 | attn(cnn=0.502, lstm=0.499, inter=0.501) | lr 5.00e-05
# Fold 8 | Epoch 003 | train loss 1.8097 acc 0.2390 bal_acc 0.2149 f1 0.1954 | val loss 1.8438 acc 0.2043 bal_acc 0.2258 f1 0.1266 | attn(cnn=0.501, lstm=0.499, inter=0.503) | lr 5.00e-05
# Fold 8 | Epoch 004 | train loss 1.8037 acc 0.3085 bal_acc 0.2233 f1 0.2202 | val loss 1.8339 acc 0.2108 bal_acc 0.2405 f1 0.1292 | attn(cnn=0.498, lstm=0.499, inter=0.508) | lr 5.00e-05
# Fold 8 | Epoch 005 | train loss 1.7864 acc 0.3293 bal_acc 0.2444 f1 0.2330 | val loss 1.8280 acc 0.2237 bal_acc 0.2710 f1 0.1611 | attn(cnn=0.491, lstm=0.499, inter=0.525) | lr 5.00e-05
# Fold 8 | Epoch 006 | train loss 1.7648 acc 0.3742 bal_acc 0.2766 f1 0.2541 | val loss 1.8591 acc 0.1613 bal_acc 0.2009 f1 0.0965 | attn(cnn=0.484, lstm=0.499, inter=0.559) | lr 5.00e-05
# Fold 8 | Epoch 007 | train loss 1.7155 acc 0.3997 bal_acc 0.3040 f1 0.2712 | val loss 1.8895 acc 0.1484 bal_acc 0.1812 f1 0.0740 | attn(cnn=0.474, lstm=0.499, inter=0.631) | lr 5.00e-05
# Fold 8 | Epoch 008 | train loss 1.6516 acc 0.4298 bal_acc 0.3448 f1 0.3174 | val loss 1.9625 acc 0.1376 bal_acc 0.1769 f1 0.0568 | attn(cnn=0.465, lstm=0.498, inter=0.739) | lr 5.00e-05
# Fold 8 | Epoch 009 | train loss 1.6277 acc 0.4200 bal_acc 0.3438 f1 0.3082 | val loss 1.9918 acc 0.1376 bal_acc 0.1745 f1 0.0586 | attn(cnn=0.464, lstm=0.498, inter=0.799) | lr 5.00e-05
# Fold 8 | Epoch 010 | train loss 1.5943 acc 0.4391 bal_acc 0.3611 f1 0.3407 | val loss 2.0688 acc 0.1355 bal_acc 0.1737 f1 0.0573 | attn(cnn=0.457, lstm=0.498, inter=0.824) | lr 5.00e-05
# Fold 8 | Epoch 011 | train loss 1.5770 acc 0.4391 bal_acc 0.3624 f1 0.3403 | val loss 2.1014 acc 0.1398 bal_acc 0.1802 f1 0.0662 | attn(cnn=0.459, lstm=0.497, inter=0.844) | lr 5.00e-05
# Fold 8 | Epoch 012 | train loss 1.5563 acc 0.4503 bal_acc 0.3620 f1 0.3427 | val loss 2.2034 acc 0.1312 bal_acc 0.1768 f1 0.0605 | attn(cnn=0.452, lstm=0.497, inter=0.862) | lr 2.50e-05
# Fold 8 | Epoch 013 | train loss 1.5439 acc 0.4458 bal_acc 0.3723 f1 0.3477 | val loss 2.2124 acc 0.1333 bal_acc 0.1825 f1 0.0674 | attn(cnn=0.451, lstm=0.497, inter=0.868) | lr 2.50e-05
# Fold 8 | Epoch 014 | train loss 1.5343 acc 0.4585 bal_acc 0.3854 f1 0.3647 | val loss 2.2288 acc 0.1376 bal_acc 0.1884 f1 0.0770 | attn(cnn=0.450, lstm=0.497, inter=0.875) | lr 2.50e-05
# Fold 8 | Epoch 015 | train loss 1.5199 acc 0.4573 bal_acc 0.3794 f1 0.3602 | val loss 2.3601 acc 0.1312 bal_acc 0.1834 f1 0.0695 | attn(cnn=0.446, lstm=0.497, inter=0.877) | lr 2.50e-05
# Fold 8 | Epoch 016 | train loss 1.5220 acc 0.4628 bal_acc 0.3893 f1 0.3680 | val loss 2.3600 acc 0.1419 bal_acc 0.1995 f1 0.0847 | attn(cnn=0.444, lstm=0.497, inter=0.882) | lr 2.50e-05
# Fold 8 | Epoch 017 | train loss 1.5093 acc 0.4594 bal_acc 0.3814 f1 0.3664 | val loss 2.2811 acc 0.1591 bal_acc 0.2186 f1 0.1098 | attn(cnn=0.450, lstm=0.497, inter=0.890) | lr 2.50e-05
# Fold 8 | Epoch 018 | train loss 1.4900 acc 0.4692 bal_acc 0.3956 f1 0.3726 | val loss 2.4119 acc 0.1613 bal_acc 0.2280 f1 0.1124 | attn(cnn=0.444, lstm=0.497, inter=0.894) | lr 2.50e-05
# Fold 8 | Epoch 019 | train loss 1.4948 acc 0.4737 bal_acc 0.4018 f1 0.3867 | val loss 2.3713 acc 0.1742 bal_acc 0.2431 f1 0.1218 | attn(cnn=0.447, lstm=0.497, inter=0.897) | lr 1.25e-05
# Fold 8 | Epoch 020 | train loss 1.4917 acc 0.4716 bal_acc 0.3928 f1 0.3752 | val loss 2.4326 acc 0.1742 bal_acc 0.2428 f1 0.1220 | attn(cnn=0.443, lstm=0.497, inter=0.897) | lr 1.25e-05
# Early stopping triggered.
#
# ========== Fold 9/10 ==========
# /home/rithik-tank/enter/envs/tf_gpu/lib/python3.10/site-packages/torch/nn/modules/rnn.py:1013: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   super().__init__("LSTM", *args, **kwargs)
# Fold 9 | Epoch 001 | train loss 1.8175 acc 0.1151 bal_acc 0.1655 f1 0.0806 | val loss 1.8510 acc 0.1097 bal_acc 0.1667 f1 0.0329 | attn(cnn=0.500, lstm=0.500, inter=0.499) | lr 5.00e-05
# Fold 9 | Epoch 002 | train loss 1.8155 acc 0.1184 bal_acc 0.1664 f1 0.0913 | val loss 1.8497 acc 0.1075 bal_acc 0.1634 f1 0.0324 | attn(cnn=0.499, lstm=0.500, inter=0.500) | lr 5.00e-05
# Fold 9 | Epoch 003 | train loss 1.8131 acc 0.1509 bal_acc 0.1925 f1 0.1352 | val loss 1.8469 acc 0.1247 bal_acc 0.1754 f1 0.0660 | attn(cnn=0.499, lstm=0.500, inter=0.501) | lr 5.00e-05
# Fold 9 | Epoch 004 | train loss 1.8109 acc 0.2034 bal_acc 0.2042 f1 0.1735 | val loss 1.8443 acc 0.1462 bal_acc 0.1966 f1 0.0814 | attn(cnn=0.499, lstm=0.500, inter=0.502) | lr 5.00e-05
# Fold 9 | Epoch 005 | train loss 1.8051 acc 0.2445 bal_acc 0.2410 f1 0.2192 | val loss 1.8409 acc 0.1591 bal_acc 0.2052 f1 0.1178 | attn(cnn=0.499, lstm=0.500, inter=0.506) | lr 5.00e-05
# Fold 9 | Epoch 006 | train loss 1.7908 acc 0.3030 bal_acc 0.2796 f1 0.2564 | val loss 1.8232 acc 0.2409 bal_acc 0.3042 f1 0.2409 | attn(cnn=0.499, lstm=0.500, inter=0.525) | lr 5.00e-05
# Fold 9 | Epoch 007 | train loss 1.7439 acc 0.3601 bal_acc 0.2877 f1 0.2626 | val loss 1.8127 acc 0.2215 bal_acc 0.2838 f1 0.1969 | attn(cnn=0.498, lstm=0.499, inter=0.592) | lr 5.00e-05
# Fold 9 | Epoch 008 | train loss 1.6590 acc 0.4031 bal_acc 0.3162 f1 0.2996 | val loss 1.8170 acc 0.2065 bal_acc 0.2636 f1 0.1698 | attn(cnn=0.492, lstm=0.499, inter=0.670) | lr 5.00e-05
# Fold 9 | Epoch 009 | train loss 1.6187 acc 0.4083 bal_acc 0.3254 f1 0.3084 | val loss 1.8748 acc 0.1785 bal_acc 0.2290 f1 0.1222 | attn(cnn=0.487, lstm=0.499, inter=0.696) | lr 5.00e-05
# Fold 9 | Epoch 010 | train loss 1.5935 acc 0.4019 bal_acc 0.3328 f1 0.3170 | val loss 1.8406 acc 0.1978 bal_acc 0.2522 f1 0.1581 | attn(cnn=0.488, lstm=0.498, inter=0.728) | lr 5.00e-05
# Fold 9 | Epoch 011 | train loss 1.5872 acc 0.4181 bal_acc 0.3442 f1 0.3311 | val loss 1.8529 acc 0.2086 bal_acc 0.2709 f1 0.1724 | attn(cnn=0.486, lstm=0.497, inter=0.768) | lr 5.00e-05
# Fold 9 | Epoch 012 | train loss 1.5601 acc 0.4341 bal_acc 0.3610 f1 0.3441 | val loss 1.9331 acc 0.1978 bal_acc 0.2624 f1 0.1686 | attn(cnn=0.481, lstm=0.494, inter=0.794) | lr 5.00e-05
# Fold 9 | Epoch 013 | train loss 1.5669 acc 0.4119 bal_acc 0.3476 f1 0.3326 | val loss 1.6818 acc 0.3376 bal_acc 0.3627 f1 0.3009 | attn(cnn=0.491, lstm=0.490, inter=0.814) | lr 5.00e-05
# Fold 9 | Epoch 014 | train loss 1.5416 acc 0.4351 bal_acc 0.3641 f1 0.3449 | val loss 1.7996 acc 0.2559 bal_acc 0.3234 f1 0.2439 | attn(cnn=0.482, lstm=0.485, inter=0.843) | lr 5.00e-05
# Fold 9 | Epoch 015 | train loss 1.5282 acc 0.4432 bal_acc 0.3684 f1 0.3587 | val loss 1.8232 acc 0.2495 bal_acc 0.3172 f1 0.2389 | attn(cnn=0.478, lstm=0.482, inter=0.862) | lr 5.00e-05
# Fold 9 | Epoch 016 | train loss 1.5054 acc 0.4568 bal_acc 0.3843 f1 0.3740 | val loss 1.7742 acc 0.2667 bal_acc 0.3402 f1 0.2710 | attn(cnn=0.477, lstm=0.479, inter=0.881) | lr 5.00e-05
# Fold 9 | Epoch 017 | train loss 1.5023 acc 0.4546 bal_acc 0.3799 f1 0.3704 | val loss 1.7697 acc 0.2753 bal_acc 0.3442 f1 0.2888 | attn(cnn=0.474, lstm=0.477, inter=0.889) | lr 5.00e-05
# Fold 9 | Epoch 018 | train loss 1.4807 acc 0.4570 bal_acc 0.3941 f1 0.3782 | val loss 1.7441 acc 0.2645 bal_acc 0.3388 f1 0.2851 | attn(cnn=0.471, lstm=0.474, inter=0.901) | lr 5.00e-05
# Fold 9 | Epoch 019 | train loss 1.4789 acc 0.4628 bal_acc 0.3952 f1 0.3859 | val loss 1.7419 acc 0.2645 bal_acc 0.3308 f1 0.2853 | attn(cnn=0.469, lstm=0.471, inter=0.906) | lr 5.00e-05
# Fold 9 | Epoch 020 | train loss 1.4670 acc 0.4797 bal_acc 0.4203 f1 0.4055 | val loss 1.7272 acc 0.2731 bal_acc 0.3399 f1 0.2994 | attn(cnn=0.466, lstm=0.470, inter=0.914) | lr 2.50e-05
# Fold 9 | Epoch 021 | train loss 1.4565 acc 0.4816 bal_acc 0.4256 f1 0.4108 | val loss 1.6518 acc 0.3075 bal_acc 0.3815 f1 0.3202 | attn(cnn=0.468, lstm=0.469, inter=0.917) | lr 2.50e-05
# Fold 9 | Epoch 022 | train loss 1.4480 acc 0.4704 bal_acc 0.4147 f1 0.3985 | val loss 1.6294 acc 0.3376 bal_acc 0.4059 f1 0.3360 | attn(cnn=0.467, lstm=0.468, inter=0.921) | lr 2.50e-05
# Fold 9 | Epoch 023 | train loss 1.4416 acc 0.4904 bal_acc 0.4303 f1 0.4175 | val loss 1.6491 acc 0.3140 bal_acc 0.3846 f1 0.3347 | attn(cnn=0.464, lstm=0.467, inter=0.923) | lr 2.50e-05
# Fold 9 | Epoch 024 | train loss 1.4225 acc 0.4897 bal_acc 0.4256 f1 0.4109 | val loss 1.5900 acc 0.3290 bal_acc 0.3960 f1 0.3279 | attn(cnn=0.466, lstm=0.466, inter=0.928) | lr 2.50e-05
# Fold 9 | Epoch 025 | train loss 1.4255 acc 0.4924 bal_acc 0.4362 f1 0.4188 | val loss 1.6393 acc 0.3226 bal_acc 0.4010 f1 0.3189 | attn(cnn=0.462, lstm=0.466, inter=0.931) | lr 2.50e-05
# Fold 9 | Epoch 026 | train loss 1.4150 acc 0.4995 bal_acc 0.4393 f1 0.4242 | val loss 1.5284 acc 0.3892 bal_acc 0.4217 f1 0.3571 | attn(cnn=0.468, lstm=0.465, inter=0.932) | lr 2.50e-05
# Fold 9 | Epoch 027 | train loss 1.4119 acc 0.4969 bal_acc 0.4486 f1 0.4302 | val loss 1.5168 acc 0.4129 bal_acc 0.4548 f1 0.3944 | attn(cnn=0.468, lstm=0.464, inter=0.934) | lr 2.50e-05
# Fold 9 | Epoch 028 | train loss 1.4008 acc 0.5038 bal_acc 0.4511 f1 0.4335 | val loss 1.5159 acc 0.3978 bal_acc 0.4403 f1 0.3742 | attn(cnn=0.465, lstm=0.464, inter=0.936) | lr 2.50e-05
# Fold 9 | Epoch 029 | train loss 1.4032 acc 0.4983 bal_acc 0.4413 f1 0.4242 | val loss 1.5533 acc 0.3656 bal_acc 0.4214 f1 0.3452 | attn(cnn=0.463, lstm=0.463, inter=0.938) | lr 2.50e-05
# Fold 9 | Epoch 030 | train loss 1.3978 acc 0.5057 bal_acc 0.4617 f1 0.4409 | val loss 1.5997 acc 0.3462 bal_acc 0.4137 f1 0.3291 | attn(cnn=0.460, lstm=0.463, inter=0.940) | lr 2.50e-05
# Fold 9 | Epoch 031 | train loss 1.3958 acc 0.5017 bal_acc 0.4508 f1 0.4336 | val loss 1.5001 acc 0.4065 bal_acc 0.4402 f1 0.3755 | attn(cnn=0.463, lstm=0.462, inter=0.941) | lr 2.50e-05
# Fold 9 | Epoch 032 | train loss 1.3812 acc 0.5033 bal_acc 0.4571 f1 0.4383 | val loss 1.5894 acc 0.3505 bal_acc 0.4164 f1 0.3313 | attn(cnn=0.458, lstm=0.462, inter=0.943) | lr 2.50e-05
# Fold 9 | Epoch 033 | train loss 1.3845 acc 0.5170 bal_acc 0.4679 f1 0.4481 | val loss 1.4891 acc 0.4000 bal_acc 0.4288 f1 0.3610 | attn(cnn=0.464, lstm=0.462, inter=0.944) | lr 2.50e-05
# Fold 9 | Epoch 034 | train loss 1.3824 acc 0.5029 bal_acc 0.4547 f1 0.4348 | val loss 1.4969 acc 0.3914 bal_acc 0.4388 f1 0.3547 | attn(cnn=0.461, lstm=0.462, inter=0.947) | lr 2.50e-05
# Fold 9 | Epoch 035 | train loss 1.3590 acc 0.5205 bal_acc 0.4720 f1 0.4557 | val loss 1.4334 acc 0.4280 bal_acc 0.4396 f1 0.3804 | attn(cnn=0.464, lstm=0.461, inter=0.948) | lr 2.50e-05
# Fold 9 | Epoch 036 | train loss 1.3590 acc 0.5196 bal_acc 0.4783 f1 0.4540 | val loss 1.4452 acc 0.4129 bal_acc 0.4321 f1 0.3688 | attn(cnn=0.461, lstm=0.460, inter=0.950) | lr 2.50e-05
# Fold 9 | Epoch 037 | train loss 1.3331 acc 0.5308 bal_acc 0.4962 f1 0.4715 | val loss 1.4387 acc 0.4108 bal_acc 0.4486 f1 0.3868 | attn(cnn=0.462, lstm=0.460, inter=0.950) | lr 2.50e-05
# Fold 9 | Epoch 038 | train loss 1.3493 acc 0.5234 bal_acc 0.4823 f1 0.4607 | val loss 1.4122 acc 0.4452 bal_acc 0.4502 f1 0.3912 | attn(cnn=0.463, lstm=0.460, inter=0.950) | lr 2.50e-05
# Fold 9 | Epoch 039 | train loss 1.3521 acc 0.5260 bal_acc 0.4876 f1 0.4649 | val loss 1.4188 acc 0.4452 bal_acc 0.4457 f1 0.3883 | attn(cnn=0.465, lstm=0.459, inter=0.952) | lr 2.50e-05
# Fold 9 | Epoch 040 | train loss 1.3366 acc 0.5301 bal_acc 0.4868 f1 0.4645 | val loss 1.4288 acc 0.4022 bal_acc 0.4402 f1 0.3694 | attn(cnn=0.460, lstm=0.459, inter=0.953) | lr 2.50e-05
# Fold 9 | Epoch 041 | train loss 1.3231 acc 0.5282 bal_acc 0.4885 f1 0.4679 | val loss 1.4061 acc 0.4387 bal_acc 0.4548 f1 0.3978 | attn(cnn=0.463, lstm=0.459, inter=0.953) | lr 2.50e-05
# Fold 9 | Epoch 042 | train loss 1.3097 acc 0.5423 bal_acc 0.5070 f1 0.4809 | val loss 1.3997 acc 0.4430 bal_acc 0.4673 f1 0.4075 | attn(cnn=0.461, lstm=0.459, inter=0.954) | lr 2.50e-05
# Fold 9 | Epoch 043 | train loss 1.3194 acc 0.5389 bal_acc 0.4968 f1 0.4704 | val loss 1.3961 acc 0.4516 bal_acc 0.4715 f1 0.4038 | attn(cnn=0.461, lstm=0.458, inter=0.954) | lr 2.50e-05
# Fold 9 | Epoch 044 | train loss 1.3095 acc 0.5392 bal_acc 0.5047 f1 0.4798 | val loss 1.4052 acc 0.4215 bal_acc 0.4404 f1 0.3841 | attn(cnn=0.465, lstm=0.458, inter=0.954) | lr 2.50e-05
# Fold 9 | Epoch 045 | train loss 1.2966 acc 0.5451 bal_acc 0.5074 f1 0.4830 | val loss 1.3969 acc 0.4151 bal_acc 0.4541 f1 0.3893 | attn(cnn=0.461, lstm=0.458, inter=0.955) | lr 2.50e-05
# Fold 9 | Epoch 046 | train loss 1.2978 acc 0.5451 bal_acc 0.5194 f1 0.4901 | val loss 1.3733 acc 0.4667 bal_acc 0.4738 f1 0.4205 | attn(cnn=0.461, lstm=0.458, inter=0.955) | lr 2.50e-05
# Fold 9 | Epoch 047 | train loss 1.2880 acc 0.5528 bal_acc 0.5221 f1 0.4927 | val loss 1.3960 acc 0.4108 bal_acc 0.4396 f1 0.3687 | attn(cnn=0.464, lstm=0.458, inter=0.956) | lr 2.50e-05
# Fold 9 | Epoch 048 | train loss 1.2686 acc 0.5559 bal_acc 0.5274 f1 0.4967 | val loss 1.3738 acc 0.4559 bal_acc 0.4725 f1 0.4013 | attn(cnn=0.462, lstm=0.459, inter=0.957) | lr 2.50e-05
# Fold 9 | Epoch 049 | train loss 1.2670 acc 0.5590 bal_acc 0.5334 f1 0.5038 | val loss 1.4003 acc 0.4086 bal_acc 0.4367 f1 0.3677 | attn(cnn=0.464, lstm=0.459, inter=0.956) | lr 2.50e-05
# Fold 9 | Epoch 050 | train loss 1.2721 acc 0.5509 bal_acc 0.5201 f1 0.4901 | val loss 1.3734 acc 0.4430 bal_acc 0.4556 f1 0.3879 | attn(cnn=0.465, lstm=0.459, inter=0.957) | lr 2.50e-05
# Fold 9 | Epoch 051 | train loss 1.2611 acc 0.5604 bal_acc 0.5322 f1 0.5040 | val loss 1.3732 acc 0.4387 bal_acc 0.4797 f1 0.3784 | attn(cnn=0.462, lstm=0.459, inter=0.957) | lr 2.50e-05
# Fold 9 | Epoch 052 | train loss 1.2431 acc 0.5819 bal_acc 0.5571 f1 0.5297 | val loss 1.3516 acc 0.4559 bal_acc 0.4734 f1 0.3849 | attn(cnn=0.462, lstm=0.458, inter=0.958) | lr 2.50e-05
# Fold 9 | Epoch 053 | train loss 1.2386 acc 0.5807 bal_acc 0.5532 f1 0.5219 | val loss 1.3602 acc 0.4387 bal_acc 0.4632 f1 0.3610 | attn(cnn=0.461, lstm=0.459, inter=0.960) | lr 2.50e-05
# Fold 9 | Epoch 054 | train loss 1.2353 acc 0.5843 bal_acc 0.5573 f1 0.5270 | val loss 1.3535 acc 0.4624 bal_acc 0.4606 f1 0.3795 | attn(cnn=0.464, lstm=0.459, inter=0.958) | lr 2.50e-05
# Fold 9 | Epoch 055 | train loss 1.2424 acc 0.5649 bal_acc 0.5391 f1 0.5079 | val loss 1.3629 acc 0.4495 bal_acc 0.4607 f1 0.3682 | attn(cnn=0.464, lstm=0.459, inter=0.959) | lr 2.50e-05
# Fold 9 | Epoch 056 | train loss 1.2254 acc 0.5762 bal_acc 0.5481 f1 0.5172 | val loss 1.3900 acc 0.4043 bal_acc 0.4391 f1 0.3593 | attn(cnn=0.465, lstm=0.459, inter=0.957) | lr 2.50e-05
# Fold 9 | Epoch 057 | train loss 1.2225 acc 0.5790 bal_acc 0.5631 f1 0.5290 | val loss 1.3506 acc 0.4538 bal_acc 0.4767 f1 0.3738 | attn(cnn=0.463, lstm=0.459, inter=0.960) | lr 2.50e-05
# Fold 9 | Epoch 058 | train loss 1.2136 acc 0.5864 bal_acc 0.5642 f1 0.5323 | val loss 1.3802 acc 0.3957 bal_acc 0.4405 f1 0.3092 | attn(cnn=0.464, lstm=0.459, inter=0.960) | lr 2.50e-05
# Fold 9 | Epoch 059 | train loss 1.2201 acc 0.5817 bal_acc 0.5643 f1 0.5299 | val loss 1.3786 acc 0.4387 bal_acc 0.4569 f1 0.3355 | attn(cnn=0.469, lstm=0.459, inter=0.958) | lr 2.50e-05
# Fold 9 | Epoch 060 | train loss 1.1931 acc 0.6060 bal_acc 0.5863 f1 0.5549 | val loss 1.3674 acc 0.4237 bal_acc 0.4548 f1 0.3244 | attn(cnn=0.464, lstm=0.458, inter=0.960) | lr 2.50e-05
# Fold 9 | Epoch 061 | train loss 1.1978 acc 0.6010 bal_acc 0.5787 f1 0.5482 | val loss 1.4008 acc 0.3892 bal_acc 0.4473 f1 0.3001 | attn(cnn=0.463, lstm=0.458, inter=0.961) | lr 2.50e-05
# Fold 9 | Epoch 062 | train loss 1.1885 acc 0.5981 bal_acc 0.5718 f1 0.5396 | val loss 1.3881 acc 0.4323 bal_acc 0.4568 f1 0.3286 | attn(cnn=0.469, lstm=0.459, inter=0.960) | lr 2.50e-05
# Fold 9 | Epoch 063 | train loss 1.1801 acc 0.5903 bal_acc 0.5831 f1 0.5475 | val loss 1.3895 acc 0.4237 bal_acc 0.4621 f1 0.3214 | attn(cnn=0.463, lstm=0.459, inter=0.962) | lr 2.50e-05
# Fold 9 | Epoch 064 | train loss 1.1834 acc 0.5955 bal_acc 0.5707 f1 0.5400 | val loss 1.4154 acc 0.4086 bal_acc 0.4521 f1 0.3089 | attn(cnn=0.466, lstm=0.459, inter=0.962) | lr 1.25e-05
# Fold 9 | Epoch 065 | train loss 1.1636 acc 0.6113 bal_acc 0.5854 f1 0.5552 | val loss 1.4176 acc 0.4172 bal_acc 0.4594 f1 0.3199 | attn(cnn=0.467, lstm=0.459, inter=0.960) | lr 1.25e-05
# Fold 9 | Epoch 066 | train loss 1.1803 acc 0.5900 bal_acc 0.5771 f1 0.5442 | val loss 1.3856 acc 0.4452 bal_acc 0.4660 f1 0.3408 | attn(cnn=0.468, lstm=0.459, inter=0.960) | lr 1.25e-05
# Fold 9 | Epoch 067 | train loss 1.1624 acc 0.6079 bal_acc 0.5931 f1 0.5582 | val loss 1.4123 acc 0.4258 bal_acc 0.4632 f1 0.3228 | attn(cnn=0.469, lstm=0.459, inter=0.960) | lr 1.25e-05
# Fold 9 | Epoch 068 | train loss 1.1672 acc 0.5986 bal_acc 0.5861 f1 0.5495 | val loss 1.4021 acc 0.4258 bal_acc 0.4632 f1 0.3223 | attn(cnn=0.468, lstm=0.459, inter=0.961) | lr 1.25e-05
# Fold 9 | Epoch 069 | train loss 1.1572 acc 0.6139 bal_acc 0.5956 f1 0.5629 | val loss 1.4094 acc 0.4172 bal_acc 0.4580 f1 0.3145 | attn(cnn=0.466, lstm=0.459, inter=0.961) | lr 1.25e-05
# Fold 9 | Epoch 070 | train loss 1.1473 acc 0.6158 bal_acc 0.5986 f1 0.5657 | val loss 1.4314 acc 0.4280 bal_acc 0.4657 f1 0.3239 | attn(cnn=0.469, lstm=0.459, inter=0.961) | lr 1.25e-05
# Fold 9 | Epoch 071 | train loss 1.1493 acc 0.6144 bal_acc 0.6022 f1 0.5654 | val loss 1.4348 acc 0.4237 bal_acc 0.4689 f1 0.3203 | attn(cnn=0.468, lstm=0.459, inter=0.961) | lr 6.25e-06
# Fold 9 | Epoch 072 | train loss 1.1336 acc 0.6242 bal_acc 0.6030 f1 0.5735 | val loss 1.4373 acc 0.4086 bal_acc 0.4545 f1 0.3083 | attn(cnn=0.467, lstm=0.459, inter=0.962) | lr 6.25e-06
# Early stopping triggered.
#
# ========== Fold 10/10 ==========
# /home/rithik-tank/enter/envs/tf_gpu/lib/python3.10/site-packages/torch/nn/modules/rnn.py:1013: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   super().__init__("LSTM", *args, **kwargs)
# Fold 10 | Epoch 001 | train loss 1.8178 acc 0.1263 bal_acc 0.1541 f1 0.0723 | val loss 1.8464 acc 0.1226 bal_acc 0.1667 f1 0.0364 | attn(cnn=0.500, lstm=0.500, inter=0.502) | lr 5.00e-05
# Fold 10 | Epoch 002 | train loss 1.8160 acc 0.1538 bal_acc 0.1703 f1 0.1035 | val loss 1.8471 acc 0.1226 bal_acc 0.1667 f1 0.0370 | attn(cnn=0.500, lstm=0.500, inter=0.502) | lr 5.00e-05
# Fold 10 | Epoch 003 | train loss 1.8125 acc 0.1841 bal_acc 0.1953 f1 0.1496 | val loss 1.8467 acc 0.1226 bal_acc 0.1667 f1 0.0368 | attn(cnn=0.500, lstm=0.500, inter=0.504) | lr 5.00e-05
# Fold 10 | Epoch 004 | train loss 1.8077 acc 0.2335 bal_acc 0.2181 f1 0.2019 | val loss 1.8451 acc 0.1269 bal_acc 0.1707 f1 0.0443 | attn(cnn=0.500, lstm=0.500, inter=0.506) | lr 5.00e-05
# Fold 10 | Epoch 005 | train loss 1.7956 acc 0.2963 bal_acc 0.2586 f1 0.2478 | val loss 1.8475 acc 0.1398 bal_acc 0.1928 f1 0.0778 | attn(cnn=0.499, lstm=0.500, inter=0.516) | lr 5.00e-05
# Fold 10 | Epoch 006 | train loss 1.7561 acc 0.3477 bal_acc 0.3054 f1 0.2764 | val loss 1.8609 acc 0.1376 bal_acc 0.1985 f1 0.0772 | attn(cnn=0.494, lstm=0.500, inter=0.558) | lr 5.00e-05
# Fold 10 | Epoch 007 | train loss 1.6646 acc 0.3761 bal_acc 0.3147 f1 0.2857 | val loss 1.9280 acc 0.1269 bal_acc 0.1841 f1 0.0616 | attn(cnn=0.481, lstm=0.499, inter=0.628) | lr 5.00e-05
# Fold 10 | Epoch 008 | train loss 1.6176 acc 0.3866 bal_acc 0.3280 f1 0.3001 | val loss 2.0433 acc 0.1204 bal_acc 0.1754 f1 0.0494 | attn(cnn=0.470, lstm=0.499, inter=0.658) | lr 5.00e-05
# Fold 10 | Epoch 009 | train loss 1.5881 acc 0.3954 bal_acc 0.3401 f1 0.3197 | val loss 2.1197 acc 0.1247 bal_acc 0.1813 f1 0.0547 | attn(cnn=0.466, lstm=0.499, inter=0.680) | lr 5.00e-05
# Fold 10 | Epoch 010 | train loss 1.5726 acc 0.4157 bal_acc 0.3504 f1 0.3354 | val loss 2.1710 acc 0.1247 bal_acc 0.1813 f1 0.0546 | attn(cnn=0.463, lstm=0.499, inter=0.706) | lr 5.00e-05
# Fold 10 | Epoch 011 | train loss 1.5518 acc 0.4210 bal_acc 0.3586 f1 0.3389 | val loss 2.2772 acc 0.1290 bal_acc 0.1871 f1 0.0578 | attn(cnn=0.457, lstm=0.498, inter=0.724) | lr 2.50e-05
# Fold 10 | Epoch 012 | train loss 1.5377 acc 0.4327 bal_acc 0.3590 f1 0.3422 | val loss 2.3466 acc 0.1333 bal_acc 0.1928 f1 0.0631 | attn(cnn=0.455, lstm=0.497, inter=0.746) | lr 2.50e-05
# Fold 10 | Epoch 013 | train loss 1.5251 acc 0.4327 bal_acc 0.3736 f1 0.3588 | val loss 2.3600 acc 0.1333 bal_acc 0.1928 f1 0.0630 | attn(cnn=0.456, lstm=0.496, inter=0.774) | lr 2.50e-05
# Fold 10 | Epoch 014 | train loss 1.5242 acc 0.4386 bal_acc 0.3746 f1 0.3601 | val loss 2.4079 acc 0.1290 bal_acc 0.1860 f1 0.0631 | attn(cnn=0.454, lstm=0.495, inter=0.787) | lr 2.50e-05
# Fold 10 | Epoch 015 | train loss 1.5115 acc 0.4451 bal_acc 0.3837 f1 0.3662 | val loss 2.5137 acc 0.1333 bal_acc 0.1923 f1 0.0651 | attn(cnn=0.451, lstm=0.493, inter=0.793) | lr 2.50e-05
# Fold 10 | Epoch 016 | train loss 1.5034 acc 0.4508 bal_acc 0.3824 f1 0.3682 | val loss 2.5130 acc 0.1247 bal_acc 0.1793 f1 0.0631 | attn(cnn=0.452, lstm=0.492, inter=0.807) | lr 2.50e-05
# Fold 10 | Epoch 017 | train loss 1.4988 acc 0.4513 bal_acc 0.3880 f1 0.3681 | val loss 2.5506 acc 0.1247 bal_acc 0.1791 f1 0.0636 | attn(cnn=0.450, lstm=0.491, inter=0.811) | lr 2.50e-05
# Fold 10 | Epoch 018 | train loss 1.4975 acc 0.4494 bal_acc 0.3900 f1 0.3714 | val loss 2.5793 acc 0.1204 bal_acc 0.1726 f1 0.0622 | attn(cnn=0.450, lstm=0.489, inter=0.816) | lr 1.25e-05
# Fold 10 | Epoch 019 | train loss 1.4880 acc 0.4613 bal_acc 0.3925 f1 0.3793 | val loss 2.5493 acc 0.1226 bal_acc 0.1757 f1 0.0635 | attn(cnn=0.452, lstm=0.488, inter=0.824) | lr 1.25e-05
# Early stopping triggered.
#
# ========== CV Summary ==========
# Fold 1: best val loss=1.8261 | best val acc=0.2082 | best val f1=0.1608
# Fold 2: best val loss=1.8329 | best val acc=0.1910 | best val f1=0.1317
# Fold 3: best val loss=1.8290 | best val acc=0.3133 | best val f1=0.2735
# Fold 4: best val loss=1.6745 | best val acc=0.3957 | best val f1=0.2628
# Fold 5: best val loss=1.6811 | best val acc=0.4086 | best val f1=0.3491
# Fold 6: best val loss=1.8348 | best val acc=0.2086 | best val f1=0.1252
# Fold 7: best val loss=1.8446 | best val acc=0.1677 | best val f1=0.1180
# Fold 8: best val loss=1.8280 | best val acc=0.2237 | best val f1=0.1611
# Fold 9: best val loss=1.3506 | best val acc=0.4667 | best val f1=0.4205
# Fold 10: best val loss=1.8451 | best val acc=0.1398 | best val f1=0.0778
# Mean(best val acc) across folds: 0.2723
# Mean(best val f1 ) across folds: 0.2081
# Saved best-fold checkpoint to: best_model.pt

# %% [markdown]
# ## 9) Plot Loss / Accuracy (TF-history equivalent)

# %%
plt.figure(figsize=(10, 5))
plt.plot(history["train_loss"], label="Train loss")
plt.plot(history["val_loss"], label="Val/Test loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.title("Loss Curves")
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(history["train_acc"], label="Train acc")
plt.plot(history["val_acc"], label="Val/Test acc")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.title("Accuracy Curves")
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(history["train_f1"], label="Train macro-F1")
plt.plot(history["val_f1"], label="Val/Test macro-F1")
plt.xlabel("Epoch")
plt.ylabel("Macro-F1")
plt.legend()
plt.title("Macro-F1 Curves")
plt.show()

plt.figure(figsize=(10, 5))
plt.plot(history["val_w_cnn"], label="Val attn w_cnn (MFCC+Chroma CNN)")
plt.plot(history["val_w_lstm"], label="Val attn w_lstm (MFCC+Chroma LSTM)")
plt.plot(history["val_w_inter"], label="Val attn w_inter (CNN+LSTM)")
plt.xlabel("Epoch")
plt.ylabel("Mean gate weight")
plt.legend()
plt.title("Attention/Gated Fusion Weight Trends (Validation)")
plt.show()

# %% [markdown]
# ## 10) Final Evaluation on Unseen Set (Confusion Matrix + Report)
# Loads the best checkpoint (lowest validation loss) and evaluates on the unseen set.

# %%
# Load best checkpoint
model.load_state_dict(torch.load(checkpoint_path, map_location=device))
model.eval()

all_preds = []
all_targets = []

with torch.no_grad():
    for mfcc, chroma, y in unseen_loader:
        mfcc = mfcc.to(device)
        chroma = chroma.to(device)
        logits = model(mfcc, chroma)
        preds = torch.argmax(logits, dim=1).cpu().numpy()
        all_preds.append(preds)
        all_targets.append(y.numpy())

all_preds = np.concatenate(all_preds)
all_targets = np.concatenate(all_targets)

acc = accuracy_score(all_targets, all_preds)
prec, rec, f1, _ = precision_recall_fscore_support(all_targets, all_preds, average="macro", zero_division=0)
print(f"Unseen Accuracy: {acc:.4f}")
print(f"Unseen Macro Precision: {prec:.4f} | Recall: {rec:.4f} | F1: {f1:.4f}")

print("\nClassification report:")
print(classification_report(all_targets, all_preds, digits=4))

cm = confusion_matrix(all_targets, all_preds)
plt.figure(figsize=(7, 6))
plt.imshow(cm, interpolation="nearest")
plt.title("Confusion Matrix (Unseen)")
plt.colorbar()
plt.xlabel("Predicted")
plt.ylabel("True")
plt.show()
# Out:
# Unseen Accuracy: 0.3643
# Unseen Macro Precision: 0.3149 | Recall: 0.3280 | F1: 0.2347
#
# Classification report:
#               precision    recall  f1-score   support
#
#            0     0.0245    0.2353    0.0444        17
#            1     0.0000    0.0000    0.0000        28
#            2     0.8509    0.3224    0.4676       425
#            3     0.1533    0.6389    0.2473        36
#            4     0.3991    0.6855    0.5045       124
#            5     0.4615    0.0857    0.1446        70
#
#     accuracy                         0.3643       700
#    macro avg     0.3149    0.3280    0.2347       700
# weighted avg     0.6420    0.3643    0.4015       700
# /home/rithik-tank/enter/envs/tf_gpu/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/rithik-tank/enter/envs/tf_gpu/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/rithik-tank/enter/envs/tf_gpu/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
